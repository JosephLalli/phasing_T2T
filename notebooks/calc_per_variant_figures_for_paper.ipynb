# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
import polars as pl
import seaborn as sns
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import importlib


pedigree_file_loc = 'resources/pedigrees/gatk_1kgp.ped'
summary_statistics_folder='intermediate_data'

if os.getcwd()!='phasing_T2T_project':
    os.chdir('..') # Change to the parent directory

# %%
import glob; glob.glob(f"{summary_statistics_folder}/*")
# Out:
# ['intermediate_data/rolling_stats_500k_window.parquet',
#  'intermediate_data/flips_and_switches.parquet',
#  'intermediate_data/samples.parquet',
#  'intermediate_data/compressed_ideogram_100000_window.parquet',
#  'intermediate_data/variants.parquet',
#  'intermediate_data/compressed_ideogram_1000000_window.parquet',
#  'intermediate_data/per_genome_cnv_regions_with_slop.parquet',
#  'intermediate_data/chroms.parquet',
#  'intermediate_data/variant_frequency_stats',
#  'intermediate_data/switch_errors.parquet',
#  'intermediate_data/MAF_performance_variants.parquet',
#  'intermediate_data/sample_genotype_concordance.parquet',
#  'intermediate_data/per_sample_imputation_performance.parquet',
#  'intermediate_data/rolling_stats_250k_window.parquet',
#  'intermediate_data/bcftools_query_variant_data.parquet',
#  'intermediate_data/per_genome_cnv_regions.parquet',
#  'intermediate_data/per_variant_category_imputation_performance.parquet',
#  'intermediate_data/per_MAF_bin.parquet',
#  'intermediate_data/methods.parquet',
#  'intermediate_data/filter_summary_stats.parquet',
#  'intermediate_data/frequency.parquet',
#  'intermediate_data/variants.nozeros.parquet',
#  'intermediate_data/ancestries.parquet',
#  'intermediate_data/block_length.parquet',
#  'intermediate_data/all_variant_data.parquet',
#  'intermediate_data/rolling_stats_1m_window.parquet',
#  'intermediate_data/binned_maf_data.parquet',
#  'intermediate_data/type.parquet',
#  'intermediate_data/per_cytoband_variant_data.parquet']

# %%
q = pd.read_parquet('intermediate_data/per_MAF_bin.parquet')
q = q[(q.rounded_MAF=='singleton')&(q.method_of_phasing=='phased_with_parents_and_pedigree')&(q.syntenic=='All')&(q.type=='SNPs + Indels')]
# q.type=='SNPs + Indels'
q
# Out:
#                type rounded_MAF     genome                 method_of_phasing  \
# 862   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 1032  SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 978   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 901   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 1101  SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 893   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 748   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
#
#          ground_truth_data_source  n_switch_errors  n_checked  n_gt_errors  \
# 862                 HGSVC_samples            389.0     1505.0         3071
# 1032          HPRC_HGSVC_probands              4.0      109.0         3581
# 978   HGSVC_samples_nontrios_only            369.0     1123.0         2261
# 901                HGSVC_probands              4.0      109.0         1607
# 1101                HGSVC_parents             20.0      274.0         1176
# 893                  HPRC_samples              NaN        NaN         1046
# 748        HPRC_HGSVC_all_samples            393.0     1506.0         9450
#
#       n_gt_checked   MAC        AN  switch_error_rate  gt_error_rate  \
# 862         142515  2312  14806048          25.847176       2.154861
# 1032         52836   777   4975908           3.669725       6.777576
# 978          31863  1677  10739508          32.858415       7.096005
# 901          20646   666   4265064           3.669725       7.783590
# 1101         10192   784   5020736           7.299270      11.538462
# 893          32658   851   5449804                NaN       3.202891
# 748         267100  2671  17105084          26.095618       3.538001
#
#            MAF syntenic
# 862   0.015615      All
# 1032  0.015615      All
# 978   0.015615      All
# 901   0.015615      All
# 1101  0.015615      All
# 893   0.015615      All
# 748   0.015615      All

# %%
MAF_performance_variant_df = pl.read_parquet(f'{summary_statistics_folder}/MAF_performance_variants.parquet')
all_chroms = pd.read_parquet(f'{summary_statistics_folder}/chroms.parquet')
all_samples = pd.read_parquet(f'{summary_statistics_folder}/samples.parquet')
all_ancestries = pd.read_parquet(f'{summary_statistics_folder}/ancestries.parquet')
all_methods = pd.read_parquet(f'{summary_statistics_folder}/methods.parquet')
all_variants = pl.read_parquet(f'{summary_statistics_folder}/variants.parquet')

per_variant_category_imputation_performance = pd.read_parquet(f'{summary_statistics_folder}/per_variant_category_imputation_performance.parquet')
per_sample_imputation_performance = pd.read_parquet(f'{summary_statistics_folder}/per_sample_imputation_performance.parquet')

# %% [markdown]
# ### Variant Filtering Stats
# Stats in paragraph after "Full length, telomere to telomere maps of human genetic recombination rates are largely consistent with deCODE recombination rates"

# %%
variant_filter_stats = pd.read_parquet(f"{summary_statistics_folder}/filter_summary_stats.parquet")
variant_filter_stats['gatk_filter'] = variant_filter_stats.VQSLOD_filter #| variant_filter_stats.neg_train_site_filter
chm13_variant_stats = variant_filter_stats.loc[(variant_filter_stats.genome=='CHM13v2.0')]
singletons = chm13_variant_stats.loc[chm13_variant_stats.singleton]
not_singletons = chm13_variant_stats.loc[~chm13_variant_stats.singleton]

num_affected_gatk = chm13_variant_stats.loc[~(chm13_variant_stats.GRCh38_criteria_fail) &
                                            # chm13_variant_stats.CHM13_criteria_fail &
                                            chm13_variant_stats.gatk_filter].len.sum()


singletons_gained = singletons.loc[chm13_variant_stats.GRCh38_criteria_fail & 
                                   ~(chm13_variant_stats.CHM13_criteria_fail | 
                                   variant_filter_stats.CHM13_filtered)].len.sum()
print(f"Our VQSLOD filter resulted in the loss of an additional \n\
{num_affected_gatk} \
variants compared to the NYGC’s GRCh38 1KGP variant filtering methods, but the inclusion of singleton alleles added \n\
{singletons_gained} \
unique variants to our dataset (Supplemental Figure 1).")
singletons
# Out:
# Our VQSLOD filter resulted in the loss of an additional
# 14494016 variants compared to the NYGC’s GRCh38 1KGP variant filtering methods, but the inclusion of singleton alleles added
# 111805 unique variants to our dataset (Supplemental Figure 1).
#         genome  Syntenic  singleton  VQSLOD_filter  MERR_filter  \
# 7    CHM13v2.0     False       True          False        False
# 12   CHM13v2.0      True       True          False        False
# 40   CHM13v2.0     False       True           True        False
# 55   CHM13v2.0      True       True          False        False
# 90   CHM13v2.0      True       True          False        False
# 95   CHM13v2.0      True       True           True        False
# 104  CHM13v2.0      True       True           True         True
# 109  CHM13v2.0      True       True          False        False
# 113  CHM13v2.0      True       True          False        False
# 122  CHM13v2.0      True       True           True        False
# 124  CHM13v2.0      True       True          False        False
# 137  CHM13v2.0      True       True           True        False
# 166  CHM13v2.0     False       True          False        False
# 167  CHM13v2.0      True       True           True        False
# 180  CHM13v2.0      True       True          False        False
# 181  CHM13v2.0     False       True           True        False
# 205  CHM13v2.0     False       True           True        False
# 209  CHM13v2.0     False       True          False        False
# 219  CHM13v2.0     False       True           True        False
# 224  CHM13v2.0      True       True           True        False
# 235  CHM13v2.0      True       True           True        False
# 238  CHM13v2.0      True       True          False        False
# 261  CHM13v2.0      True       True           True        False
# 266  CHM13v2.0      True       True           True        False
# 269  CHM13v2.0      True       True          False        False
# 276  CHM13v2.0      True       True          False        False
# 289  CHM13v2.0      True       True           True        False
# 292  CHM13v2.0     False       True           True        False
# 301  CHM13v2.0     False       True          False        False
# 311  CHM13v2.0      True       True           True        False
# 315  CHM13v2.0      True       True          False        False
# 326  CHM13v2.0      True       True          False        False
# 328  CHM13v2.0     False       True           True        False
# 343  CHM13v2.0      True       True          False        False
# 355  CHM13v2.0     False       True          False        False
# 382  CHM13v2.0     False       True          False        False
# 393  CHM13v2.0     False       True          False        False
# 405  CHM13v2.0      True       True          False        False
# 417  CHM13v2.0     False       True          False        False
# 422  CHM13v2.0     False       True          False        False
# 426  CHM13v2.0     False       True           True        False
# 431  CHM13v2.0      True       True           True        False
# 436  CHM13v2.0     False       True           True        False
# 443  CHM13v2.0     False       True           True        False
# 446  CHM13v2.0      True       True          False        False
# 464  CHM13v2.0     False       True           True        False
# 469  CHM13v2.0     False       True          False        False
# 490  CHM13v2.0     False       True           True        False
# 497  CHM13v2.0      True       True           True        False
#
#      HWE_pop_filter  MAC_filter  AC_filter  f_missing_filter  var_len_filter  \
# 7             False       False       True             False           False
# 12            False       False       True              True            True
# 40            False       False       True             False           False
# 55            False       False      False              True           False
# 90            False       False      False             False           False
# 95            False       False      False             False           False
# 104           False       False       True              True           False
# 109           False       False       True             False           False
# 113           False       False       True              True           False
# 122           False       False       True              True           False
# 124           False       False       True             False            True
# 137           False       False       True              True            True
# 166           False       False       True              True           False
# 167           False       False      False             False           False
# 180           False       False       True             False           False
# 181           False       False       True              True           False
# 205           False       False      False             False           False
# 209           False       False       True             False            True
# 219           False       False       True              True           False
# 224           False       False       True             False            True
# 235           False       False       True              True           False
# 238           False       False       True             False           False
# 261           False       False       True             False           False
# 266           False       False       True             False           False
# 269           False       False       True              True            True
# 276           False       False      False             False           False
# 289           False       False      False              True           False
# 292           False       False       True              True            True
# 301           False       False       True             False            True
# 311           False       False       True             False            True
# 315           False       False       True              True           False
# 326           False       False      False             False           False
# 328           False       False       True             False            True
# 343           False       False       True             False            True
# 355           False       False       True             False           False
# 382           False       False       True              True           False
# 393           False       False       True              True            True
# 405           False       False       True             False           False
# 417           False       False       True              True            True
# 422           False       False      False             False           False
# 426           False       False       True             False           False
# 431           False       False       True              True            True
# 436           False       False      False              True           False
# 443           False       False       True             False            True
# 446           False       False       True             False           False
# 464           False       False       True              True            True
# 469           False       False       True             False           False
# 490           False       False       True             False           False
# 497           False       False       True             False           False
#
#      alt_star_filter  pass_filter  CHM13_filtered  GRCh38_filtered  \
# 7              False        False            True             True
# 12             False        False            True             True
# 40             False        False            True             True
# 55             False        False            True             True
# 90              True        False            True             True
# 95              True        False            True             True
# 104             True        False            True             True
# 109             True        False            True             True
# 113            False        False            True             True
# 122             True        False            True             True
# 124             True        False            True             True
# 137             True        False            True             True
# 166            False        False            True             True
# 167            False        False            True             True
# 180            False        False           False             True
# 181            False        False            True             True
# 205            False        False            True             True
# 209            False        False            True             True
# 219             True        False            True             True
# 224             True        False            True             True
# 235            False        False            True             True
# 238            False        False           False            False
# 261             True        False            True             True
# 266            False        False            True             True
# 269             True        False            True             True
# 276            False        False           False             True
# 289            False        False            True             True
# 292            False        False            True             True
# 301             True        False            True             True
# 311            False        False            True             True
# 315             True        False            True             True
# 326            False        False            True             True
# 328             True        False            True             True
# 343            False        False            True             True
# 355            False        False           False             True
# 382             True        False            True             True
# 393            False        False            True             True
# 405            False        False            True            False
# 417             True        False            True             True
# 422            False        False            True             True
# 426             True        False            True             True
# 431            False        False            True             True
# 436            False        False            True             True
# 443            False        False            True             True
# 446            False        False            True             True
# 464             True        False            True             True
# 469             True        False            True             True
# 490            False        False            True            False
# 497            False        False            True            False
#
#      GRCh38_criteria_fail  CHM13_criteria_fail       len  gatk_filter
# 7                    True                False    106488        False
# 12                   True                 True      1360        False
# 40                   True                 True    589443         True
# 55                   True                 True         3        False
# 90                   True                 True         1        False
# 95                   True                 True        12         True
# 104                  True                 True         2         True
# 109                  True                 True    441729        False
# 113                  True                 True     31253        False
# 122                  True                 True     10378         True
# 124                  True                 True      2318        False
# 137                  True                 True       535         True
# 166                  True                 True     15800        False
# 167                 False                 True       533         True
# 180                  True                False    111601        False
# 181                  True                 True    429834         True
# 205                 False                 True        11         True
# 209                  True                 True      1097        False
# 219                  True                 True     47924         True
# 224                  True                 True      4862         True
# 235                  True                 True    210022         True
# 238                  True                False       122        False
# 261                  True                 True    203660         True
# 266                  True                 True   7816298         True
# 269                  True                 True        44        False
# 276                 False                False         3        False
# 289                  True                 True        16         True
# 292                  True                 True     11841         True
# 301                  True                 True       532        False
# 311                  True                 True     68335         True
# 315                  True                 True      1133        False
# 326                 False                False      1545        False
# 328                  True                 True      2747         True
# 343                  True                 True     14518        False
# 355                  True                False        82        False
# 382                  True                 True      1245        False
# 393                  True                 True       354        False
# 405                  True                False        66        False
# 417                  True                 True       140        False
# 422                 False                False         3        False
# 426                  True                 True     52949         True
# 431                  True                 True     18167         True
# 436                  True                 True         5         True
# 443                  True                 True     11239         True
# 446                  True                False  40008264        False
# 464                  True                 True      2418         True
# 469                  True                 True      6834        False
# 490                  True                 True         3         True
# 497                  True                 True        26         True

# %%
not_singletons.loc[(not_singletons.Syntenic)].groupby(['CHM13_filtered', 'CHM13_criteria_fail','gatk_filter']).len.sum()
# Out:
# CHM13_filtered  CHM13_criteria_fail  gatk_filter
# False           False                False            213333
# True            False                False          60511946
#                 True                 False           2032062
#                                      True           17508360
# Name: len, dtype: uint64

# %%
variant_filter_stats.groupby(['genome','gatk_filter','GRCh38_criteria_fail'])['len'].sum().reset_index()
# Out:
# /tmp/ipykernel_3427642/2682831855.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   variant_filter_stats.groupby(['genome','gatk_filter','GRCh38_criteria_fail'])['len'].sum().reset_index()
#       genome  gatk_filter  GRCh38_criteria_fail       len
# 0     GRCh38        False                 False  61243112
# 1     GRCh38        False                  True  42784742
# 2     GRCh38         True                 False  13365695
# 3     GRCh38         True                  True  25729879
# 4  CHM13v2.0        False                 False  60934254
# 5  CHM13v2.0        False                  True  42867140
# 6  CHM13v2.0         True                 False  14494016
# 7  CHM13v2.0         True                  True  16177227

# %%
variant_filter_stats.loc[(~variant_filter_stats.CHM13_criteria_fail)&(variant_filter_stats.GRCh38_criteria_fail)].groupby(['GRCh38_criteria_fail','gatk_filter','genome','singleton'])['len'].sum().reset_index()
# Out:
# /tmp/ipykernel_3427642/1937395110.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   variant_filter_stats.loc[(~variant_filter_stats.CHM13_criteria_fail)&(variant_filter_stats.GRCh38_criteria_fail)].groupby(['GRCh38_criteria_fail','gatk_filter','genome','singleton'])['len'].sum().reset_index()
#    GRCh38_criteria_fail  gatk_filter     genome  singleton       len
# 0                  True        False     GRCh38       True  39599697
# 1                  True        False  CHM13v2.0       True  40226623

# %% [markdown]
# Table 1 and supplemental table XX

# %%
best_phased_variants = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree'))
catVarType = pl.Enum(['SNP','Indel','SNPs + Indels'])
best_phased_variants = best_phased_variants.with_columns(type=pl.col('type').cast(catVarType))
best_phased_variants = pl.concat([best_phased_variants, best_phased_variants.with_columns(type=pl.lit('SNPs + Indels').cast(catVarType))])
best_phased_variants_by_syntenic = best_phased_variants.group_by(['type','Syntenic','method_of_phasing','ground_truth_data_source','genome']
                                                                 ).sum(
                                                                 ).with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked')*100,
                                                                                switch_error_rate = pl.col('n_switch_errors')/pl.col('n_checked')*100
                                                                 ).to_pandas()
best_phased_variants_overall = best_phased_variants.group_by(['type','method_of_phasing','ground_truth_data_source','genome']
                                                                 ).sum(
                                                                 ).with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked')*100,
                                                                                switch_error_rate = pl.col('n_switch_errors')/pl.col('n_checked')*100
                                                                 ).to_pandas()

# %%
best_phased_variants_overall.sort_values(['ground_truth_data_source','genome','type'])
# Out:
#              type                 method_of_phasing  \
# 19            SNP  phased_with_parents_and_pedigree
# 16          Indel  phased_with_parents_and_pedigree
# 8   SNPs + Indels  phased_with_parents_and_pedigree
# 38            SNP  phased_with_parents_and_pedigree
# 33          Indel  phased_with_parents_and_pedigree
# 9   SNPs + Indels  phased_with_parents_and_pedigree
# 27            SNP  phased_with_parents_and_pedigree
# 13          Indel  phased_with_parents_and_pedigree
# 31  SNPs + Indels  phased_with_parents_and_pedigree
# 0             SNP  phased_with_parents_and_pedigree
# 4           Indel  phased_with_parents_and_pedigree
# 15  SNPs + Indels  phased_with_parents_and_pedigree
# 20            SNP  phased_with_parents_and_pedigree
# 7           Indel  phased_with_parents_and_pedigree
# 29  SNPs + Indels  phased_with_parents_and_pedigree
# 23            SNP  phased_with_parents_and_pedigree
# 5           Indel  phased_with_parents_and_pedigree
# 35  SNPs + Indels  phased_with_parents_and_pedigree
# 32            SNP  phased_with_parents_and_pedigree
# 30          Indel  phased_with_parents_and_pedigree
# 26  SNPs + Indels  phased_with_parents_and_pedigree
# 11            SNP  phased_with_parents_and_pedigree
# 34          Indel  phased_with_parents_and_pedigree
# 18  SNPs + Indels  phased_with_parents_and_pedigree
# 39            SNP  phased_with_parents_and_pedigree
# 24          Indel  phased_with_parents_and_pedigree
# 1   SNPs + Indels  phased_with_parents_and_pedigree
# 25            SNP  phased_with_parents_and_pedigree
# 3           Indel  phased_with_parents_and_pedigree
# 6   SNPs + Indels  phased_with_parents_and_pedigree
# 10            SNP  phased_with_parents_and_pedigree
# 37          Indel  phased_with_parents_and_pedigree
# 28  SNPs + Indels  phased_with_parents_and_pedigree
# 36            SNP  phased_with_parents_and_pedigree
# 2           Indel  phased_with_parents_and_pedigree
# 40  SNPs + Indels  phased_with_parents_and_pedigree
# 41            SNP  phased_with_parents_and_pedigree
# 22          Indel  phased_with_parents_and_pedigree
# 14  SNPs + Indels  phased_with_parents_and_pedigree
# 12            SNP  phased_with_parents_and_pedigree
# 17          Indel  phased_with_parents_and_pedigree
# 21  SNPs + Indels  phased_with_parents_and_pedigree
#
#        ground_truth_data_source     genome variant_id  n_switch_errors  \
# 19                 HPRC_samples     GRCh38       None             3664
# 16                 HPRC_samples     GRCh38       None             1466
# 8                  HPRC_samples     GRCh38       None             5130
# 38                 HPRC_samples  CHM13v2.0       None             2170
# 33                 HPRC_samples  CHM13v2.0       None             1193
# 9                  HPRC_samples  CHM13v2.0       None             3363
# 27                HGSVC_samples     GRCh38       None             6682
# 13                HGSVC_samples     GRCh38       None             2465
# 31                HGSVC_samples     GRCh38       None             9147
# 0                 HGSVC_samples  CHM13v2.0       None             4688
# 4                 HGSVC_samples  CHM13v2.0       None             2592
# 15                HGSVC_samples  CHM13v2.0       None             7280
# 20       HPRC_HGSVC_all_samples     GRCh38       None            12237
# 7        HPRC_HGSVC_all_samples     GRCh38       None             3735
# 29       HPRC_HGSVC_all_samples     GRCh38       None            15972
# 23       HPRC_HGSVC_all_samples  CHM13v2.0       None             8412
# 5        HPRC_HGSVC_all_samples  CHM13v2.0       None             3661
# 35       HPRC_HGSVC_all_samples  CHM13v2.0       None            12073
# 32          HPRC_HGSVC_probands     GRCh38       None             7041
# 30          HPRC_HGSVC_probands     GRCh38       None             2188
# 26          HPRC_HGSVC_probands     GRCh38       None             9229
# 11          HPRC_HGSVC_probands  CHM13v2.0       None             4921
# 34          HPRC_HGSVC_probands  CHM13v2.0       None             2265
# 18          HPRC_HGSVC_probands  CHM13v2.0       None             7186
# 39               HGSVC_probands     GRCh38       None             3319
# 24               HGSVC_probands     GRCh38       None              996
# 1                HGSVC_probands     GRCh38       None             4315
# 25               HGSVC_probands  CHM13v2.0       None             2237
# 3                HGSVC_probands  CHM13v2.0       None             1049
# 6                HGSVC_probands  CHM13v2.0       None             3286
# 10                HGSVC_parents     GRCh38       None             1812
# 37                HGSVC_parents     GRCh38       None              568
# 28                HGSVC_parents     GRCh38       None             2380
# 36                HGSVC_parents  CHM13v2.0       None             1044
# 2                 HGSVC_parents  CHM13v2.0       None              560
# 40                HGSVC_parents  CHM13v2.0       None             1604
# 41  HGSVC_samples_nontrios_only     GRCh38       None             3386
# 22  HGSVC_samples_nontrios_only     GRCh38       None              938
# 14  HGSVC_samples_nontrios_only     GRCh38       None             4324
# 12  HGSVC_samples_nontrios_only  CHM13v2.0       None             2440
# 17  HGSVC_samples_nontrios_only  CHM13v2.0       None              793
# 21  HGSVC_samples_nontrios_only  CHM13v2.0       None             3233
#
#     n_checked  n_gt_errors  n_gt_checked       MAC         AN  Syntenic  \
# 19     368771        55269       2690863  41946142  444066168     69221
# 16      70966        33755        531857   9134280   87709184     13683
# 8      439737        89024       3222720  51080422  531775352     82904
# 38     354018        12172       2499336  39847161  412936324     64480
# 33      79594        23808        563401   9924572   93120564     14534
# 9      433612        35980       3062737  49771733  506056888     79014
# 27     532570        75542       4308072  38507201  445878500     69489
# 13     104443        51501        855247   8512412   88432836     13792
# 31     637013       127043       5163319  47019613  534311336     83281
# 0      529875        46334       4278024  37923130  442337088     69069
# 4      118246        48364        948753   9459864   98051644     15275
# 15     648121        94698       5226777  47382994  540388732     84344
# 20     860644       239404       8314500  39412191  532460580     82986
# 7      166310       109060       1570600   8797182  100581224     15686
# 29    1026954       348464       9885100  48209373  633041804     98672
# 23     854138       171416       8197200  38603424  524948688     81967
# 5      190066       101392       1734000   9762226  111045360     17298
# 35    1044204       272808       9931200  48365650  635994048     99265
# 32     595191        94047       4968420  39115048  467908260     72917
# 30     113913        58298        965600   8594170   90936800     14182
# 26     709104       152345       5934020  47709218  558845060     87099
# 11     586088        70223       4803044  38331543  452333732     70628
# 34     130287        55686       1059984   9543504   99825552     15548
# 18     716375       125909       5863028  47875047  552159284     86176
# 39     270023        38096       1731660  38364549  357727440     55741
# 24      51477        23736        362266   8249435   74837144     11672
# 1      321500        61832       2093926  46613984  432564584     67413
# 25     263892        36644       1672481  37624081  345502204     53947
# 3       58636        24185        394661   9186869   81529324     12699
# 6      322528        60829       2067142  46810950  427031528     66646
# 10     115944        33585        574613  37052464  283063204     44089
# 37      22762        12698        121420   7753885   59813360      9330
# 28     138706        46283        696033  44806349  342876564     53419
# 36     118176        21603        558467  36412859  275109436     42958
# 2       26409        11560        133666   8759995   65845928     10259
# 40     144585        33163        692133  45172854  340955364     53217
# 41     149192        44905        874437  37640950  294731292     45927
# 22      29739        18356        188157   7982317   63418812      9894
# 14     178931        63261       1062594  45623267  358150104     55821
# 12     149650        29222        864823  37005573  291490868     45515
# 17      33490        16321        207309   8979034   69874044     10888
# 21     183140        45543       1072132  45984607  361364912     56403
#
#     multiallelic  in_platinum_STRs  in_segdups  in_STRs            MAF  \
# 19          5601              7803       22995     3083  654836.500000
# 16          9941              9679        3451     2011  142638.359375
# 8          15542             17482       26446     5094  797406.062500
# 38          4688              6145        7788     2267  622073.750000
# 33         10155              9844        2301     2584  154979.968750
# 9          14843             15989       10089     4851  776970.937500
# 27          5524              8023       22003     3179  601137.375000
# 13         10062              9783        3216     2018  132927.281250
# 31         15586             17806       25219     5197  733991.125000
# 0           5047              6718        8337     2512  592002.562500
# 4          10694             10343        2354     2655  147723.484375
# 15         15741             17061       10691     5167  739630.812500
# 20          6336              9313       25414     3635  615215.687500
# 7          11178             10917        3802     2309  137374.734375
# 29         17514             20230       29216     5944  752485.125000
# 23          5861              7735        9270     2847  602568.375000
# 5          11858             11522        2804     2989  152445.734375
# 35         17719             19257       12074     5836  754892.687500
# 32          5653              8214       22287     3234  610620.625000
# 30         10202              9933        3351     2079  134204.093750
# 26         15855             18147       25638     5313  744732.187500
# 11          5171              6693        8015     2490  598381.562500
# 34         10745             10432        2467     2708  149029.703125
# 18         15916             17125       10482     5198  747309.812500
# 39          4507              6342       17574     2534  598971.187500
# 24          8635              8403        2696     1723  128819.960938
# 1          13142             14745       20270     4257  727732.375000
# 25          4145              5174        6339     1967  587404.062500
# 3           9032              8749        1920     2264  143459.359375
# 6          13177             13923        8259     4231  730796.625000
# 10          3622              4948       14165     1971  578524.687500
# 37          6888              6700        2108     1397  121080.867188
# 28         10510             11648       16273     3368  699571.875000
# 36          3365              4108        5190     1554  568530.812500
# 2           7310              7076        1517     1890  136792.187500
# 40         10675             11184        6707     3444  705290.125000
# 41          3830              5192       14599     2077  587707.687500
# 22          7421              7220        2163     1448  124648.085938
# 14         11251             12412       16762     3525  712320.000000
# 12          3620              4369        5424     1657  577773.437500
# 17          7862              7609        1581     1954  140212.906250
# 21         11482             11978        7005     3611  717948.687500
#
#    rounded_MAF  gt_error_rate  switch_error_rate
# 19         NaN       2.053951           0.993571
# 16         NaN       6.346631           2.065778
# 8          NaN       2.762387           1.166606
# 38         NaN       0.487009           0.612963
# 33         NaN       4.225765           1.498857
# 9          NaN       1.174766           0.775578
# 27         NaN       1.753499           1.254671
# 13         NaN       6.021769           2.360139
# 31         NaN       2.460491           1.435920
# 0          NaN       1.083070           0.884737
# 4          NaN       5.097639           2.192040
# 15         NaN       1.811786           1.123247
# 20         NaN       2.879355           1.421842
# 7          NaN       6.943843           2.245806
# 29         NaN       3.525144           1.555279
# 23         NaN       2.091153           0.984853
# 5          NaN       5.847290           1.926173
# 35         NaN       2.746979           1.156192
# 32         NaN       1.892896           1.182982
# 30         NaN       6.037490           1.920764
# 26         NaN       2.567315           1.301502
# 11         NaN       1.462052           0.839635
# 34         NaN       5.253476           1.738470
# 18         NaN       2.147508           1.003106
# 39         NaN       2.199970           1.229155
# 24         NaN       6.552092           1.934845
# 1          NaN       2.952922           1.342146
# 25         NaN       2.190996           0.847695
# 3          NaN       6.128044           1.789003
# 6          NaN       2.942662           1.018826
# 10         NaN       5.844803           1.562823
# 37         NaN      10.457915           2.495387
# 28         NaN       6.649541           1.715859
# 36         NaN       3.868268           0.883428
# 2          NaN       8.648422           2.120489
# 40         NaN       4.791420           1.109382
# 41         NaN       5.135304           2.269559
# 22         NaN       9.755683           3.154107
# 14         NaN       5.953450           2.416574
# 12         NaN       3.378957           1.630471
# 17         NaN       7.872789           2.367871
# 21         NaN       4.247891           1.765316

# %%
best_phased_variants_by_syntenic.loc[best_phased_variants_by_syntenic.ground_truth_data_source=='HPRC_samples'].sort_values(['ground_truth_data_source','Syntenic','genome','type'])
# Out:
#              type  Syntenic                 method_of_phasing  \
# 4             SNP     False  phased_with_parents_and_pedigree
# 30          Indel     False  phased_with_parents_and_pedigree
# 28  SNPs + Indels     False  phased_with_parents_and_pedigree
# 53            SNP     False  phased_with_parents_and_pedigree
# 73          Indel     False  phased_with_parents_and_pedigree
# 82  SNPs + Indels     False  phased_with_parents_and_pedigree
# 79            SNP      True  phased_with_parents_and_pedigree
# 26          Indel      True  phased_with_parents_and_pedigree
# 75  SNPs + Indels      True  phased_with_parents_and_pedigree
# 59            SNP      True  phased_with_parents_and_pedigree
# 10          Indel      True  phased_with_parents_and_pedigree
# 77  SNPs + Indels      True  phased_with_parents_and_pedigree
#
#    ground_truth_data_source     genome variant_id  n_switch_errors  n_checked  \
# 4              HPRC_samples     GRCh38       None                0        882
# 30             HPRC_samples     GRCh38       None                0         47
# 28             HPRC_samples     GRCh38       None                0        929
# 53             HPRC_samples  CHM13v2.0       None                0          0
# 73             HPRC_samples  CHM13v2.0       None                3         22
# 82             HPRC_samples  CHM13v2.0       None                3         22
# 79             HPRC_samples     GRCh38       None             3664     367889
# 26             HPRC_samples     GRCh38       None             1466      70919
# 75             HPRC_samples     GRCh38       None             5130     438808
# 59             HPRC_samples  CHM13v2.0       None             2170     354018
# 10             HPRC_samples  CHM13v2.0       None             1190      79572
# 77             HPRC_samples  CHM13v2.0       None             3360     433590
#
#     n_gt_errors  n_gt_checked       MAC         AN  multiallelic  \
# 4           145          4716     97434     774884             9
# 30           22           507      7212      83252             8
# 28          167          5223    104646     858136            17
# 53            3            39       109       6404             1
# 73           60           273      6347      44828             5
# 82           63           312      6456      51232             6
# 79        55124       2686147  41848708  443291284          5592
# 26        33733        531350   9127068   87625932          9933
# 75        88857       3217497  50975776  530917216         15525
# 59        12169       2499297  39847052  412929920          4687
# 10        23748        563128   9918225   93075736         10150
# 77        35917       3062425  49765277  506005656         14837
#
#     in_platinum_STRs  in_segdups  in_STRs            MAF rounded_MAF  \
# 4                  7           2        3    1521.455322         NaN
# 30                 7           2        1     112.617111         NaN
# 28                14           4        4    1634.072754         NaN
# 53                 0           1        0       1.702061         NaN
# 73                 5           7        3      99.109924         NaN
# 82                 5           8        3     100.811989         NaN
# 79              7796       22993     3080  653316.625000         NaN
# 26              9672        3449     2010  142525.718750         NaN
# 75             17468       26442     5090  795773.625000         NaN
# 59              6145        7787     2267  622072.062500         NaN
# 10              9839        2294     2581  154880.875000         NaN
# 77             15984       10081     4848  776870.125000         NaN
#
#     gt_error_rate  switch_error_rate
# 4        3.074640           0.000000
# 30       4.339250           0.000000
# 28       3.197396           0.000000
# 53       7.692308                NaN
# 73      21.978022          13.636364
# 82      20.192308          13.636364
# 79       2.052159           0.995953
# 26       6.348546           2.067147
# 75       2.761681           1.169076
# 59       0.486897           0.612963
# 10       4.217158           1.495501
# 77       1.172829           0.774926

# %% [markdown]
# ### Percent concordance in different panels

# %%
overall_subsetted = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree')).group_by(['type','Syntenic','method_of_phasing','ground_truth_data_source','genome']).sum().with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked'))
overall           = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree')).group_by(['method_of_phasing','ground_truth_data_source','genome']).sum().with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked'))
overall_syntenic  = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('Syntenic'))&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree')).group_by(['method_of_phasing','ground_truth_data_source','genome']).sum().with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked'))

# %%
overall_syntenic = overall_syntenic.to_pandas()[['Syntenic','genome','ground_truth_data_source','gt_error_rate']].sort_values(['genome','Syntenic','gt_error_rate'])
overall_syntenic['Non-reference true positive rate'] = (1-overall_syntenic.gt_error_rate) * 100
overall_syntenic['gt_error_rate'] *= 100
overall_syntenic.loc[overall_syntenic.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples','HPRC_HGSVC_all_samples'))]
# Out:
#     Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 4      82904     GRCh38             HPRC_samples       2.761681
# 5      83281     GRCh38            HGSVC_samples       2.463194
# 1      98672     GRCh38   HPRC_HGSVC_all_samples       3.522661
# 2      79014  CHM13v2.0             HPRC_samples       1.172829
# 13     84344  CHM13v2.0            HGSVC_samples       1.806058
# 3      99265  CHM13v2.0   HPRC_HGSVC_all_samples       2.740583
#
#     Non-reference true positive rate
# 4                          97.238319
# 5                          97.536806
# 1                          96.477339
# 2                          98.827171
# 13                         98.193942
# 3                          97.259417

# %%
overall = overall.to_pandas()[['Syntenic','genome','ground_truth_data_source','gt_error_rate']].sort_values(['genome','Syntenic','gt_error_rate'])
overall['Non-reference true positive rate'] = (1-overall.gt_error_rate) * 100
overall['gt_error_rate'] *= 100
overall.loc[overall.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples','HPRC_HGSVC_all_samples'))]
# Out:
#    Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 2     82904     GRCh38             HPRC_samples       2.762387
# 6     83281     GRCh38            HGSVC_samples       2.460491
# 1     98672     GRCh38   HPRC_HGSVC_all_samples       3.525144
# 4     79014  CHM13v2.0             HPRC_samples       1.174766
# 7     84344  CHM13v2.0            HGSVC_samples       1.811786
# 8     99265  CHM13v2.0   HPRC_HGSVC_all_samples       2.746979
#
#    Non-reference true positive rate
# 2                         97.237613
# 6                         97.539509
# 1                         96.474856
# 4                         98.825234
# 7                         98.188214
# 8                         97.253021

# %%
overall_subsetted = overall_subsetted.to_pandas()[['type','Syntenic','genome','ground_truth_data_source','gt_error_rate']].sort_values(['genome','type','Syntenic','gt_error_rate'])
overall_subsetted['Non-reference true positive rate'] = (1-overall_subsetted.gt_error_rate) * 100
overall_subsetted['gt_error_rate'] *= 100
overall_subsetted.loc[overall_subsetted.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples','HPRC_HGSVC_all_samples'))]
# Out:
#      type  Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 17    SNP     False     GRCh38            HGSVC_samples       0.771056
# 14    SNP     False     GRCh38             HPRC_samples       3.074640
# 54    SNP     False     GRCh38   HPRC_HGSVC_all_samples       5.000000
# 55    SNP      True     GRCh38            HGSVC_samples       1.755425
# 24    SNP      True     GRCh38             HPRC_samples       2.052159
# 33    SNP      True     GRCh38   HPRC_HGSVC_all_samples       2.875292
# 7   Indel     False     GRCh38            HGSVC_samples       2.754036
# 1   Indel     False     GRCh38   HPRC_HGSVC_all_samples       4.050000
# 39  Indel     False     GRCh38             HPRC_samples       4.339250
# 46  Indel      True     GRCh38            HGSVC_samples       6.025797
# 37  Indel      True     GRCh38             HPRC_samples       6.348546
# 51  Indel      True     GRCh38   HPRC_HGSVC_all_samples       6.947533
# 28    SNP     False  CHM13v2.0             HPRC_samples       7.692308
# 10    SNP     False  CHM13v2.0            HGSVC_samples      15.591398
# 42    SNP     False  CHM13v2.0   HPRC_HGSVC_all_samples      17.200000
# 21    SNP      True  CHM13v2.0             HPRC_samples       0.486897
# 19    SNP      True  CHM13v2.0            HGSVC_samples       1.082439
# 22    SNP      True  CHM13v2.0   HPRC_HGSVC_all_samples       2.090231
# 2   Indel     False  CHM13v2.0            HGSVC_samples      14.093357
# 44  Indel     False  CHM13v2.0   HPRC_HGSVC_all_samples      16.142857
# 25  Indel     False  CHM13v2.0             HPRC_samples      21.978022
# 0   Indel      True  CHM13v2.0             HPRC_samples       4.217158
# 5   Indel      True  CHM13v2.0            HGSVC_samples       5.076464
# 12  Indel      True  CHM13v2.0   HPRC_HGSVC_all_samples       5.822292
#
#     Non-reference true positive rate
# 17                         99.228944
# 14                         96.925360
# 54                         95.000000
# 55                         98.244575
# 24                         97.947841
# 33                         97.124708
# 7                          97.245964
# 1                          95.950000
# 39                         95.660750
# 46                         93.974203
# 37                         93.651454
# 51                         93.052467
# 28                         92.307692
# 10                         84.408602
# 42                         82.800000
# 21                         99.513103
# 19                         98.917561
# 22                         97.909769
# 2                          85.906643
# 44                         83.857143
# 25                         78.021978
# 0                          95.782842
# 5                          94.923536
# 12                         94.177708

# %%
# wide_genome_ideogram['SER_diff'] = wide_genome_ideogram['SER_t2t'] - wide_genome_ideogram['SER_grch38']
# region_table = (wide_genome_ideogram.loc[(wide_genome_ideogram.ground_truth_data_source=='HPRC_samples') & 
#                          (wide_genome_ideogram.method_of_phasing=='HPRC_variation_phased_with_reference_panel') #& 
#                         & (wide_genome_ideogram.contextual_MAC_grch38 > 1e6)
#                         & (wide_genome_ideogram.contextual_MAC_t2t > 1e6)
#                         ])
# decipher_regions = ['1p36.33','1p36.32','1p36.31','1p36.23','1p36.22','1p36.21','1q21.1','1q21.2','2p21','2p16.1','2p15','2q32.3','2q33.1','2q33.2','2q33.3','2q37.3','3q29','4p16.3','5p15.33','5p15.32','5p15.31','5p15.2','5q22.3','5q23.2','5q35.2','5q35.3','7q11.22','7q21.3','8p23.1','8q21.13','9q34.3','11p13','11p11.2','12q14.2','12q14.3','12q15','15q11.2','15q12','15q13.1','15q13.2','15q13.3','15q24.1','15q24.2','15q26.3','16p13.3','16p13.11','16p12.2','16p12.1','16p11.2','17p13.3','17p12','17p11.2','17q11.2','17q12','17q21.31','21q21.3','22p13','22p12','22p11.2','22p11.1','22q11.1','22q11.21','22q11.22','22q11.23','22q13.33','Xp22.33','Xp22.31','Xp11.23','Xp11.22','Xq22.2','Xq28']
# region_table.interval_names = region_table.chrom.str.replace('chr','') + region_table.interval_names
# region_table['decipher_region'] = region_table.interval_names.isin(decipher_regions)

# region_table = (region_table.sort_values('SER_diff').iloc[:].reset_index(drop=True)
#                         [['chrom','interval_names','decipher_region','n_switch_errors_grch38','n_checked_grch38','n_switch_errors_t2t','n_checked_t2t','SER_grch38','SER_t2t','SER_diff']])

# region_table = region_table.drop(columns='chrom').rename(columns={'interval_names':'Genetic Region',
#                                                    'n_switch_errors_grch38': 'Switch Errors (GRCh38 panel)',
#                                                    'n_switch_errors_t2t': 'Switch Errors (CHM13 panel)',
#                                                    'n_checked_grch38': 'Heterozygous sites (GRCh38 panel)',
#                                                    'n_checked_t2t': 'Heterozygous sites (CHM13 panel)',
#                                                    'SER_grch38': 'SER % (GRCh38 panel)',
#                                                    'SER_t2t': 'SER % (CHM13 panel)',
#                                                    'SER_diff': 'Absolute reduction in SER (% points)'})

# pd.set_option('display.float_format', lambda x: f'{x:,.2f}%')
# region_table.set_index('Genetic Region')

# %%
rephase=all_variants.filter((pl.col('method_of_phasing') == '1kgp_variation_phased_with_reference_panel') & 
                         (pl.col('ground_truth_data_source') == 'HPRC_samples'))

singletons_rephase_sum = rephase.filter(pl.col('contextual_MAC') == 1).group_by('genome').sum().to_pandas().reset_index()
singletons_rephase_sum['SER'] = singletons_rephase_sum.n_switch_errors/singletons_rephase_sum.n_checked*100
for idx, (genome, ser) in singletons_rephase_sum[['genome','SER']].iterrows():
    print(f'Singletons in {genome}: {ser}')

rare_rephase = rephase.filter(pl.col('contextual_MAC')/pl.col('contextual_AN') < 0.01)
common_rephase = rephase.filter(pl.col('contextual_MAC')/pl.col('contextual_AN') >= 0.01)

rare_rephase_sum = rare_rephase.group_by('genome').sum().to_pandas().reset_index()
common_rephase_sum = common_rephase.group_by('genome').sum().to_pandas().reset_index()
for idx, (genome, n_switch_errors, n_checked) in rare_rephase_sum[['genome','n_switch_errors', 'n_checked']].iterrows():
    print (f"\nRare in {genome}: {n_switch_errors/n_checked*100}")
    print (f"Common in {genome}: {common_rephase_sum.iloc[idx].n_switch_errors/common_rephase_sum.iloc[idx].n_checked*100}")
syntenic = common_rephase.filter(pl.col('Syntenic') == True)
nonsyntenic = common_rephase.filter(pl.col('Syntenic') == False)

syntenic_sum = syntenic.group_by('genome').sum().to_pandas().set_index('genome')
nonsyntenic_sum = nonsyntenic.group_by('genome').sum().to_pandas().set_index('genome')

for genome, row in syntenic_sum.iterrows():
    print (f"\nCommon Syntenic in {genome}: {row.n_switch_errors/row.n_checked*100}")
    print (f"Common Nonsyntenic {genome}: {nonsyntenic_sum.loc[genome].n_switch_errors/nonsyntenic_sum.loc[genome].n_checked*100}")
# Out:
# Singletons in GRCh38: 14.39873417721519
# Singletons in CHM13v2.0: 9.825145711906744
#
# Rare in CHM13v2.0: 6.018179918503814
# Common in CHM13v2.0: 1.1376264478260545
#
# Rare in GRCh38: 7.419862621637092
# Common in GRCh38: 1.6314417692446646
#
# Common Syntenic in GRCh38: 1.635230560250521
# Common Nonsyntenic GRCh38: 0.798175598631699
#
# Common Syntenic in CHM13v2.0: 1.1374146006742445
# Common Nonsyntenic CHM13v2.0: 7.6923076923076925

# %%
synEnum = pl.Enum(categories=['All_regions', 'Syntenic', 'Nonsyntenic'])
concordance = all_variants.filter((pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
                                  (pl.col('ground_truth_data_source') == 'HPRC_samples')).with_columns(Syntenic=pl.col('Syntenic').cast(str).replace('true','Syntenic').replace('false','Nonsyntenic').cast(synEnum))

# %%
concordance_summary = concordance.clone().with_columns(Syntenic = pl.lit('All_regions').cast(synEnum))
concordance_summary = pl.concat((concordance, concordance_summary)).group_by(['Syntenic','genome','type']).sum().to_pandas().reset_index()
concordance_summary = pd.concat((concordance_summary, concordance_summary.copy().assign(type = 'SNPs + Indels').groupby(['Syntenic','genome','type'], observed=True).sum(numeric_only=True).reset_index()))
concordance_summary['gt_error_rate'] = concordance_summary.n_gt_errors/concordance_summary.n_gt_checked*100
concordance_summary['gt_accuracy_rate'] = 100-concordance_summary['gt_error_rate'] 
concordance_summary['switch_error_rate'] = concordance_summary.n_switch_errors/concordance_summary.n_checked*100
concordance_summary['Syntenic'] = concordance_summary.Syntenic.replace('false', 'Nonsyntenic').replace('true','Syntenic')

# %%
pd.set_option("display.precision", 3)
concordance_summary.sort_values(['Syntenic','genome','type']).set_index(['Syntenic','genome','type'])[['switch_error_rate','gt_error_rate','n_gt_errors','n_gt_checked', 'n_switch_errors', 'n_checked']].astype(float)
# Out:
#                                      switch_error_rate  gt_error_rate  \
# Syntenic    genome    type
# All_regions GRCh38    Indel                      2.066          6.347
#                       SNP                        0.994          2.054
#                       SNPs + Indels              1.167          2.762
#             CHM13v2.0 Indel                      1.499          4.226
#                       SNP                        0.613          0.487
#                       SNPs + Indels              0.776          1.175
# Syntenic    GRCh38    Indel                      2.067          6.349
#                       SNP                        0.996          2.052
#                       SNPs + Indels              1.169          2.762
#             CHM13v2.0 Indel                      1.496          4.217
#                       SNP                        0.613          0.487
#                       SNPs + Indels              0.775          1.173
# Nonsyntenic GRCh38    Indel                      0.000          4.339
#                       SNP                        0.000          3.075
#                       SNPs + Indels              0.000          3.197
#             CHM13v2.0 Indel                     13.636         21.978
#                       SNP                          NaN          7.692
#                       SNPs + Indels             13.636         20.192
#
#                                      n_gt_errors  n_gt_checked  \
# Syntenic    genome    type
# All_regions GRCh38    Indel              33755.0     5.319e+05
#                       SNP                55269.0     2.691e+06
#                       SNPs + Indels      89024.0     3.223e+06
#             CHM13v2.0 Indel              23808.0     5.634e+05
#                       SNP                12172.0     2.499e+06
#                       SNPs + Indels      35980.0     3.063e+06
# Syntenic    GRCh38    Indel              33733.0     5.314e+05
#                       SNP                55124.0     2.686e+06
#                       SNPs + Indels      88857.0     3.217e+06
#             CHM13v2.0 Indel              23748.0     5.631e+05
#                       SNP                12169.0     2.499e+06
#                       SNPs + Indels      35917.0     3.062e+06
# Nonsyntenic GRCh38    Indel                 22.0     5.070e+02
#                       SNP                  145.0     4.716e+03
#                       SNPs + Indels        167.0     5.223e+03
#             CHM13v2.0 Indel                 60.0     2.730e+02
#                       SNP                    3.0     3.900e+01
#                       SNPs + Indels         63.0     3.120e+02
#
#                                      n_switch_errors  n_checked
# Syntenic    genome    type
# All_regions GRCh38    Indel                   1466.0    70966.0
#                       SNP                     3664.0   368771.0
#                       SNPs + Indels           5130.0   439737.0
#             CHM13v2.0 Indel                   1193.0    79594.0
#                       SNP                     2170.0   354018.0
#                       SNPs + Indels           3363.0   433612.0
# Syntenic    GRCh38    Indel                   1466.0    70919.0
#                       SNP                     3664.0   367889.0
#                       SNPs + Indels           5130.0   438808.0
#             CHM13v2.0 Indel                   1190.0    79572.0
#                       SNP                     2170.0   354018.0
#                       SNPs + Indels           3360.0   433590.0
# Nonsyntenic GRCh38    Indel                      0.0       47.0
#                       SNP                        0.0      882.0
#                       SNPs + Indels              0.0      929.0
#             CHM13v2.0 Indel                      3.0       22.0
#                       SNP                        0.0        0.0
#                       SNPs + Indels              3.0       22.0

# %%
# Parental-uninformative rate among proband hets (CHM13v2.0 PAR1)
from pathlib import Path

import pandas as pd

parquet_path = Path("..") / "intermediate_data" / "proband_parent_uninformative_by_MAF.parquet"
uninformative_by_maf = pd.read_parquet(parquet_path)

# Quick sanity check: show how many variants and trios were used
uninformative_by_maf[["genome", "region", "n_trios", "n_variants_seen"]].drop_duplicates().reset_index(drop=True)
# Out:
#       genome          region  n_trios  n_variants_seen
# 0  CHM13v2.0  chrX:1-2394410      602            68904

# %%
# Plot breakdown of informative vs uninformative categories by MAF bin (CHM13v2.0 PAR1)
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# If the previous cell hasn't been run, load the parquet here too.
if "uninformative_by_maf" not in globals():
    parquet_path = Path("..") / "intermediate_data" / "proband_parent_uninformative_by_MAF.parquet"
    uninformative_by_maf = pd.read_parquet(parquet_path)

# Canonical rounded_MAF ordering used throughout the repo
rounded_maf_order = [
    "singleton",
    "0.00021-0.00042",
    "0.00042-0.00064",
    "0.00064-0.001",
    "0.001-0.0016",
    "0.0016-0.0022",
    "0.0022-0.003",
    "0.003-0.004",
    "0.004-0.0054",
    "0.0054-0.0072",
    "0.0072-0.0094",
    "0.0094-0.0126",
    "0.0126-0.0172",
    "0.0172-0.0244",
    "0.0244-0.037",
    "0.037-0.06",
    "0.06-0.102",
    "0.102-0.166",
    "0.166-0.255",
    "0.255-0.372",
    "0.372-0.5",
]

plot_df = uninformative_by_maf.copy()
plot_df = plot_df.loc[(plot_df.genome == "CHM13v2.0") & (plot_df.region == "chrX:1-2394410")].copy()

# Ensure all required percent columns exist (compute from counts if needed).
needed_count_cols = [
    "n_proband_hets",
    "n_uninf_both_parents_het",
    "n_uninf_both_parents_missing",
    "n_uninf_one_missing_one_het",
    "n_informative",
]
missing_counts = [c for c in needed_count_cols if c not in plot_df.columns]
if missing_counts:
    raise ValueError(f"Parquet is missing required columns: {missing_counts}")

# Fill missing MAF bins with zeros for cleaner plotting
plot_df["rounded_MAF"] = pd.Categorical(plot_df["rounded_MAF"], categories=rounded_maf_order, ordered=True)
plot_df = plot_df.set_index("rounded_MAF").reindex(rounded_maf_order).reset_index()
for col in needed_count_cols:
    plot_df[col] = plot_df[col].fillna(0).astype(float)

den = plot_df["n_proband_hets"].replace(0, np.nan)
plot_df["pct_uninf_both_parents_het"] = plot_df["n_uninf_both_parents_het"] / den * 100
plot_df["pct_uninf_both_parents_missing"] = plot_df["n_uninf_both_parents_missing"] / den * 100
plot_df["pct_uninf_one_missing_one_het"] = plot_df["n_uninf_one_missing_one_het"] / den * 100
plot_df["pct_informative"] = plot_df["n_informative"] / den * 100

x = plot_df["rounded_MAF"].astype(str).tolist()
p_both_het = plot_df["pct_uninf_both_parents_het"].fillna(0).to_numpy()
p_both_missing = plot_df["pct_uninf_both_parents_missing"].fillna(0).to_numpy()
p_one_missing_one_het = plot_df["pct_uninf_one_missing_one_het"].fillna(0).to_numpy()
p_informative = plot_df["pct_informative"].fillna(0).to_numpy()

plt.figure(figsize=(12, 4))
bottom = np.zeros_like(p_both_het)
plt.bar(x, p_both_het, bottom=bottom, label="Uninformative: both parents het")
bottom = bottom + p_both_het
plt.bar(x, p_both_missing, bottom=bottom, label="Uninformative: both parents missing")
bottom = bottom + p_both_missing
plt.bar(x, p_one_missing_one_het, bottom=bottom, label="Uninformative: one missing + one het")
bottom = bottom + p_one_missing_one_het
# plt.bar(x, p_informative, bottom=bottom, label="Informative")

plt.xlabel("rounded_MAF")
plt.ylabel("% of proband het sites")
plt.title("CHM13v2.0 PAR1: parental informativeness breakdown by MAF bin")
plt.xticks(rotation=90)
plt.legend(frameon=False, ncol=2, fontsize=9)
plt.tight_layout()
plt.show()

# %%
plot_df
# Out:
#         rounded_MAF     genome          region  n_proband_hets  \
# 0         singleton  CHM13v2.0  chrX:1-2394410            10.0
# 1   0.00021-0.00042  CHM13v2.0  chrX:1-2394410          3816.0
# 2   0.00042-0.00064  CHM13v2.0  chrX:1-2394410          3163.0
# 3     0.00064-0.001  CHM13v2.0  chrX:1-2394410          2746.0
# 4      0.001-0.0016  CHM13v2.0  chrX:1-2394410          4768.0
# 5     0.0016-0.0022  CHM13v2.0  chrX:1-2394410          4985.0
# 6      0.0022-0.003  CHM13v2.0  chrX:1-2394410          6916.0
# 7       0.003-0.004  CHM13v2.0  chrX:1-2394410          8551.0
# 8      0.004-0.0054  CHM13v2.0  chrX:1-2394410         13374.0
# 9     0.0054-0.0072  CHM13v2.0  chrX:1-2394410         16781.0
# 10    0.0072-0.0094  CHM13v2.0  chrX:1-2394410         19323.0
# 11    0.0094-0.0126  CHM13v2.0  chrX:1-2394410         25995.0
# 12    0.0126-0.0172  CHM13v2.0  chrX:1-2394410         37229.0
# 13    0.0172-0.0244  CHM13v2.0  chrX:1-2394410         55983.0
# 14     0.0244-0.037  CHM13v2.0  chrX:1-2394410         89385.0
# 15       0.037-0.06  CHM13v2.0  chrX:1-2394410        130921.0
# 16       0.06-0.102  CHM13v2.0  chrX:1-2394410        225260.0
# 17      0.102-0.166  CHM13v2.0  chrX:1-2394410        355883.0
# 18      0.166-0.255  CHM13v2.0  chrX:1-2394410        473707.0
# 19      0.255-0.372  CHM13v2.0  chrX:1-2394410        649266.0
# 20        0.372-0.5  CHM13v2.0  chrX:1-2394410        653815.0
#
#     n_parent_uninformative  n_uninf_both_parents_het  \
# 0                        1                       0.0
# 1                        1                       0.0
# 2                       16                      16.0
# 3                       20                      18.0
# 4                       49                      45.0
# 5                       61                      60.0
# 6                       96                      93.0
# 7                      144                     139.0
# 8                      259                     252.0
# 9                      406                     397.0
# 10                     525                     514.0
# 11                     996                     982.0
# 12                    1758                    1739.0
# 13                    3639                    3592.0
# 14                    7522                    7460.0
# 15                   13074                   12966.0
# 16                   27267                   27115.0
# 17                   52508                   52281.0
# 18                   84887                   84613.0
# 19                  137707                  137482.0
# 20                  150561                  150305.0
#
#     n_uninf_both_parents_missing  n_uninf_one_missing_one_het  n_informative  \
# 0                            1.0                          0.0            9.0
# 1                            1.0                          0.0         3815.0
# 2                            0.0                          0.0         3147.0
# 3                            1.0                          1.0         2726.0
# 4                            0.0                          4.0         4719.0
# 5                            0.0                          1.0         4924.0
# 6                            0.0                          3.0         6820.0
# 7                            1.0                          4.0         8407.0
# 8                            0.0                          7.0        13115.0
# 9                            0.0                          9.0        16375.0
# 10                           1.0                         10.0        18798.0
# 11                           2.0                         12.0        24999.0
# 12                           5.0                         14.0        35471.0
# 13                           5.0                         42.0        52344.0
# 14                           4.0                         58.0        81863.0
# 15                          15.0                         93.0       117847.0
# 16                          22.0                        130.0       197993.0
# 17                          37.0                        190.0       303375.0
# 18                          26.0                        248.0       388820.0
# 19                          17.0                        208.0       511559.0
# 20                          36.0                        220.0       503254.0
#
#     pct_parent_uninformative  pct_uninf_both_parents_het  \
# 0                  10.000000                    0.000000
# 1                   0.026205                    0.000000
# 2                   0.505849                    0.505849
# 3                   0.728332                    0.655499
# 4                   1.027685                    0.943792
# 5                   1.223671                    1.203611
# 6                   1.388086                    1.344708
# 7                   1.684014                    1.625541
# 8                   1.936593                    1.884253
# 9                   2.419403                    2.365771
# 10                  2.716969                    2.660042
# 11                  3.831506                    3.777650
# 12                  4.722125                    4.671090
# 13                  6.500188                    6.416233
# 14                  8.415282                    8.345919
# 15                  9.986175                    9.903682
# 16                 12.104679                   12.037201
# 17                 14.754287                   14.690502
# 18                 17.919727                   17.861885
# 19                 21.209643                   21.174988
# 20                 23.028074                   22.988919
#
#     pct_uninf_both_parents_missing  pct_uninf_one_missing_one_het  \
# 0                        10.000000                       0.000000
# 1                         0.026205                       0.000000
# 2                         0.000000                       0.000000
# 3                         0.036417                       0.036417
# 4                         0.000000                       0.083893
# 5                         0.000000                       0.020060
# 6                         0.000000                       0.043378
# 7                         0.011695                       0.046778
# 8                         0.000000                       0.052340
# 9                         0.000000                       0.053632
# 10                        0.005175                       0.051752
# 11                        0.007694                       0.046163
# 12                        0.013430                       0.037605
# 13                        0.008931                       0.075023
# 14                        0.004475                       0.064888
# 15                        0.011457                       0.071035
# 16                        0.009766                       0.057711
# 17                        0.010397                       0.053388
# 18                        0.005489                       0.052353
# 19                        0.002618                       0.032036
# 20                        0.005506                       0.033649
#
#     pct_informative  n_trios  n_variants_seen  \
# 0         90.000000      602            68904
# 1         99.973795      602            68904
# 2         99.494151      602            68904
# 3         99.271668      602            68904
# 4         98.972315      602            68904
# 5         98.776329      602            68904
# 6         98.611914      602            68904
# 7         98.315986      602            68904
# 8         98.063407      602            68904
# 9         97.580597      602            68904
# 10        97.283031      602            68904
# 11        96.168494      602            68904
# 12        95.277875      602            68904
# 13        93.499812      602            68904
# 14        91.584718      602            68904
# 15        90.013825      602            68904
# 16        87.895321      602            68904
# 17        85.245713      602            68904
# 18        82.080273      602            68904
# 19        78.790357      602            68904
# 20        76.971926      602            68904
#
#                                             panel_bcf
# 0   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 1   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 2   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 3   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 4   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 5   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 6   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 7   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 8   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 9   1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 10  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 11  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 12  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 13  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 14  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 15  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 16  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 17  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 18  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 19  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
# 20  1KGP.CHM13v2.0.PAR1.snp_indel.phasing_qual_pas...
