# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
import polars as pl
import seaborn as sns
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import importlib


pedigree_file_loc = 'resources/pedigrees/gatk_1kgp.ped'
summary_statistics_folder='intermediate_data_fullgenome'

if os.getcwd()!='phasing_T2T_project':
    os.chdir('..') # Change to the parent directory

# %%
import glob; glob.glob(f"{summary_statistics_folder}/*")
# Out:
# ['intermediate_data_fullgenome/rolling_stats_500k_window.parquet',
#  'intermediate_data_fullgenome/flips_and_switches.parquet',
#  'intermediate_data_fullgenome/samples.parquet',
#  'intermediate_data_fullgenome/compressed_ideogram_100000_window.parquet',
#  'intermediate_data_fullgenome/variants.parquet',
#  'intermediate_data_fullgenome/compressed_ideogram_1000000_window.parquet',
#  'intermediate_data_fullgenome/per_genome_cnv_regions_with_slop.parquet',
#  'intermediate_data_fullgenome/chroms.parquet',
#  'intermediate_data_fullgenome/variant_frequency_stats',
#  'intermediate_data_fullgenome/switch_errors.parquet',
#  'intermediate_data_fullgenome/MAF_performance_variants.parquet',
#  'intermediate_data_fullgenome/sample_genotype_concordance.parquet',
#  'intermediate_data_fullgenome/per_sample_imputation_performance.parquet',
#  'intermediate_data_fullgenome/rolling_stats_250k_window.parquet',
#  'intermediate_data_fullgenome/bcftools_query_variant_data.parquet',
#  'intermediate_data_fullgenome/per_genome_cnv_regions.parquet',
#  'intermediate_data_fullgenome/per_variant_category_imputation_performance.parquet',
#  'intermediate_data_fullgenome/per_MAF_bin.parquet',
#  'intermediate_data_fullgenome/methods.parquet',
#  'intermediate_data_fullgenome/filter_summary_stats.parquet',
#  'intermediate_data_fullgenome/frequency.parquet',
#  'intermediate_data_fullgenome/variants.nozeros.parquet',
#  'intermediate_data_fullgenome/ancestries.parquet',
#  'intermediate_data_fullgenome/block_length.parquet',
#  'intermediate_data_fullgenome/all_variant_data.parquet',
#  'intermediate_data_fullgenome/rolling_stats_1m_window.parquet',
#  'intermediate_data_fullgenome/binned_maf_data.parquet',
#  'intermediate_data_fullgenome/type.parquet',
#  'intermediate_data_fullgenome/per_cytoband_variant_data.parquet']

# %%
q = pd.read_parquet('intermediate_data/per_MAF_bin.parquet')
q = q[(q.rounded_MAF=='singleton')&(q.method_of_phasing=='phased_with_parents_and_pedigree')&(q.syntenic=='All')&(q.type=='SNPs + Indels')]
# q.type=='SNPs + Indels'
q
# Out:
#                type rounded_MAF     genome                 method_of_phasing  \
# 1105  SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 964   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 1058  SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 914   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 836   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 983   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
# 931   SNPs + Indels   singleton  CHM13v2.0  phased_with_parents_and_pedigree
#
#          ground_truth_data_source  n_switch_errors  n_checked  n_gt_errors  \
# 1105          HPRC_HGSVC_probands              4.0      109.0         3581
# 964                 HGSVC_samples            389.0     1505.0         3071
# 1058                 HPRC_samples              NaN        NaN         1046
# 914                HGSVC_probands              4.0      109.0         1607
# 836                 HGSVC_parents             20.0      274.0         1176
# 983        HPRC_HGSVC_all_samples            393.0     1506.0         9450
# 931   HGSVC_samples_nontrios_only            369.0     1123.0         2261
#
#       n_gt_checked   MAC        AN  switch_error_rate  gt_error_rate  \
# 1105         52836   777   4975908           3.669725       6.777576
# 964         142515  2312  14806048          25.847176       2.154861
# 1058         32658   851   5449804                NaN       3.202891
# 914          20646   666   4265064           3.669725       7.783590
# 836          10192   784   5020736           7.299270      11.538462
# 983         267100  2671  17105084          26.095618       3.538001
# 931          31863  1677  10739508          32.858415       7.096005
#
#            MAF syntenic
# 1105  0.015615      All
# 964   0.015615      All
# 1058  0.015615      All
# 914   0.015615      All
# 836   0.015615      All
# 983   0.015615      All
# 931   0.015615      All

# %%
MAF_performance_variant_df = pl.read_parquet(f'{summary_statistics_folder}/MAF_performance_variants.parquet')
all_chroms = pd.read_parquet(f'{summary_statistics_folder}/chroms.parquet')
all_samples = pd.read_parquet(f'{summary_statistics_folder}/samples.parquet')
all_ancestries = pd.read_parquet(f'{summary_statistics_folder}/ancestries.parquet')
all_methods = pd.read_parquet(f'{summary_statistics_folder}/methods.parquet')
all_variants = pl.read_parquet(f'{summary_statistics_folder}/variants.parquet')

per_variant_category_imputation_performance = pd.read_parquet(f'{summary_statistics_folder}/per_variant_category_imputation_performance.parquet')
per_sample_imputation_performance = pd.read_parquet(f'{summary_statistics_folder}/per_sample_imputation_performance.parquet')

# %% [markdown]
# ### Variant Filtering Stats
# Stats in paragraph after "Full length, telomere to telomere maps of human genetic recombination rates are largely consistent with deCODE recombination rates"

# %%
variant_filter_stats = pd.read_parquet(f"{summary_statistics_folder}/filter_summary_stats.parquet")
variant_filter_stats['gatk_filter'] = variant_filter_stats.VQSLOD_filter #| variant_filter_stats.neg_train_site_filter
chm13_variant_stats = variant_filter_stats.loc[(variant_filter_stats.genome=='CHM13v2.0')]
singletons = chm13_variant_stats.loc[chm13_variant_stats.singleton]
not_singletons = chm13_variant_stats.loc[~chm13_variant_stats.singleton]

num_affected_gatk = chm13_variant_stats.loc[~(chm13_variant_stats.GRCh38_criteria_fail) &
                                            # chm13_variant_stats.CHM13_criteria_fail &
                                            chm13_variant_stats.gatk_filter].len.sum()


singletons_gained = singletons.loc[chm13_variant_stats.GRCh38_criteria_fail & 
                                   ~(chm13_variant_stats.CHM13_criteria_fail | 
                                   variant_filter_stats.CHM13_filtered)].len.sum()
print(f"Our VQSLOD filter resulted in the loss of an additional \n\
{num_affected_gatk} \
variants compared to the NYGC’s GRCh38 1KGP variant filtering methods, but the inclusion of singleton alleles added \n\
{singletons_gained} \
unique variants to our dataset (Supplemental Figure 1).")
singletons
# Out:
# Our VQSLOD filter resulted in the loss of an additional
# 14494016 variants compared to the NYGC’s GRCh38 1KGP variant filtering methods, but the inclusion of singleton alleles added
# 26014731 unique variants to our dataset (Supplemental Figure 1).
#         genome  Syntenic  singleton  VQSLOD_filter  MERR_filter  \
# 4    CHM13v2.0      True       True          False        False
# 24   CHM13v2.0     False       True          False        False
# 33   CHM13v2.0     False       True          False        False
# 38   CHM13v2.0     False       True           True        False
# 40   CHM13v2.0     False       True           True        False
# 44   CHM13v2.0      True       True          False        False
# 46   CHM13v2.0     False       True          False        False
# 68   CHM13v2.0     False       True          False        False
# 69   CHM13v2.0     False       True           True        False
# 82   CHM13v2.0      True       True          False        False
# 87   CHM13v2.0      True       True          False        False
# 107  CHM13v2.0     False       True           True        False
# 127  CHM13v2.0      True       True           True        False
# 146  CHM13v2.0      True       True          False        False
# 148  CHM13v2.0      True       True           True         True
# 150  CHM13v2.0      True       True           True        False
# 154  CHM13v2.0      True       True           True        False
# 159  CHM13v2.0      True       True           True        False
# 169  CHM13v2.0     False       True          False        False
# 170  CHM13v2.0      True       True          False        False
# 180  CHM13v2.0      True       True          False        False
# 192  CHM13v2.0      True       True          False        False
# 206  CHM13v2.0      True       True           True        False
# 230  CHM13v2.0      True       True          False        False
# 234  CHM13v2.0     False       True           True        False
# 265  CHM13v2.0     False       True          False        False
# 267  CHM13v2.0      True       True          False        False
# 270  CHM13v2.0     False       True          False        False
# 271  CHM13v2.0     False       True           True        False
# 272  CHM13v2.0     False       True          False        False
# 274  CHM13v2.0     False       True          False        False
# 276  CHM13v2.0      True       True          False        False
# 295  CHM13v2.0      True       True          False        False
# 306  CHM13v2.0      True       True          False        False
# 313  CHM13v2.0      True       True           True        False
# 315  CHM13v2.0      True       True          False        False
# 320  CHM13v2.0      True       True           True        False
# 329  CHM13v2.0     False       True          False        False
# 330  CHM13v2.0      True       True           True        False
# 351  CHM13v2.0     False       True           True        False
# 353  CHM13v2.0      True       True          False        False
# 354  CHM13v2.0      True       True           True        False
# 365  CHM13v2.0      True       True          False        False
# 416  CHM13v2.0     False       True           True        False
# 446  CHM13v2.0     False       True          False        False
# 448  CHM13v2.0      True       True           True        False
# 454  CHM13v2.0      True       True           True        False
# 491  CHM13v2.0     False       True           True        False
# 500  CHM13v2.0      True       True          False        False
# 501  CHM13v2.0     False       True          False        False
# 502  CHM13v2.0     False       True          False        False
# 510  CHM13v2.0     False       True           True        False
# 511  CHM13v2.0      True       True           True        False
# 514  CHM13v2.0     False       True           True        False
# 531  CHM13v2.0      True       True           True        False
# 558  CHM13v2.0     False       True           True        False
#
#      HWE_pop_filter  MAC_filter  AC_filter  f_missing_filter  var_len_filter  \
# 4             False       False      False              True           False
# 24            False       False       True             False           False
# 33            False       False       True             False            True
# 38            False       False       True              True            True
# 40            False       False       True             False            True
# 44            False       False       True              True           False
# 46            False       False       True              True           False
# 68            False       False       True              True            True
# 69            False       False      False             False           False
# 82            False       False       True             False           False
# 87            False       False      False             False           False
# 107           False       False      False              True           False
# 127           False       False      False             False           False
# 146           False       False       True             False            True
# 148           False       False       True              True           False
# 150           False       False       True              True            True
# 154           False       False       True             False           False
# 159           False       False       True             False           False
# 169           False       False       True             False           False
# 170           False       False       True             False            True
# 180           False       False       True             False           False
# 192           False       False       True              True           False
# 206           False       False       True             False            True
# 230           False       False       True             False           False
# 234           False       False       True             False           False
# 265           False       False      False             False           False
# 267           False       False       True              True            True
# 270           False       False       True             False           False
# 271           False       False       True             False           False
# 272           False       False       True              True           False
# 274           False       False       True             False            True
# 276           False       False       True              True            True
# 295           False       False       True              True           False
# 306           False       False       True             False           False
# 313           False       False      False             False           False
# 315           False       False       True             False           False
# 320           False       False       True              True            True
# 329           False       False       True             False           False
# 330           False       False       True              True           False
# 351           False       False       True              True            True
# 353           False       False      False             False           False
# 354           False       False       True              True           False
# 365           False       False      False             False           False
# 416           False       False       True              True           False
# 446           False       False       True              True            True
# 448           False       False       True             False            True
# 454           False       False       True              True           False
# 491           False       False       True              True           False
# 500           False       False      False             False           False
# 501           False       False       True             False           False
# 502           False       False       True              True           False
# 510           False       False       True             False            True
# 511           False       False      False              True           False
# 514           False       False       True             False           False
# 531           False       False       True             False           False
# 558           False       False       True              True           False
#
#      alt_star_filter  pass_filter  CHM13_filtered  GRCh38_filtered  \
# 4              False        False            True             True
# 24             False        False           False            False
# 33             False        False            True             True
# 38              True        False            True             True
# 40              True        False            True             True
# 44             False        False            True            False
# 46              True        False            True             True
# 68             False        False            True             True
# 69             False        False            True             True
# 82             False        False            True             True
# 87              True        False            True             True
# 107            False        False            True             True
# 127             True        False            True             True
# 146             True        False            True             True
# 148             True        False            True             True
# 150            False        False            True             True
# 154            False        False            True             True
# 159            False        False            True            False
# 169            False        False            True             True
# 170            False        False            True             True
# 180             True        False            True             True
# 192            False        False            True             True
# 206             True        False            True             True
# 230            False        False           False            False
# 234            False        False            True             True
# 265            False        False           False             True
# 267             True        False            True             True
# 270            False        False            True            False
# 271            False        False            True            False
# 272            False        False            True            False
# 274             True        False            True             True
# 276            False        False            True             True
# 295             True        False            True             True
# 306            False        False           False             True
# 313            False        False            True             True
# 315            False        False            True            False
# 320             True        False            True             True
# 329             True        False            True             True
# 330             True        False            True             True
# 351            False        False            True             True
# 353            False        False           False            False
# 354            False        False            True            False
# 365            False        False           False             True
# 416             True        False            True             True
# 446             True        False            True             True
# 448            False        False            True             True
# 454            False        False            True             True
# 491            False        False            True            False
# 500            False        False            True             True
# 501            False        False           False             True
# 502            False        False            True             True
# 510            False        False            True             True
# 511            False        False            True             True
# 514             True        False            True             True
# 531             True        False            True             True
# 558            False        False            True             True
#
#      GRCh38_criteria_fail  CHM13_criteria_fail       len  gatk_filter
# 4                    True                 True         3        False
# 24                   True                False        25        False
# 33                   True                 True      1097        False
# 38                   True                 True      2418         True
# 40                   True                 True      2747         True
# 44                   True                 True        25        False
# 46                   True                 True      1245        False
# 68                   True                 True       354        False
# 69                  False                 True        11         True
# 82                   True                False  14164284        False
# 87                   True                 True         1        False
# 107                  True                 True         5         True
# 127                  True                 True        12         True
# 146                  True                 True      2318        False
# 148                  True                 True         2         True
# 150                  True                 True     18167         True
# 154                  True                 True   7810883         True
# 159                  True                 True      5441         True
# 169                  True                False     33052        False
# 170                  True                 True     14518        False
# 180                  True                 True    441729        False
# 192                  True                 True     31228        False
# 206                  True                 True      4862         True
# 230                  True                False     28083        False
# 234                  True                 True    589337         True
# 265                 False                False         3        False
# 267                  True                 True        44        False
# 270                  True                False        11        False
# 271                  True                 True       109         True
# 272                  True                 True         2        False
# 274                  True                 True       532        False
# 276                  True                 True      1360        False
# 295                  True                 True      1133        False
# 306                  True                False  25913141        False
# 313                 False                 True       533         True
# 315                  True                False     14545        False
# 320                  True                 True       535         True
# 329                  True                 True      6834        False
# 330                  True                 True     10378         True
# 351                  True                 True     11841         True
# 353                 False                False         1        False
# 354                  True                 True        90         True
# 365                 False                False      1058        False
# 416                  True                 True     47924         True
# 446                  True                 True       140        False
# 448                  True                 True     68335         True
# 454                  True                 True    209932         True
# 491                  True                 True        63         True
# 500                 False                False       489        False
# 501                  True                False     73482        False
# 502                  True                 True     15798        False
# 510                  True                 True     11239         True
# 511                  True                 True        16         True
# 514                  True                 True     52949         True
# 531                  True                 True    203660         True
# 558                  True                 True    429771         True

# %%
not_singletons.loc[(not_singletons.Syntenic)].groupby(['CHM13_filtered', 'CHM13_criteria_fail','gatk_filter']).len.sum()
# Out:
# CHM13_filtered  CHM13_criteria_fail  gatk_filter
# False           False                False          48948192
# True            False                False          11777087
#                 True                 False           2032062
#                                      True           17508360
# Name: len, dtype: uint64

# %%
variant_filter_stats.groupby(['genome','gatk_filter','GRCh38_criteria_fail'])['len'].sum().reset_index()
# Out:
# /tmp/ipykernel_2890186/2682831855.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   variant_filter_stats.groupby(['genome','gatk_filter','GRCh38_criteria_fail'])['len'].sum().reset_index()
#       genome  gatk_filter  GRCh38_criteria_fail       len
# 0     GRCh38        False                 False  61243112
# 1     GRCh38        False                  True  42784742
# 2     GRCh38         True                 False  13365695
# 3     GRCh38         True                  True  25729879
# 4  CHM13v2.0        False                 False  60934254
# 5  CHM13v2.0        False                  True  42867140
# 6  CHM13v2.0         True                 False  14494016
# 7  CHM13v2.0         True                  True  16177227

# %%
variant_filter_stats.loc[(~variant_filter_stats.CHM13_criteria_fail)&(variant_filter_stats.GRCh38_criteria_fail)].groupby(['GRCh38_criteria_fail','gatk_filter','genome','singleton'])['len'].sum().reset_index()
# Out:
# /tmp/ipykernel_2890186/1937395110.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   variant_filter_stats.loc[(~variant_filter_stats.CHM13_criteria_fail)&(variant_filter_stats.GRCh38_criteria_fail)].groupby(['GRCh38_criteria_fail','gatk_filter','genome','singleton'])['len'].sum().reset_index()
#    GRCh38_criteria_fail  gatk_filter     genome  singleton       len
# 0                  True        False     GRCh38       True  39599697
# 1                  True        False  CHM13v2.0       True  40226623

# %% [markdown]
# Table 1 and supplemental table XX

# %%
best_phased_variants = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree'))
catVarType = pl.Enum(['SNP','Indel','SNPs + Indels'])
best_phased_variants = best_phased_variants.with_columns(type=pl.col('type').cast(catVarType))
best_phased_variants = pl.concat([best_phased_variants, best_phased_variants.with_columns(type=pl.lit('SNPs + Indels').cast(catVarType))])
best_phased_variants_by_syntenic = best_phased_variants.group_by(['type','Syntenic','method_of_phasing','ground_truth_data_source','genome']
                                                                 ).sum(
                                                                 ).with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked')*100,
                                                                                switch_error_rate = pl.col('n_switch_errors')/pl.col('n_checked')*100
                                                                 ).to_pandas()
best_phased_variants_overall = best_phased_variants.group_by(['type','method_of_phasing','ground_truth_data_source','genome']
                                                                 ).sum(
                                                                 ).with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked')*100,
                                                                                switch_error_rate = pl.col('n_switch_errors')/pl.col('n_checked')*100
                                                                 ).to_pandas()

# %%
best_phased_variants_overall.sort_values(['ground_truth_data_source','genome','type'])
# Out:
#              type                 method_of_phasing  \
# 19            SNP  phased_with_parents_and_pedigree
# 3           Indel  phased_with_parents_and_pedigree
# 22  SNPs + Indels  phased_with_parents_and_pedigree
# 27            SNP  phased_with_parents_and_pedigree
# 36          Indel  phased_with_parents_and_pedigree
# 28  SNPs + Indels  phased_with_parents_and_pedigree
# 41            SNP  phased_with_parents_and_pedigree
# 18          Indel  phased_with_parents_and_pedigree
# 9   SNPs + Indels  phased_with_parents_and_pedigree
# 4             SNP  phased_with_parents_and_pedigree
# 31          Indel  phased_with_parents_and_pedigree
# 20  SNPs + Indels  phased_with_parents_and_pedigree
# 6             SNP  phased_with_parents_and_pedigree
# 39          Indel  phased_with_parents_and_pedigree
# 7   SNPs + Indels  phased_with_parents_and_pedigree
# 5             SNP  phased_with_parents_and_pedigree
# 35          Indel  phased_with_parents_and_pedigree
# 23  SNPs + Indels  phased_with_parents_and_pedigree
# 1             SNP  phased_with_parents_and_pedigree
# 14          Indel  phased_with_parents_and_pedigree
# 34  SNPs + Indels  phased_with_parents_and_pedigree
# 38            SNP  phased_with_parents_and_pedigree
# 15          Indel  phased_with_parents_and_pedigree
# 32  SNPs + Indels  phased_with_parents_and_pedigree
# 10            SNP  phased_with_parents_and_pedigree
# 37          Indel  phased_with_parents_and_pedigree
# 17  SNPs + Indels  phased_with_parents_and_pedigree
# 8             SNP  phased_with_parents_and_pedigree
# 2           Indel  phased_with_parents_and_pedigree
# 33  SNPs + Indels  phased_with_parents_and_pedigree
# 24            SNP  phased_with_parents_and_pedigree
# 40          Indel  phased_with_parents_and_pedigree
# 13  SNPs + Indels  phased_with_parents_and_pedigree
# 21            SNP  phased_with_parents_and_pedigree
# 29          Indel  phased_with_parents_and_pedigree
# 11  SNPs + Indels  phased_with_parents_and_pedigree
# 16            SNP  phased_with_parents_and_pedigree
# 12          Indel  phased_with_parents_and_pedigree
# 26  SNPs + Indels  phased_with_parents_and_pedigree
# 30            SNP  phased_with_parents_and_pedigree
# 25          Indel  phased_with_parents_and_pedigree
# 0   SNPs + Indels  phased_with_parents_and_pedigree
#
#        ground_truth_data_source     genome variant_id  n_switch_errors  \
# 19                 HPRC_samples     GRCh38       None           203833
# 3                  HPRC_samples     GRCh38       None           270831
# 22                 HPRC_samples     GRCh38       None           474664
# 27                 HPRC_samples  CHM13v2.0       None           125429
# 36                 HPRC_samples  CHM13v2.0       None           236515
# 28                 HPRC_samples  CHM13v2.0       None           361944
# 41                HGSVC_samples     GRCh38       None           754134
# 18                HGSVC_samples     GRCh38       None           645574
# 9                 HGSVC_samples     GRCh38       None          1399708
# 4                 HGSVC_samples  CHM13v2.0       None           485678
# 31                HGSVC_samples  CHM13v2.0       None           533760
# 20                HGSVC_samples  CHM13v2.0       None          1019438
# 6        HPRC_HGSVC_all_samples     GRCh38       None           957339
# 39       HPRC_HGSVC_all_samples     GRCh38       None           903281
# 7        HPRC_HGSVC_all_samples     GRCh38       None          1860620
# 5        HPRC_HGSVC_all_samples  CHM13v2.0       None           619740
# 35       HPRC_HGSVC_all_samples  CHM13v2.0       None           766099
# 23       HPRC_HGSVC_all_samples  CHM13v2.0       None          1385839
# 1           HPRC_HGSVC_probands     GRCh38       None           392141
# 14          HPRC_HGSVC_probands     GRCh38       None           530431
# 34          HPRC_HGSVC_probands     GRCh38       None           922572
# 38          HPRC_HGSVC_probands  CHM13v2.0       None           239782
# 15          HPRC_HGSVC_probands  CHM13v2.0       None           468515
# 32          HPRC_HGSVC_probands  CHM13v2.0       None           708297
# 10               HGSVC_probands     GRCh38       None           189404
# 37               HGSVC_probands     GRCh38       None           246392
# 17               HGSVC_probands     GRCh38       None           435796
# 8                HGSVC_probands  CHM13v2.0       None           111439
# 2                HGSVC_probands  CHM13v2.0       None           214074
# 33               HGSVC_probands  CHM13v2.0       None           325513
# 24                HGSVC_parents     GRCh38       None           142964
# 40                HGSVC_parents     GRCh38       None           132952
# 13                HGSVC_parents     GRCh38       None           275916
# 21                HGSVC_parents  CHM13v2.0       None            60029
# 29                HGSVC_parents  CHM13v2.0       None           110811
# 11                HGSVC_parents  CHM13v2.0       None           170840
# 16  HGSVC_samples_nontrios_only     GRCh38       None           423045
# 12  HGSVC_samples_nontrios_only     GRCh38       None           241792
# 26  HGSVC_samples_nontrios_only     GRCh38       None           664837
# 30  HGSVC_samples_nontrios_only  CHM13v2.0       None           320395
# 25  HGSVC_samples_nontrios_only  CHM13v2.0       None           188371
# 0   HGSVC_samples_nontrios_only  CHM13v2.0       None           508766
#
#     n_checked  n_gt_errors  n_gt_checked          MAC            AN  Syntenic  \
# 19   96830151      3025975     711358610  10944096358  116867178764  18221880
# 3    19555688      6481975     145991067   2456453580   23980917912   3740768
# 22  116385839      9507950     857349677  13400549938  140848096676  21962648
# 27   83970616      1581451     615986668   9469281970  101191249828  15792611
# 36   18027890      5285347     131789145   2235467907   21649362400   3376142
# 28  101998506      6866798     747775813  11704749877  122840612228  19168753
# 41  151010447      8002821    1262828279  10955497233  128888389728  20094909
# 18   29972914     13099186     257525124   2469918872   26283412072   4099769
# 9   180983361     21102007    1520353403  13425416105  155171801800  24194678
# 4   131554603      5512226    1118869739   9491939443  114194366900  17820975
# 31   27594727     10825486     232867189   2243090467   23766358296   3702815
# 20  159149330     16337712    1351736928  11735029910  137960725196  21523790
# 6   241013562     14721907    2350794845  10982317171  152594204608  23793129
# 39   47466990     21396841     445915360   2476326087   29056677080   4532480
# 7   288480552     36118748    2796710205  13458643258  181650881688  28325609
# 5   209878593     10533796    2082299645   9521752792  135196547464  21100865
# 35   43608428     17831326     402399835   2245832839   26229554432   4089910
# 23  253487021     28365122    2484699480  11767585631  161426101896  25190775
# 1   164491634      7523433    1396660154  10907986574  133179742148  20766556
# 14   32349730     13448642     275069141   2433600414   26313991172   4105018
# 34  196841364     20972075    1671729295  13341586988  159493733320  24871574
# 38  142966973      4885380    1206225547   9459032010  115063447336  17958339
# 15   29686314     11141390     247071200   2206659927   23644887224   3687219
# 32  172653287     16026770    1453296747  11665691937  138708334560  21645558
# 10   73719637      3536488     478222804  10701095005   99849848776  15569973
# 37   14535103      5879840     103388337   2360505655   21645936260   3377159
# 17   88254740      9416328     581611141  13061600660  121495785036  18947132
# 8    64083157      2443173     413454077   9283079788   86358522764  13478025
# 2    13331480      4837731      92803375   2140405049   19439463676   3031931
# 33   77414637      7280904     506257452  11423484837  105797986440  16509956
# 24   33168366      1101386     155285503  10306271778   77507554364  12085944
# 40    6628759      2189651      34800663   2238640700   17421422388   2718117
# 13   39797125      3291037     190086166  12544912478   94928976752  14804061
# 21   28907987       687896     135397717   8941645479   67615026596  10552603
# 29    6100767      1824830      31395703   2031937895   15729447164   2453315
# 11   35008754      2512726     166793420  10973583374   83344473760  13005918
# 16   43341629      2699076     233348273  10442767236   79816247596  12446981
# 12    8580217      3510984      53180074   2283546245   18263529176   2849598
# 26   51921846      6210060     286528347  12726313481   98079776772  15296579
# 30   37994100      2097605     207776731   9060713235   71102619380  11097182
# 25    7907309      2866376      47918554   2070335651   16469973704   2569134
# 0    45901409      4963981     255695285  11131048886   87572593084  13666316
#
#     multiallelic  in_STRs  in_segdups  in_platinum_STRs          MAF  \
# 19       1265576   766061      729897           1743056  163978912.0
# 3        2691149   755934      125781           2640091   38157448.0
# 22       3956725  1521995      855678           4383147  199150912.0
# 27        987434   517335      278683           1313540  142845632.0
# 36       2364140   779837      113103           2303815   34772896.0
# 28       3351574  1297172      391786           3617355  174973280.0
# 41       1367442   838425      803320           1895313  163417504.0
# 18       2940460   813114      138324           2887930   38311516.0
# 9        4307902  1651539      941644           4783243  198561632.0
# 4        1097102   587425      302935           1471419  142577184.0
# 31       2583571   833259      123069           2518845   34848980.0
# 20       3680673  1420684      426004           3990264  174604576.0
# 6        1568185   958358      920122           2213064  162859712.0
# 39       3185320   886608      150987           3129710   38340076.0
# 7        4753505  1844966     1071109           5342774  197901856.0
# 5        1266753   672813      341500           1726315  142198736.0
# 35       2798030   893192      131438           2729404   34835496.0
# 23       4064783  1566005      472938           4455719  174114928.0
# 1        1386360   839847      805160           1939416  162603296.0
# 14       2919010   811535      135286           2866535   37747428.0
# 34       4305370  1651382      940446           4805951  197185104.0
# 38       1097397   576521      292548           1475703  141984288.0
# 15       2553224   824407      116962           2491677   34286452.0
# 32       3650621  1400928      409510           3967380  173475584.0
# 10       1075135   639116      607418           1470196  161630560.0
# 37       2470508   678159      109993           2422863   36720604.0
# 17       3545643  1317275      717411           3893059  195674480.0
# 8         850471   438828      221570           1117010  141086784.0
# 2        2155489   699440       94593           2102793   33334632.0
# 33       3005960  1138268      316163           3219803  172083120.0
# 24        856704   500251      472025           1148979  157311664.0
# 40       2005144   562272       87418           1962357   34890920.0
# 13       2861848  1062523      559443           3111336  190270688.0
# 21        682129   346061      174238            878947  137145680.0
# 29       1755681   586063       75477           1709678   31681192.0
# 11       2437810   932124      249715           2588625  167135872.0
# 16        883777   514418      483147           1184948  159613792.0
# 12       2120649   583367       91449           2076316   35577040.0
# 26       3004426  1097785      574596           3261264  193158208.0
# 30        713470   361885      180836            923329  139174608.0
# 25       1853408   607640       78461           1805361   32271340.0
# 0        2566878   969525      259297           2728690  169718640.0
#
#    rounded_MAF  gt_error_rate  switch_error_rate
# 19         NaN       0.425380           0.210506
# 3          NaN       4.439981           1.384922
# 22         NaN       1.108993           0.407837
# 27         NaN       0.256735           0.149372
# 36         NaN       4.010457           1.311939
# 28         NaN       0.918296           0.354852
# 41         NaN       0.633722           0.499392
# 18         NaN       5.086566           2.153858
# 9          NaN       1.387967           0.773390
# 4          NaN       0.492660           0.369184
# 31         NaN       4.648781           1.934283
# 20         NaN       1.208646           0.640554
# 6          NaN       0.626252           0.397214
# 39         NaN       4.798409           1.902967
# 7          NaN       1.291473           0.644972
# 5          NaN       0.505873           0.295285
# 35         NaN       4.431246           1.756768
# 23         NaN       1.141592           0.546710
# 1          NaN       0.538673           0.238396
# 14         NaN       4.889186           1.639677
# 34         NaN       1.254514           0.468688
# 38         NaN       0.405014           0.167718
# 15         NaN       4.509384           1.578219
# 32         NaN       1.102787           0.410242
# 10         NaN       0.739506           0.256925
# 37         NaN       5.687141           1.695151
# 17         NaN       1.619008           0.493793
# 8          NaN       0.590918           0.173897
# 2          NaN       5.212883           1.605778
# 33         NaN       1.438182           0.420480
# 24         NaN       0.709265           0.431025
# 40         NaN       6.291981           2.005685
# 13         NaN       1.731340           0.693306
# 21         NaN       0.508056           0.207655
# 29         NaN       5.812356           1.816345
# 11         NaN       1.506490           0.487992
# 16         NaN       1.156673           0.976071
# 12         NaN       6.602067           2.818017
# 26         NaN       2.167346           1.280457
# 30         NaN       1.009548           0.843276
# 25         NaN       5.981766           2.382239
# 0          NaN       1.941366           1.108389

# %%
best_phased_variants_by_syntenic.loc[best_phased_variants_by_syntenic.ground_truth_data_source=='HPRC_samples'].sort_values(['ground_truth_data_source','Syntenic','genome','type'])
# Out:
#              type  Syntenic                 method_of_phasing  \
# 3             SNP     False  phased_with_parents_and_pedigree
# 58          Indel     False  phased_with_parents_and_pedigree
# 42  SNPs + Indels     False  phased_with_parents_and_pedigree
# 41            SNP     False  phased_with_parents_and_pedigree
# 80          Indel     False  phased_with_parents_and_pedigree
# 76  SNPs + Indels     False  phased_with_parents_and_pedigree
# 43            SNP      True  phased_with_parents_and_pedigree
# 68          Indel      True  phased_with_parents_and_pedigree
# 33  SNPs + Indels      True  phased_with_parents_and_pedigree
# 63            SNP      True  phased_with_parents_and_pedigree
# 52          Indel      True  phased_with_parents_and_pedigree
# 38  SNPs + Indels      True  phased_with_parents_and_pedigree
#
#    ground_truth_data_source     genome variant_id  n_switch_errors  n_checked  \
# 3              HPRC_samples     GRCh38       None              450     122930
# 58             HPRC_samples     GRCh38       None              174      15490
# 42             HPRC_samples     GRCh38       None              624     138420
# 41             HPRC_samples  CHM13v2.0       None              133      26737
# 80             HPRC_samples  CHM13v2.0       None              410      15019
# 76             HPRC_samples  CHM13v2.0       None              543      41756
# 43             HPRC_samples     GRCh38       None           203383   96707221
# 68             HPRC_samples     GRCh38       None           270657   19540198
# 33             HPRC_samples     GRCh38       None           474040  116247419
# 63             HPRC_samples  CHM13v2.0       None           125296   83943879
# 52             HPRC_samples  CHM13v2.0       None           236105   18012871
# 38             HPRC_samples  CHM13v2.0       None           361401  101956750
#
#     n_gt_errors  n_gt_checked          MAC            AN  multiallelic  \
# 3         25015       1054999     14013151     174259244          3736
# 58        10527        152017      2255971      25039640          2623
# 42        35542       1207016     16269122     199298884          6359
# 41        15469        336505      3625205      55368984          1475
# 80        16586        173023      2662187      28549032          3520
# 76        32055        509528      6287392      83918016          4995
# 43      3000960     710303611  10930083207  116692919520       1261840
# 68      6471448     145839050   2454197609   23955878272       2688526
# 33      9472408     856142661  13384280816  140648797792       3950366
# 63      1565982     615650163   9465656765  101135880844        985959
# 52      5268761     131616122   2232805720   21620813368       2360620
# 38      6834743     747266285  11698462485  122756694212       3346579
#
#     in_STRs  in_segdups  in_platinum_STRs           MAF rounded_MAF  \
# 3     16442         983              2220  2.188301e+05         NaN
# 58     1673         191              1852  3.522783e+04         NaN
# 42    18115        1174              4072  2.540636e+05         NaN
# 41     3542        2255               849  5.660954e+04         NaN
# 80     3259        1868              1150  4.157111e+04         NaN
# 76     6801        4123              1999  9.818216e+04         NaN
# 43   749619      728914           1740836  1.637886e+08         NaN
# 68   754261      125590           2638239  3.812274e+07         NaN
# 33  1503880      854504           4379075  1.989228e+08         NaN
# 63   513793      276428           1312691  1.427933e+08         NaN
# 52   776578      111235           2302665  3.473216e+07         NaN
# 38  1290371      387663           3615356  1.748844e+08         NaN
#
#     gt_error_rate  switch_error_rate
# 3        2.371092           0.366062
# 58       6.924883           1.123305
# 42       2.944617           0.450802
# 41       4.596960           0.497438
# 80       9.586009           2.729875
# 76       6.291116           1.300412
# 43       0.422490           0.210308
# 68       4.437390           1.385129
# 33       1.106405           0.407785
# 63       0.254362           0.149262
# 52       4.003127           1.310757
# 38       0.914633           0.354465

# %% [markdown]
# ### Percent concordance in different panels

# %%
overall_subsetted = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree')).group_by(['type','Syntenic','method_of_phasing','ground_truth_data_source','genome']).sum().with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked'))
overall           = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree')).group_by(['method_of_phasing','ground_truth_data_source','genome']).sum().with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked'))
overall_syntenic  = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('Syntenic'))&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree')).group_by(['method_of_phasing','ground_truth_data_source','genome']).sum().with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked'))

# %%
overall_syntenic = overall_syntenic.to_pandas()[['Syntenic','genome','ground_truth_data_source','gt_error_rate']].sort_values(['genome','Syntenic','gt_error_rate'])
overall_syntenic['Non-reference true positive rate'] = (1-overall_syntenic.gt_error_rate) * 100
overall_syntenic['gt_error_rate'] *= 100
overall_syntenic.loc[overall_syntenic.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples','HPRC_HGSVC_all_samples'))]
# Out:
#     Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 2   21962648     GRCh38             HPRC_samples       1.106405
# 4   24194678     GRCh38            HGSVC_samples       1.386977
# 0   28325609     GRCh38   HPRC_HGSVC_all_samples       1.289689
# 12  19168753  CHM13v2.0             HPRC_samples       0.914633
# 11  21523790  CHM13v2.0            HGSVC_samples       1.203934
# 13  25190775  CHM13v2.0   HPRC_HGSVC_all_samples       1.138373
#
#     Non-reference true positive rate
# 2                          98.893595
# 4                          98.613023
# 0                          98.710311
# 12                         99.085367
# 11                         98.796066
# 13                         98.861627

# %%
overall = overall.to_pandas()[['Syntenic','genome','ground_truth_data_source','gt_error_rate']].sort_values(['genome','Syntenic','gt_error_rate'])
overall['Non-reference true positive rate'] = (1-overall.gt_error_rate) * 100
overall['gt_error_rate'] *= 100
overall.loc[overall.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples','HPRC_HGSVC_all_samples'))]
# Out:
#     Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 11  21962648     GRCh38             HPRC_samples       1.108993
# 2   24194678     GRCh38            HGSVC_samples       1.387967
# 5   28325609     GRCh38   HPRC_HGSVC_all_samples       1.291473
# 6   19168753  CHM13v2.0             HPRC_samples       0.918296
# 10  21523790  CHM13v2.0            HGSVC_samples       1.208646
# 4   25190775  CHM13v2.0   HPRC_HGSVC_all_samples       1.141592
#
#     Non-reference true positive rate
# 11                         98.891007
# 2                          98.612033
# 5                          98.708527
# 6                          99.081704
# 10                         98.791354
# 4                          98.858408

# %%
overall_subsetted = overall_subsetted.to_pandas()[['type','Syntenic','genome','ground_truth_data_source','gt_error_rate']].sort_values(['genome','type','Syntenic','gt_error_rate'])
overall_subsetted['Non-reference true positive rate'] = (1-overall_subsetted.gt_error_rate) * 100
overall_subsetted['gt_error_rate'] *= 100
overall_subsetted.loc[overall_subsetted.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples','HPRC_HGSVC_all_samples'))]
# Out:
#      type  Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 38    SNP     False     GRCh38            HGSVC_samples       1.442616
# 44    SNP     False     GRCh38   HPRC_HGSVC_all_samples       2.010190
# 16    SNP     False     GRCh38             HPRC_samples       2.371092
# 18    SNP      True     GRCh38             HPRC_samples       0.422490
# 6     SNP      True     GRCh38   HPRC_HGSVC_all_samples       0.624200
# 36    SNP      True     GRCh38            HGSVC_samples       0.632463
# 51  Indel     False     GRCh38            HGSVC_samples       6.394128
# 3   Indel     False     GRCh38   HPRC_HGSVC_all_samples       6.490134
# 9   Indel     False     GRCh38             HPRC_samples       6.924883
# 53  Indel      True     GRCh38             HPRC_samples       4.437390
# 49  Indel      True     GRCh38   HPRC_HGSVC_all_samples       4.796596
# 25  Indel      True     GRCh38            HGSVC_samples       5.085148
# 11    SNP     False  CHM13v2.0   HPRC_HGSVC_all_samples       4.181155
# 43    SNP     False  CHM13v2.0            HGSVC_samples       4.204832
# 31    SNP     False  CHM13v2.0             HPRC_samples       4.596960
# 12    SNP      True  CHM13v2.0             HPRC_samples       0.254362
# 26    SNP      True  CHM13v2.0            HGSVC_samples       0.490435
# 5     SNP      True  CHM13v2.0   HPRC_HGSVC_all_samples       0.504153
# 20  Indel     False  CHM13v2.0             HPRC_samples       9.586009
# 22  Indel     False  CHM13v2.0            HGSVC_samples       9.598220
# 45  Indel     False  CHM13v2.0   HPRC_HGSVC_all_samples       9.751645
# 15  Indel      True  CHM13v2.0             HPRC_samples       4.003127
# 2   Indel      True  CHM13v2.0   HPRC_HGSVC_all_samples       4.423507
# 55  Indel      True  CHM13v2.0            HGSVC_samples       4.637721
#
#     Non-reference true positive rate
# 38                         98.557384
# 44                         97.989810
# 16                         97.628908
# 18                         99.577510
# 6                          99.375800
# 36                         99.367537
# 51                         93.605872
# 3                          93.509866
# 9                          93.075117
# 53                         95.562610
# 49                         95.203404
# 25                         94.914852
# 11                         95.818845
# 43                         95.795168
# 31                         95.403040
# 12                         99.745638
# 26                         99.509565
# 5                          99.495847
# 20                         90.413991
# 22                         90.401780
# 45                         90.248355
# 15                         95.996873
# 2                          95.576493
# 55                         95.362279

# %%
rephase=all_variants.filter((pl.col('method_of_phasing') == '1kgp_variation_phased_with_reference_panel') & 
                         (pl.col('ground_truth_data_source') == 'HPRC_samples'))

singletons_rephase_sum = rephase.filter(pl.col('contextual_MAC') == 1).group_by('genome').sum().to_pandas().reset_index()
singletons_rephase_sum['SER'] = singletons_rephase_sum.n_switch_errors/singletons_rephase_sum.n_checked*100
for idx, (genome, ser) in singletons_rephase_sum[['genome','SER']].iterrows():
    print(f'Singletons in {genome}: {ser}')

rare_rephase = rephase.filter(pl.col('contextual_MAC')/pl.col('contextual_AN') < 0.01)
common_rephase = rephase.filter(pl.col('contextual_MAC')/pl.col('contextual_AN') >= 0.01)

rare_rephase_sum = rare_rephase.group_by('genome').sum().to_pandas().reset_index()
common_rephase_sum = common_rephase.group_by('genome').sum().to_pandas().reset_index()
for idx, (genome, n_switch_errors, n_checked) in rare_rephase_sum[['genome','n_switch_errors', 'n_checked']].iterrows():
    print (f"\nRare in {genome}: {n_switch_errors/n_checked*100}")
    print (f"Common in {genome}: {common_rephase_sum.iloc[idx].n_switch_errors/common_rephase_sum.iloc[idx].n_checked*100}")
syntenic = common_rephase.filter(pl.col('Syntenic') == True)
nonsyntenic = common_rephase.filter(pl.col('Syntenic') == False)

syntenic_sum = syntenic.group_by('genome').sum().to_pandas().set_index('genome')
nonsyntenic_sum = nonsyntenic.group_by('genome').sum().to_pandas().set_index('genome')

for genome, row in syntenic_sum.iterrows():
    print (f"\nCommon Syntenic in {genome}: {row.n_switch_errors/row.n_checked*100}")
    print (f"Common Nonsyntenic {genome}: {nonsyntenic_sum.loc[genome].n_switch_errors/nonsyntenic_sum.loc[genome].n_checked*100}")
# Out:
# Singletons in CHM13v2.0: 8.27393547908082
# Singletons in GRCh38: 11.690793831015235
#
# Rare in GRCh38: 6.616868852558108
# Common in GRCh38: 0.9045780019233195
#
# Rare in CHM13v2.0: 6.225743033345612
# Common in CHM13v2.0: 0.8103833501207229
#
# Common Syntenic in CHM13v2.0: 0.8099508170456401
# Common Nonsyntenic CHM13v2.0: 1.8914473684210527
#
# Common Syntenic in GRCh38: 0.9045591759081486
# Common Nonsyntenic GRCh38: 0.9198633549213578

# %%
synEnum = pl.Enum(categories=['All_regions', 'Syntenic', 'Nonsyntenic'])
concordance = all_variants.filter((pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
                                  (pl.col('ground_truth_data_source') == 'HPRC_samples')).with_columns(Syntenic=pl.col('Syntenic').cast(str).replace('true','Syntenic').replace('false','Nonsyntenic').cast(synEnum))

# %%
concordance_summary = concordance.clone().with_columns(Syntenic = pl.lit('All_regions').cast(synEnum))
concordance_summary = pl.concat((concordance, concordance_summary)).group_by(['Syntenic','genome','type']).sum().to_pandas().reset_index()
concordance_summary = pd.concat((concordance_summary, concordance_summary.copy().assign(type = 'SNPs + Indels').groupby(['Syntenic','genome','type'], observed=True).sum(numeric_only=True).reset_index()))
concordance_summary['gt_error_rate'] = concordance_summary.n_gt_errors/concordance_summary.n_gt_checked*100
concordance_summary['gt_accuracy_rate'] = 100-concordance_summary['gt_error_rate'] 
concordance_summary['switch_error_rate'] = concordance_summary.n_switch_errors/concordance_summary.n_checked*100
concordance_summary['Syntenic'] = concordance_summary.Syntenic.replace('false', 'Nonsyntenic').replace('true','Syntenic')

# %%
pd.set_option("display.precision", 3)
concordance_summary.sort_values(['Syntenic','genome','type']).set_index(['Syntenic','genome','type'])[['switch_error_rate','gt_error_rate','n_gt_errors','n_gt_checked', 'n_switch_errors', 'n_checked']].astype(float)
# Out:
#                                      switch_error_rate  gt_error_rate  \
# Syntenic    genome    type
# All_regions GRCh38    Indel                      1.385          4.440
#                       SNP                        0.211          0.425
#                       SNPs + Indels              0.408          1.109
#             CHM13v2.0 Indel                      1.312          4.010
#                       SNP                        0.149          0.257
#                       SNPs + Indels              0.355          0.918
# Syntenic    GRCh38    Indel                      1.385          4.437
#                       SNP                        0.210          0.422
#                       SNPs + Indels              0.408          1.106
#             CHM13v2.0 Indel                      1.311          4.003
#                       SNP                        0.149          0.254
#                       SNPs + Indels              0.354          0.915
# Nonsyntenic GRCh38    Indel                      1.123          6.925
#                       SNP                        0.366          2.371
#                       SNPs + Indels              0.451          2.945
#             CHM13v2.0 Indel                      2.730          9.586
#                       SNP                        0.497          4.597
#                       SNPs + Indels              1.300          6.291
#
#                                      n_gt_errors  n_gt_checked  \
# Syntenic    genome    type
# All_regions GRCh38    Indel            6.482e+06     1.460e+08
#                       SNP              3.026e+06     7.114e+08
#                       SNPs + Indels    9.508e+06     8.573e+08
#             CHM13v2.0 Indel            5.285e+06     1.318e+08
#                       SNP              1.581e+06     6.160e+08
#                       SNPs + Indels    6.867e+06     7.478e+08
# Syntenic    GRCh38    Indel            6.471e+06     1.458e+08
#                       SNP              3.001e+06     7.103e+08
#                       SNPs + Indels    9.472e+06     8.561e+08
#             CHM13v2.0 Indel            5.269e+06     1.316e+08
#                       SNP              1.566e+06     6.157e+08
#                       SNPs + Indels    6.835e+06     7.473e+08
# Nonsyntenic GRCh38    Indel            1.053e+04     1.520e+05
#                       SNP              2.502e+04     1.055e+06
#                       SNPs + Indels    3.554e+04     1.207e+06
#             CHM13v2.0 Indel            1.659e+04     1.730e+05
#                       SNP              1.547e+04     3.365e+05
#                       SNPs + Indels    3.206e+04     5.095e+05
#
#                                      n_switch_errors  n_checked
# Syntenic    genome    type
# All_regions GRCh38    Indel                 270831.0  1.956e+07
#                       SNP                   203833.0  9.683e+07
#                       SNPs + Indels         474664.0  1.164e+08
#             CHM13v2.0 Indel                 236515.0  1.803e+07
#                       SNP                   125429.0  8.397e+07
#                       SNPs + Indels         361944.0  1.020e+08
# Syntenic    GRCh38    Indel                 270657.0  1.954e+07
#                       SNP                   203383.0  9.671e+07
#                       SNPs + Indels         474040.0  1.162e+08
#             CHM13v2.0 Indel                 236105.0  1.801e+07
#                       SNP                   125296.0  8.394e+07
#                       SNPs + Indels         361401.0  1.020e+08
# Nonsyntenic GRCh38    Indel                    174.0  1.549e+04
#                       SNP                      450.0  1.229e+05
#                       SNPs + Indels            624.0  1.384e+05
#             CHM13v2.0 Indel                    410.0  1.502e+04
#                       SNP                      133.0  2.674e+04
#                       SNPs + Indels            543.0  4.176e+04
