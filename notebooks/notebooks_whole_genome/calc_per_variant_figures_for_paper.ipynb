# %% [markdown]
# # Paper inline statistics (per-variant source notebook)
#
# This notebook computes **per-variant and filter-derived statistics used directly in manuscript text and tables**.
# Each section prints plug-and-play f-string sentences that use the exact manuscript sentence structure with
# computed values inserted. These sentences are the primary deliverable -- copy-paste them into the paper and
# use the surrounding context to ctrl-F to the correct section.
#
# ## Paper source of truth
# The manuscript PDFs in `papers/` are the source of truth for organization and published figure numbering.
# See `notebooks/notebooks_whole_genome/PAPER_CROSS_REFERENCE.md` for the full figure/data-point map.
#
# ## Execution order
# 1. Run the whole-genome summary dataframe creation pipeline.
# 2. Run this notebook first (heavy per-variant calculations).
# 3. Run `notebooks/notebooks_whole_genome/make_plots.ipynb`.
# 4. Run `notebooks/notebooks_whole_genome/calc_figures_for_paper.ipynb` (summary fast-path and consolidated exports).
#
# ## Data paths
# Set `RUN_PROFILE` in the first code cell. `test` uses plain folders (`intermediate_data`, `tables`);
# `whole_genome` uses `_whole_genome` folders for publication-scale inputs and outputs.
#
# ## Organization
# Production manuscript statistics are organized first. Exploratory checks are at the end under a dedicated heading.
# The central statistics reference TSV is exported to `tables/paper_per_variant_inline_statistics_reference.tsv`.

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype
import polars as pl

from utilities import find_repo_root, require_files

# Choose "test" for Docker smoke/test data or "whole_genome" for publication-scale data.
# The environment variable is useful for automated runs; manually edit RUN_PROFILE for interactive use.
RUN_PROFILE = "whole_genome"
RUN_PROFILE = os.environ.get("PHASING_T2T_RUN_PROFILE", RUN_PROFILE)

PROFILE_PATHS = {
    "test": {
        "intermediate_data": "intermediate_data",
        "imputation_statistics": "imputation_statistics",
        "figures": "figures",
        "tables": "tables",
    },
    "whole_genome": {
        "intermediate_data": "intermediate_data_whole_genome",
        "imputation_statistics": "imputation_statistics_whole_genome",
        "figures": "figures_whole_genome",
        "tables": "tables_whole_genome",
    },
}

if RUN_PROFILE not in PROFILE_PATHS:
    raise ValueError(f"RUN_PROFILE must be one of {sorted(PROFILE_PATHS)}, got {RUN_PROFILE!r}")

profile_paths = PROFILE_PATHS[RUN_PROFILE]

repo_root = find_repo_root()
os.chdir(repo_root)

summary_statistics_folder = profile_paths["intermediate_data"]
tables_folder = profile_paths["tables"]

required_summary_files = (
    "MAF_performance_variants.parquet",
    "samples.parquet",
    "variants.parquet",
)

summary_statistics_folder = require_files(
    profile_paths["intermediate_data"],
    required_summary_files,
    "per-variant summary data",
    RUN_PROFILE,
)

Path(tables_folder).mkdir(parents=True, exist_ok=True)

print(f"RUN_PROFILE: {RUN_PROFILE}")
print(f"Working directory: {repo_root}")
print(f"Summary statistics folder: {summary_statistics_folder}")
print(f"Tables folder: {tables_folder}")
# Out:
# Checking for required files in intermediate_data_whole_genome
# intermediate_data_whole_genome/MAF_performance_variants.parquet
# RUN_PROFILE: whole_genome
# Working directory: /mnt/ssd/lalli/test_dir2/phasing_T2T
# Summary statistics folder: intermediate_data_whole_genome
# Tables folder: tables_whole_genome

# %% [markdown]
# ## 1) Load data

# %%
MAF_performance_variant_df = pl.read_parquet(f'{summary_statistics_folder}/MAF_performance_variants.parquet')
all_samples = pd.read_parquet(f'{summary_statistics_folder}/samples.parquet')
all_variants = pl.read_parquet(f'{summary_statistics_folder}/variants.parquet')

# %% [markdown]
# ## 2) Variant filtering statistics
#
# Reconstructs CHM13 variant filter flags from bcftools query data to compute the proportion
# of variants removed by each filter criterion in T2T-CHM13-unique regions.

# %%
# Build CHM13 variant ID set for filter reconstruction
chm13_ids = pl.scan_parquet(f"{summary_statistics_folder}/MAF_performance_variants.parquet") \
    .select(['variant_id','genome']) \
    .filter(pl.col('genome')=='CHM13v2.0') \
    .select('variant_id') \
    .unique() \
    .collect() \
    .to_series()
chm13_ids = set(chm13_ids)

# Load bcftools query data and compute filter flags
variant_filter_stats = (
    pl.scan_parquet(f"{summary_statistics_folder}/bcftools_query_variant_data.parquet")
    .with_columns(
        MAC_original=pl.min_horizontal(
            pl.col('AN_original_panel') - pl.col('AC_original_panel'),
            pl.col('AC_original_panel'),
        )
    )
    .filter(pl.col('genome') == 'CHM13v2.0')
    .with_columns(
        VQSLOD_filter=(pl.col('VQSLOD') < 0),
        MERR_filter=~(pl.col('MERR') > (602 * 0.05)),
        in_panel=pl.col('ID').is_in(chm13_ids),
        HWE_pop_filter=(
            (pl.col('HWE_EUR') < 1e-10) & (pl.col('HWE_AFR') < 1e-10) &
            (pl.col('HWE_EAS') < 1e-10) & (pl.col('HWE_AMR') < 1e-10) &
            (pl.col('HWE_SAS') < 1e-10)
        ).cast(pl.Boolean),
        MAC_filter=(pl.col('MAC_original') == 0).cast(pl.Boolean),
        AC_filter=(pl.col('AC_original_panel') <= 1),
        f_missing_filter=(pl.col('F_MISSING') > 0.05).cast(pl.Boolean),
        var_len_filter=(
            (pl.col('ID').str.split('_').list[2].str.len_chars().cast(pl.Int64)
             - pl.col('ID').str.split('_').list[3].str.len_chars().cast(pl.Int64)
            ).abs() >= 50 - 1  # minus 1 because bcftools ILEN does not count the anchor base
        ).cast(pl.Boolean),
        alt_star_filter=(pl.col('ALT') == '*').cast(pl.Boolean),
        singleton=(pl.col('MAC_original') == 1).cast(pl.Boolean),
        pass_filter=(pl.col('FILTER') != 'PASS').cast(pl.Boolean),
    )
    .collect()
)

variant_filter_stats = variant_filter_stats.with_columns(
    CHM13_criteria_fail=(
        pl.col('MAC_filter') | pl.col('VQSLOD_filter') |
        pl.col('f_missing_filter') | pl.col('pass_filter') |
        pl.col('HWE_pop_filter') | pl.col('MERR_filter') |
        pl.col('var_len_filter') | pl.col('alt_star_filter')
    ).cast(pl.Boolean)
)

# %% [markdown]
# ## 3) Table 1: Genotype concordance
#
# Computes genotype discordance/concordance and switch error summaries by variant class
# (SNP, Indel, combined), genome (GRCh38 vs CHM13v2.0), syntenic/non-syntenic regions,
# and ground truth source (HPRC/HGSVC/combined).

# %%
best_phased_variants = MAF_performance_variant_df.filter(
    (pl.col('ground_truth_data_source') != 'trios') &
    (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree')
)
catVarType = pl.Enum(['SNP', 'Indel', 'SNPs + Indels'])
best_phased_variants = best_phased_variants.with_columns(type=pl.col('type').cast(catVarType))
best_phased_variants = pl.concat([
    best_phased_variants,
    best_phased_variants.with_columns(type=pl.lit('SNPs + Indels').cast(catVarType)),
])

best_phased_variants_by_syntenic = (
    best_phased_variants
    .group_by(['type', 'Syntenic', 'method_of_phasing', 'ground_truth_data_source', 'genome'])
    .sum()
    .with_columns(
        gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked') * 100,
        switch_error_rate=pl.col('n_switch_errors') / pl.col('n_checked') * 100,
    )
    .to_pandas()
)

best_phased_variants_overall = (
    best_phased_variants
    .group_by(['type', 'method_of_phasing', 'ground_truth_data_source', 'genome'])
    .sum()
    .with_columns(
        gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked') * 100,
        switch_error_rate=pl.col('n_switch_errors') / pl.col('n_checked') * 100,
    )
    .to_pandas()
)

best_phased_variants_overall.sort_values(['ground_truth_data_source', 'genome', 'type'])
# Out:
#              type                 method_of_phasing  \
# 8             SNP  phased_with_parents_and_pedigree
# 15          Indel  phased_with_parents_and_pedigree
# 5   SNPs + Indels  phased_with_parents_and_pedigree
# 2             SNP  phased_with_parents_and_pedigree
# 26          Indel  phased_with_parents_and_pedigree
# 1   SNPs + Indels  phased_with_parents_and_pedigree
# 14            SNP  phased_with_parents_and_pedigree
# 34          Indel  phased_with_parents_and_pedigree
# 37  SNPs + Indels  phased_with_parents_and_pedigree
# 35            SNP  phased_with_parents_and_pedigree
# 38          Indel  phased_with_parents_and_pedigree
# 36  SNPs + Indels  phased_with_parents_and_pedigree
# 9             SNP  phased_with_parents_and_pedigree
# 40          Indel  phased_with_parents_and_pedigree
# 17  SNPs + Indels  phased_with_parents_and_pedigree
# 41            SNP  phased_with_parents_and_pedigree
# 16          Indel  phased_with_parents_and_pedigree
# 33  SNPs + Indels  phased_with_parents_and_pedigree
# 11            SNP  phased_with_parents_and_pedigree
# 27          Indel  phased_with_parents_and_pedigree
# 13  SNPs + Indels  phased_with_parents_and_pedigree
# 0             SNP  phased_with_parents_and_pedigree
# 29          Indel  phased_with_parents_and_pedigree
# 7   SNPs + Indels  phased_with_parents_and_pedigree
# 4             SNP  phased_with_parents_and_pedigree
# 32          Indel  phased_with_parents_and_pedigree
# 20  SNPs + Indels  phased_with_parents_and_pedigree
# 22            SNP  phased_with_parents_and_pedigree
# 25          Indel  phased_with_parents_and_pedigree
# 21  SNPs + Indels  phased_with_parents_and_pedigree
# 6             SNP  phased_with_parents_and_pedigree
# 3           Indel  phased_with_parents_and_pedigree
# 12  SNPs + Indels  phased_with_parents_and_pedigree
# 30            SNP  phased_with_parents_and_pedigree
# 28          Indel  phased_with_parents_and_pedigree
# 23  SNPs + Indels  phased_with_parents_and_pedigree
# 39            SNP  phased_with_parents_and_pedigree
# 19          Indel  phased_with_parents_and_pedigree
# 18  SNPs + Indels  phased_with_parents_and_pedigree
# 24            SNP  phased_with_parents_and_pedigree
# 10          Indel  phased_with_parents_and_pedigree
# 31  SNPs + Indels  phased_with_parents_and_pedigree
#
#        ground_truth_data_source     genome variant_id  n_switch_errors  \
# 8                  HPRC_samples     GRCh38       None           203833
# 15                 HPRC_samples     GRCh38       None           270831
# 5                  HPRC_samples     GRCh38       None           474664
# 2                  HPRC_samples  CHM13v2.0       None           125429
# 26                 HPRC_samples  CHM13v2.0       None           236515
# 1                  HPRC_samples  CHM13v2.0       None           361944
# 14                HGSVC_samples     GRCh38       None           754134
# 34                HGSVC_samples     GRCh38       None           645574
# 37                HGSVC_samples     GRCh38       None          1399708
# 35                HGSVC_samples  CHM13v2.0       None           485678
# 38                HGSVC_samples  CHM13v2.0       None           533760
# 36                HGSVC_samples  CHM13v2.0       None          1019438
# 9        HPRC_HGSVC_all_samples     GRCh38       None           957339
# 40       HPRC_HGSVC_all_samples     GRCh38       None           903281
# 17       HPRC_HGSVC_all_samples     GRCh38       None          1860620
# 41       HPRC_HGSVC_all_samples  CHM13v2.0       None           619740
# 16       HPRC_HGSVC_all_samples  CHM13v2.0       None           766099
# 33       HPRC_HGSVC_all_samples  CHM13v2.0       None          1385839
# 11          HPRC_HGSVC_probands     GRCh38       None           392141
# 27          HPRC_HGSVC_probands     GRCh38       None           530431
# 13          HPRC_HGSVC_probands     GRCh38       None           922572
# 0           HPRC_HGSVC_probands  CHM13v2.0       None           239782
# 29          HPRC_HGSVC_probands  CHM13v2.0       None           468515
# 7           HPRC_HGSVC_probands  CHM13v2.0       None           708297
# 4                HGSVC_probands     GRCh38       None           189404
# 32               HGSVC_probands     GRCh38       None           246392
# 20               HGSVC_probands     GRCh38       None           435796
# 22               HGSVC_probands  CHM13v2.0       None           111439
# 25               HGSVC_probands  CHM13v2.0       None           214074
# 21               HGSVC_probands  CHM13v2.0       None           325513
# 6                 HGSVC_parents     GRCh38       None           142964
# 3                 HGSVC_parents     GRCh38       None           132952
# 12                HGSVC_parents     GRCh38       None           275916
# 30                HGSVC_parents  CHM13v2.0       None            60029
# 28                HGSVC_parents  CHM13v2.0       None           110811
# 23                HGSVC_parents  CHM13v2.0       None           170840
# 39  HGSVC_samples_nontrios_only     GRCh38       None           423045
# 19  HGSVC_samples_nontrios_only     GRCh38       None           241792
# 18  HGSVC_samples_nontrios_only     GRCh38       None           664837
# 24  HGSVC_samples_nontrios_only  CHM13v2.0       None           320395
# 10  HGSVC_samples_nontrios_only  CHM13v2.0       None           188371
# 31  HGSVC_samples_nontrios_only  CHM13v2.0       None           508766
#
#     n_checked  n_gt_errors  n_gt_checked          MAC            AN  Syntenic  \
# 8    96830151      3025975     711358610  10944096358  116867178764  18221880
# 15   19555688      6481975     145991067   2456453580   23980917912   3740768
# 5   116385839      9507950     857349677  13400549938  140848096676  21962648
# 2    83970616      1581451     615986668   9469281970  101191249828  15792611
# 26   18027890      5285347     131789145   2235467907   21649362400   3376142
# 1   101998506      6866798     747775813  11704749877  122840612228  19168753
# 14  151010447      8002821    1262828279  10955497233  128888389728  20094909
# 34   29972914     13099186     257525124   2469918872   26283412072   4099769
# 37  180983361     21102007    1520353403  13425416105  155171801800  24194678
# 35  131554603      5512226    1118869739   9491939443  114194366900  17820975
# 38   27594727     10825486     232867189   2243090467   23766358296   3702815
# 36  159149330     16337712    1351736928  11735029910  137960725196  21523790
# 9   241013562     14721907    2350794845  10982317171  152594204608  23793129
# 40   47466990     21396841     445915360   2476326087   29056677080   4532480
# 17  288480552     36118748    2796710205  13458643258  181650881688  28325609
# 41  209878593     10533796    2082299645   9521752792  135196547464  21100865
# 16   43608428     17831326     402399835   2245832839   26229554432   4089910
# 33  253487021     28365122    2484699480  11767585631  161426101896  25190775
# 11  164491634      7523433    1396660154  10907986574  133179742148  20766556
# 27   32349730     13448642     275069141   2433600414   26313991172   4105018
# 13  196841364     20972075    1671729295  13341586988  159493733320  24871574
# 0   142966973      4885380    1206225547   9459032010  115063447336  17958339
# 29   29686314     11141390     247071200   2206659927   23644887224   3687219
# 7   172653287     16026770    1453296747  11665691937  138708334560  21645558
# 4    73719637      3536488     478222804  10701095005   99849848776  15569973
# 32   14535103      5879840     103388337   2360505655   21645936260   3377159
# 20   88254740      9416328     581611141  13061600660  121495785036  18947132
# 22   64083157      2443173     413454077   9283079788   86358522764  13478025
# 25   13331480      4837731      92803375   2140405049   19439463676   3031931
# 21   77414637      7280904     506257452  11423484837  105797986440  16509956
# 6    33168366      1101386     155285503  10306271778   77507554364  12085944
# 3     6628759      2189651      34800663   2238640700   17421422388   2718117
# 12   39797125      3291037     190086166  12544912478   94928976752  14804061
# 30   28907987       687896     135397717   8941645479   67615026596  10552603
# 28    6100767      1824830      31395703   2031937895   15729447164   2453315
# 23   35008754      2512726     166793420  10973583374   83344473760  13005918
# 39   43341629      2699076     233348273  10442767236   79816247596  12446981
# 19    8580217      3510984      53180074   2283546245   18263529176   2849598
# 18   51921846      6210060     286528347  12726313481   98079776772  15296579
# 24   37994100      2097605     207776731   9060713235   71102619380  11097182
# 10    7907309      2866376      47918554   2070335651   16469973704   2569134
# 31   45901409      4963981     255695285  11131048886   87572593084  13666316
#
#     multiallelic  in_STRs  in_platinum_STRs  in_segdups          MAF  \
# 8        1265576   766061           1743056      729897  163978912.0
# 15       2691149   755934           2640091      125781   38157432.0
# 5        3956725  1521995           4383147      855678  199150896.0
# 2         987434   517335           1313540      278708  142845632.0
# 26       2364140   779837           2303815      113211   34772904.0
# 1        3351574  1297172           3617355      391919  174973280.0
# 14       1367442   838425           1895313      803320  163417504.0
# 34       2940460   813114           2887930      138324   38311468.0
# 37       4307902  1651539           4783243      941644  198561648.0
# 35       1097102   587425           1471419      302956  142577184.0
# 38       2583571   833259           2518845      123142   34848972.0
# 36       3680673  1420684           3990264      426098  174604576.0
# 9        1568185   958358           2213064      920122  162859712.0
# 40       3185320   886608           3129710      150987   38340108.0
# 17       4753505  1844966           5342774     1071109  197901824.0
# 41       1266753   672813           1726315      341533  142198736.0
# 16       2798030   893192           2729404      131564   34835480.0
# 33       4064783  1566005           4455719      473097  174114928.0
# 11       1386360   839847           1939416      805160  162603296.0
# 27       2919010   811535           2866535      135286   37747404.0
# 13       4305370  1651382           4805951      940446  197185088.0
# 0        1097397   576521           1475703      292575  141984288.0
# 29       2553224   824407           2491677      117071   34286444.0
# 7        3650621  1400928           3967380      409646  173475584.0
# 4        1075135   639116           1470196      607418  161630560.0
# 32       2470508   678159           2422863      109993   36720588.0
# 20       3545643  1317275           3893059      717411  195674480.0
# 22        850471   438828           1117010      221586  141086784.0
# 25       2155489   699440           2102793       94671   33334620.0
# 21       3005960  1138268           3219803      316257  172083104.0
# 6         856704   500251           1148979      472025  157311664.0
# 3        2005144   562272           1962357       87418   34890936.0
# 12       2861848  1062523           3111336      559443  190270688.0
# 30        682129   346061            878947      174249  137145680.0
# 28       1755681   586063           1709678       75536   31681220.0
# 23       2437810   932124           2588625      249785  167135872.0
# 39        883777   514418           1184948      483147  159613792.0
# 19       2120649   583367           2076316       91449   35577040.0
# 18       3004426  1097785           3261264      574596  193158208.0
# 24        713470   361885            923329      180852  139174608.0
# 10       1853408   607640           1805361       78522   32271328.0
# 31       2566878   969525           2728690      259374  169718640.0
#
#    rounded_MAF  gt_error_rate  switch_error_rate
# 8          NaN       0.425380           0.210506
# 15         NaN       4.439981           1.384922
# 5          NaN       1.108993           0.407837
# 2          NaN       0.256735           0.149372
# 26         NaN       4.010457           1.311939
# 1          NaN       0.918296           0.354852
# 14         NaN       0.633722           0.499392
# 34         NaN       5.086566           2.153858
# 37         NaN       1.387967           0.773390
# 35         NaN       0.492660           0.369184
# 38         NaN       4.648781           1.934283
# 36         NaN       1.208646           0.640554
# 9          NaN       0.626252           0.397214
# 40         NaN       4.798409           1.902967
# 17         NaN       1.291473           0.644972
# 41         NaN       0.505873           0.295285
# 16         NaN       4.431246           1.756768
# 33         NaN       1.141592           0.546710
# 11         NaN       0.538673           0.238396
# 27         NaN       4.889186           1.639677
# 13         NaN       1.254514           0.468688
# 0          NaN       0.405014           0.167718
# 29         NaN       4.509384           1.578219
# 7          NaN       1.102787           0.410242
# 4          NaN       0.739506           0.256925
# 32         NaN       5.687141           1.695151
# 20         NaN       1.619008           0.493793
# 22         NaN       0.590918           0.173897
# 25         NaN       5.212883           1.605778
# 21         NaN       1.438182           0.420480
# 6          NaN       0.709265           0.431025
# 3          NaN       6.291981           2.005685
# 12         NaN       1.731340           0.693306
# 30         NaN       0.508056           0.207655
# 28         NaN       5.812356           1.816345
# 23         NaN       1.506490           0.487992
# 39         NaN       1.156673           0.976071
# 19         NaN       6.602067           2.818017
# 18         NaN       2.167346           1.280457
# 24         NaN       1.009548           0.843276
# 10         NaN       5.981766           2.382239
# 31         NaN       1.941366           1.108389

# %%
best_phased_variants_by_syntenic.loc[
    best_phased_variants_by_syntenic.ground_truth_data_source == 'HPRC_samples'
].sort_values(['ground_truth_data_source', 'Syntenic', 'genome', 'type'])
# Out:
#              type  Syntenic                 method_of_phasing  \
# 41            SNP     False  phased_with_parents_and_pedigree
# 67          Indel     False  phased_with_parents_and_pedigree
# 0   SNPs + Indels     False  phased_with_parents_and_pedigree
# 5             SNP     False  phased_with_parents_and_pedigree
# 17          Indel     False  phased_with_parents_and_pedigree
# 34  SNPs + Indels     False  phased_with_parents_and_pedigree
# 69            SNP      True  phased_with_parents_and_pedigree
# 11          Indel      True  phased_with_parents_and_pedigree
# 39  SNPs + Indels      True  phased_with_parents_and_pedigree
# 20            SNP      True  phased_with_parents_and_pedigree
# 54          Indel      True  phased_with_parents_and_pedigree
# 29  SNPs + Indels      True  phased_with_parents_and_pedigree
#
#    ground_truth_data_source     genome variant_id  n_switch_errors  n_checked  \
# 41             HPRC_samples     GRCh38       None              450     122930
# 67             HPRC_samples     GRCh38       None              174      15490
# 0              HPRC_samples     GRCh38       None              624     138420
# 5              HPRC_samples  CHM13v2.0       None              133      26737
# 17             HPRC_samples  CHM13v2.0       None              410      15019
# 34             HPRC_samples  CHM13v2.0       None              543      41756
# 69             HPRC_samples     GRCh38       None           203383   96707221
# 11             HPRC_samples     GRCh38       None           270657   19540198
# 39             HPRC_samples     GRCh38       None           474040  116247419
# 20             HPRC_samples  CHM13v2.0       None           125296   83943879
# 54             HPRC_samples  CHM13v2.0       None           236105   18012871
# 29             HPRC_samples  CHM13v2.0       None           361401  101956750
#
#     n_gt_errors  n_gt_checked          MAC            AN  multiallelic  \
# 41        25015       1054999     14013151     174259244          3736
# 67        10527        152017      2255971      25039640          2623
# 0         35542       1207016     16269122     199298884          6359
# 5         15469        336505      3625205      55368984          1475
# 17        16586        173023      2662187      28549032          3520
# 34        32055        509528      6287392      83918016          4995
# 69      3000960     710303611  10930083207  116692919520       1261840
# 11      6471448     145839050   2454197609   23955878272       2688526
# 39      9472408     856142661  13384280816  140648797792       3950366
# 20      1565982     615650163   9465656765  101135880844        985959
# 54      5268761     131616122   2232805720   21620813368       2360620
# 29      6834743     747266285  11698462485  122756694212       3346579
#
#     in_STRs  in_platinum_STRs  in_segdups           MAF rounded_MAF  \
# 41    16442              2220         983  2.188301e+05         NaN
# 67     1673              1852         191  3.522783e+04         NaN
# 0     18115              4072        1174  2.540636e+05         NaN
# 5      3542               849        2255  5.660954e+04         NaN
# 17     3259              1150        1868  4.157111e+04         NaN
# 34     6801              1999        4123  9.818216e+04         NaN
# 69   749619           1740836      728914  1.637886e+08         NaN
# 11   754261           2638239      125590  3.812274e+07         NaN
# 39  1503880           4379075      854504  1.989228e+08         NaN
# 20   513793           1312691      276453  1.427933e+08         NaN
# 54   776578           2302665      111343  3.473215e+07         NaN
# 29  1290371           3615356      387796  1.748844e+08         NaN
#
#     gt_error_rate  switch_error_rate
# 41       2.371092           0.366062
# 67       6.924883           1.123305
# 0        2.944617           0.450802
# 5        4.596960           0.497438
# 17       9.586009           2.729875
# 34       6.291116           1.300412
# 69       0.422490           0.210308
# 11       4.437390           1.385129
# 39       1.106405           0.407785
# 20       0.254362           0.149262
# 54       4.003127           1.310757
# 29       0.914633           0.354465

# %% [markdown]
# ## 4) Percent concordance summaries

# %%
overall_subsetted = (
    MAF_performance_variant_df
    .filter(
        (pl.col('ground_truth_data_source') != 'trios') &
        (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree')
    )
    .group_by(['type', 'Syntenic', 'method_of_phasing', 'ground_truth_data_source', 'genome'])
    .sum()
    .with_columns(gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked'))
)

overall = (
    MAF_performance_variant_df
    .filter(
        (pl.col('ground_truth_data_source') != 'trios') &
        (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree')
    )
    .group_by(['method_of_phasing', 'ground_truth_data_source', 'genome'])
    .sum()
    .with_columns(gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked'))
)

overall_syntenic = (
    MAF_performance_variant_df
    .filter(
        (pl.col('ground_truth_data_source') != 'trios') &
        (pl.col('Syntenic')) &
        (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree')
    )
    .group_by(['method_of_phasing', 'ground_truth_data_source', 'genome'])
    .sum()
    .with_columns(gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked'))
)

# %%
overall_syntenic = overall_syntenic.to_pandas()[['Syntenic', 'genome', 'ground_truth_data_source', 'gt_error_rate']].sort_values(['genome', 'Syntenic', 'gt_error_rate'])
overall_syntenic['Non-reference true positive rate'] = (1 - overall_syntenic.gt_error_rate) * 100
overall_syntenic['gt_error_rate'] *= 100
overall_syntenic.loc[overall_syntenic.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples', 'HPRC_HGSVC_all_samples'))]
# Out:
#    Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 0  21962648     GRCh38             HPRC_samples       1.106405
# 1  24194678     GRCh38            HGSVC_samples       1.386977
# 5  28325609     GRCh38   HPRC_HGSVC_all_samples       1.289689
# 6  19168753  CHM13v2.0             HPRC_samples       0.914633
# 8  21523790  CHM13v2.0            HGSVC_samples       1.203934
# 3  25190775  CHM13v2.0   HPRC_HGSVC_all_samples       1.138373
#
#    Non-reference true positive rate
# 0                         98.893595
# 1                         98.613023
# 5                         98.710311
# 6                         99.085367
# 8                         98.796066
# 3                         98.861627

# %%
overall = overall.to_pandas()[['Syntenic', 'genome', 'ground_truth_data_source', 'gt_error_rate']].sort_values(['genome', 'Syntenic', 'gt_error_rate'])
overall['Non-reference true positive rate'] = (1 - overall.gt_error_rate) * 100
overall['gt_error_rate'] *= 100
overall.loc[overall.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples', 'HPRC_HGSVC_all_samples'))]
# Out:
#    Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 3  21962648     GRCh38             HPRC_samples       1.108993
# 6  24194678     GRCh38            HGSVC_samples       1.387967
# 1  28325609     GRCh38   HPRC_HGSVC_all_samples       1.291473
# 8  19168753  CHM13v2.0             HPRC_samples       0.918296
# 0  21523790  CHM13v2.0            HGSVC_samples       1.208646
# 4  25190775  CHM13v2.0   HPRC_HGSVC_all_samples       1.141592
#
#    Non-reference true positive rate
# 3                         98.891007
# 6                         98.612033
# 1                         98.708527
# 8                         99.081704
# 0                         98.791354
# 4                         98.858408

# %%
overall_subsetted = overall_subsetted.to_pandas()[['type', 'Syntenic', 'genome', 'ground_truth_data_source', 'gt_error_rate']].sort_values(['genome', 'type', 'Syntenic', 'gt_error_rate'])
overall_subsetted['Non-reference true positive rate'] = (1 - overall_subsetted.gt_error_rate) * 100
overall_subsetted['gt_error_rate'] *= 100
overall_subsetted.loc[overall_subsetted.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples', 'HPRC_HGSVC_all_samples'))]
# Out:
#      type  Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 47    SNP     False     GRCh38            HGSVC_samples       1.442616
# 16    SNP     False     GRCh38   HPRC_HGSVC_all_samples       2.010190
# 6     SNP     False     GRCh38             HPRC_samples       2.371092
# 35    SNP      True     GRCh38             HPRC_samples       0.422490
# 23    SNP      True     GRCh38   HPRC_HGSVC_all_samples       0.624200
# 45    SNP      True     GRCh38            HGSVC_samples       0.632463
# 54  Indel     False     GRCh38            HGSVC_samples       6.394128
# 20  Indel     False     GRCh38   HPRC_HGSVC_all_samples       6.490134
# 53  Indel     False     GRCh38             HPRC_samples       6.924883
# 4   Indel      True     GRCh38             HPRC_samples       4.437390
# 43  Indel      True     GRCh38   HPRC_HGSVC_all_samples       4.796596
# 34  Indel      True     GRCh38            HGSVC_samples       5.085148
# 21    SNP     False  CHM13v2.0   HPRC_HGSVC_all_samples       4.181155
# 1     SNP     False  CHM13v2.0            HGSVC_samples       4.204832
# 37    SNP     False  CHM13v2.0             HPRC_samples       4.596960
# 8     SNP      True  CHM13v2.0             HPRC_samples       0.254362
# 24    SNP      True  CHM13v2.0            HGSVC_samples       0.490435
# 27    SNP      True  CHM13v2.0   HPRC_HGSVC_all_samples       0.504153
# 40  Indel     False  CHM13v2.0             HPRC_samples       9.586009
# 22  Indel     False  CHM13v2.0            HGSVC_samples       9.598220
# 36  Indel     False  CHM13v2.0   HPRC_HGSVC_all_samples       9.751645
# 50  Indel      True  CHM13v2.0             HPRC_samples       4.003127
# 3   Indel      True  CHM13v2.0   HPRC_HGSVC_all_samples       4.423507
# 30  Indel      True  CHM13v2.0            HGSVC_samples       4.637721
#
#     Non-reference true positive rate
# 47                         98.557384
# 16                         97.989810
# 6                          97.628908
# 35                         99.577510
# 23                         99.375800
# 45                         99.367537
# 54                         93.605872
# 20                         93.509866
# 53                         93.075117
# 4                          95.562610
# 43                         95.203404
# 34                         94.914852
# 21                         95.818845
# 1                          95.795168
# 37                         95.403040
# 8                          99.745638
# 24                         99.509565
# 27                         99.495847
# 40                         90.413991
# 22                         90.401780
# 36                         90.248355
# 50                         95.996873
# 3                          95.576493
# 30                         95.362279

# %% [markdown]
# ## 5) Singleton and doubleton accuracy

# %%
# Paper cross-reference: manuscript lines 210-214; Figure 2b,d;
# reviewer reply lines 348-354 (singleton SER ~30%).

final_dataset_singletons = MAF_performance_variant_df.filter(
    (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
    (pl.col('ground_truth_data_source') == 'HGSVC_samples_nontrios_only') &
    (pl.col('rounded_MAF').cast(pl.String) == 'singleton')
)

final_dataset_singleton_ser = (
    final_dataset_singletons
    .group_by(['genome', 'type'])
    .sum()
    .with_columns(SER=pl.col('n_switch_errors') / pl.col('n_checked') * 100)
    .sort(['genome', 'type'])
    .to_pandas()
    .reset_index(drop=True)
)

# Genotype-discordance rows for the manuscript text about singleton and doubleton SNP concordance.
# The doubleton values use all HPRC/HGSVC assembly samples; the singleton value uses HGSVC non-trio samples.
first_non_singleton_maf_bin = '0.00021-0.00042'
paper_maf_concordance = (
    MAF_performance_variant_df
    .filter(
        (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
        (pl.col('type') == 'SNP') &
        (
            ((pl.col('ground_truth_data_source') == 'HPRC_HGSVC_all_samples') &
             (pl.col('rounded_MAF').cast(pl.String) == first_non_singleton_maf_bin)) |
            ((pl.col('ground_truth_data_source') == 'HGSVC_samples_nontrios_only') &
             (pl.col('rounded_MAF').cast(pl.String) == 'singleton'))
        )
    )
    .group_by(['ground_truth_data_source', 'rounded_MAF', 'genome', 'type'])
    .sum()
    .with_columns(
        gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked') * 100,
        gt_accuracy_rate=100 - (pl.col('n_gt_errors') / pl.col('n_gt_checked') * 100),
    )
    .sort(['ground_truth_data_source', 'rounded_MAF', 'genome', 'type'])
    .to_pandas()
    .reset_index(drop=True)
)

# %% [markdown]
# ## 6) Concordance summary (Table 1 source)

# %%
synEnum = pl.Enum(categories=['All_regions', 'Syntenic', 'Nonsyntenic'])
concordance = all_variants.filter(
    (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
    (pl.col('ground_truth_data_source') == 'HPRC_samples')
).with_columns(
    Syntenic=pl.col('Syntenic').cast(str).replace('true', 'Syntenic').replace('false', 'Nonsyntenic').cast(synEnum)
)

concordance_summary = concordance.clone().with_columns(Syntenic=pl.lit('All_regions').cast(synEnum))
concordance_summary = pl.concat((concordance, concordance_summary)).group_by(['Syntenic', 'genome', 'type']).sum().to_pandas().reset_index()
concordance_summary = pd.concat((
    concordance_summary,
    concordance_summary.copy().assign(type='SNPs + Indels').groupby(['Syntenic', 'genome', 'type'], observed=True).sum(numeric_only=True).reset_index(),
))
concordance_summary['gt_error_rate'] = concordance_summary.n_gt_errors / concordance_summary.n_gt_checked * 100
concordance_summary['gt_accuracy_rate'] = 100 - concordance_summary['gt_error_rate']
concordance_summary['switch_error_rate'] = concordance_summary.n_switch_errors / concordance_summary.n_checked * 100
concordance_summary['Syntenic'] = concordance_summary.Syntenic.replace('false', 'Nonsyntenic').replace('true', 'Syntenic')

pd.set_option("display.precision", 3)
concordance_summary.sort_values(['Syntenic', 'genome', 'type']).set_index(['Syntenic', 'genome', 'type'])[
    ['switch_error_rate', 'gt_error_rate', 'n_gt_errors', 'n_gt_checked', 'n_switch_errors', 'n_checked']
].astype(float)
# Out:
#                                      switch_error_rate  gt_error_rate  \
# Syntenic    genome    type
# All_regions GRCh38    Indel                      1.385          4.440
#                       SNP                        0.211          0.425
#                       SNPs + Indels              0.408          1.109
#             CHM13v2.0 Indel                      1.312          4.010
#                       SNP                        0.149          0.257
#                       SNPs + Indels              0.355          0.918
# Syntenic    GRCh38    Indel                      1.385          4.437
#                       SNP                        0.210          0.422
#                       SNPs + Indels              0.408          1.106
#             CHM13v2.0 Indel                      1.311          4.003
#                       SNP                        0.149          0.254
#                       SNPs + Indels              0.354          0.915
# Nonsyntenic GRCh38    Indel                      1.123          6.925
#                       SNP                        0.366          2.371
#                       SNPs + Indels              0.451          2.945
#             CHM13v2.0 Indel                      2.730          9.586
#                       SNP                        0.497          4.597
#                       SNPs + Indels              1.300          6.291
#
#                                      n_gt_errors  n_gt_checked  \
# Syntenic    genome    type
# All_regions GRCh38    Indel            6.482e+06     1.460e+08
#                       SNP              3.026e+06     7.114e+08
#                       SNPs + Indels    9.508e+06     8.573e+08
#             CHM13v2.0 Indel            5.285e+06     1.318e+08
#                       SNP              1.581e+06     6.160e+08
#                       SNPs + Indels    6.867e+06     7.478e+08
# Syntenic    GRCh38    Indel            6.471e+06     1.458e+08
#                       SNP              3.001e+06     7.103e+08
#                       SNPs + Indels    9.472e+06     8.561e+08
#             CHM13v2.0 Indel            5.269e+06     1.316e+08
#                       SNP              1.566e+06     6.157e+08
#                       SNPs + Indels    6.835e+06     7.473e+08
# Nonsyntenic GRCh38    Indel            1.053e+04     1.520e+05
#                       SNP              2.502e+04     1.055e+06
#                       SNPs + Indels    3.554e+04     1.207e+06
#             CHM13v2.0 Indel            1.659e+04     1.730e+05
#                       SNP              1.547e+04     3.365e+05
#                       SNPs + Indels    3.206e+04     5.095e+05
#
#                                      n_switch_errors  n_checked
# Syntenic    genome    type
# All_regions GRCh38    Indel                 270831.0  1.956e+07
#                       SNP                   203833.0  9.683e+07
#                       SNPs + Indels         474664.0  1.164e+08
#             CHM13v2.0 Indel                 236515.0  1.803e+07
#                       SNP                   125429.0  8.397e+07
#                       SNPs + Indels         361944.0  1.020e+08
# Syntenic    GRCh38    Indel                 270657.0  1.954e+07
#                       SNP                   203383.0  9.671e+07
#                       SNPs + Indels         474040.0  1.162e+08
#             CHM13v2.0 Indel                 236105.0  1.801e+07
#                       SNP                   125296.0  8.394e+07
#                       SNPs + Indels         361401.0  1.020e+08
# Nonsyntenic GRCh38    Indel                    174.0  1.549e+04
#                       SNP                      450.0  1.229e+05
#                       SNPs + Indels            624.0  1.384e+05
#             CHM13v2.0 Indel                    410.0  1.502e+04
#                       SNP                      133.0  2.674e+04
#                       SNPs + Indels            543.0  4.176e+04

# %% [markdown]
# ## 7) STR and isolated variant stratification

# %%
# Compute indel discordance within STRs (GIAB + Platinum) and for isolated (biallelic,
# non-STR, non-overlapping) indels, grouped by genome.

indels_only = MAF_performance_variant_df.filter(
    (pl.col('type') == 'Indel') &
    (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
    (pl.col('ground_truth_data_source') == 'HPRC_samples')
)

# STR indels: in GIAB or Platinum STR regions
str_indels = (
    indels_only
    .filter(pl.col('in_STRs') | pl.col('in_platinum_STRs'))
    .group_by('genome').sum()
    .with_columns(gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked') * 100)
    .to_pandas().set_index('genome')
)

# multiallelic indels: in GIAB, or Platinum STR regions, or overlapping another variant
multiallelic_indels = (
    indels_only
    .filter(pl.col('in_STRs') | pl.col('in_platinum_STRs') | pl.col('multiallelic'))
    .group_by('genome').sum()
    .with_columns(gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked') * 100)
    .to_pandas().set_index('genome')
)


# Isolated indels: not in STRs, not overlapping other variants (biallelic)
isolated_indels = (
    indels_only
    .filter(~pl.col('in_STRs') & ~pl.col('in_platinum_STRs') & ~pl.col('multiallelic'))
    .group_by('genome').sum()
    .with_columns(gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked') * 100)
    .to_pandas().set_index('genome')
)

chm13_str_indel_disc = str_indels.loc['CHM13v2.0', 'gt_error_rate']
grch38_str_indel_disc = str_indels.loc['GRCh38', 'gt_error_rate']
chm13_multiallelic_indel_disc = multiallelic_indels.loc['CHM13v2.0', 'gt_error_rate']
grch38_multiallelic_indel_disc = multiallelic_indels.loc['GRCh38', 'gt_error_rate']
chm13_isolated_indel_disc = isolated_indels.loc['CHM13v2.0', 'gt_error_rate']
grch38_isolated_indel_disc = isolated_indels.loc['GRCh38', 'gt_error_rate']

print(f'STR indel discordance  -- GRCh38: {grch38_str_indel_disc:.2f}%, CHM13: {chm13_str_indel_disc:.2f}%')
print(f'Multiallelic indel discordance -- GRCh38: {grch38_multiallelic_indel_disc:.2f}%, CHM13: {chm13_multiallelic_indel_disc:.2f}%')
print(f'Isolated indel discordance -- GRCh38: {grch38_isolated_indel_disc:.2f}%, CHM13: {chm13_isolated_indel_disc:.2f}%')
# Out:
# STR indel discordance  -- GRCh38: 5.93%, CHM13: 5.49%
# Multiallelic indel discordance -- GRCh38: 5.56%, CHM13: 5.11%
# Isolated indel discordance -- GRCh38: 0.45%, CHM13: 0.43%

# %% [markdown]
# ## 8) Plug-and-play manuscript text
#
# The sentences below use the exact manuscript sentence structure with computed values inserted.
# Copy-paste these into the paper and use the surrounding context to ctrl-F to the correct section.

# %%
# Helper: extract a value from concordance_summary
def cs(genome, vtype, syntenic, col='gt_error_rate'):
    mask = (
        (concordance_summary.genome == genome) &
        (concordance_summary.type == vtype) &
        (concordance_summary.Syntenic == syntenic)
    )
    return float(concordance_summary.loc[mask, col].iloc[0])

# Helper: extract singleton SER
def sing_ser(genome, vtype):
    mask = (final_dataset_singleton_ser.genome == genome) & (final_dataset_singleton_ser.type == vtype)
    return float(final_dataset_singleton_ser.loc[mask, 'SER'].iloc[0])

# Helper: extract doubleton/singleton discordance from paper_maf_concordance
def maf_disc(gt_source, maf_bin, genome):
    mask = (
        (paper_maf_concordance.ground_truth_data_source == gt_source) &
        (paper_maf_concordance.rounded_MAF == maf_bin) &
        (paper_maf_concordance.genome == genome)
    )
    return float(paper_maf_concordance.loc[mask, 'gt_error_rate'].iloc[0])


# ---- Overall concordance (Table 1) ----
chm13_all_disc = cs('CHM13v2.0', 'SNPs + Indels', 'All_regions')
grch38_all_disc = cs('GRCh38', 'SNPs + Indels', 'All_regions')

print('--- Results: 1kGP short-read variant calls (Table 1 / concordance) ---')
print()
print(f'Overall, T2T-CHM13 1kGP variants were {100 - chm13_all_disc:.2f}% concordant '
      f'with assembly-derived variation, while GRCh38 1kGP variants were '
      f'{100 - grch38_all_disc:.2f}% concordant (Table 1).')
print()

# ---- Shared-region concordance ----
chm13_snp_syn = cs('CHM13v2.0', 'SNP', 'Syntenic')
grch38_snp_syn = cs('GRCh38', 'SNP', 'Syntenic')
chm13_indel_syn = cs('CHM13v2.0', 'Indel', 'Syntenic')
grch38_indel_syn = cs('GRCh38', 'Indel', 'Syntenic')

print(f'SNPs from the T2T-CHM13 panel were less discordant with assembled genomes '
      f'({chm13_snp_syn:.2f}%) than those from the GRCh38 panel ({grch38_snp_syn:.2f}%).')
print()
print(f'Indels in shared regions followed the same pattern '
      f'(T2T-CHM13: {chm13_indel_syn:.2f}%, GRCh38: {grch38_indel_syn:.2f}%, Table 1).')
print()

# ---- Doubleton/singleton discordance ----
grch38_doubleton = maf_disc('HPRC_HGSVC_all_samples', first_non_singleton_maf_bin, 'GRCh38')
chm13_doubleton = maf_disc('HPRC_HGSVC_all_samples', first_non_singleton_maf_bin, 'CHM13v2.0')
chm13_singleton = maf_disc('HGSVC_samples_nontrios_only', 'singleton', 'CHM13v2.0')

print(f'Genotyping accuracy did not vary substantially by minor allele frequency (0.02%-50%), '
      f'consistent with the VQSR method\'s design to maintain a uniform false positive rate '
      f'regardless of allele frequency. SNPs with only two minor alleles present in the panel '
      f'(doubletons) were called almost as accurately as SNPs in the overall panel '
      f'(GRCh38: {grch38_doubleton:.2f}% discordant, T2T-CHM13: {chm13_doubleton:.2f}% discordant), '
      f'and singleton SNPs in the T2T-CHM13 panel were only {chm13_singleton:.2f}% discordant '
      f'with assembly genotypes.')
print()

# ---- STR / isolated indel discordance ----
print('--- Results: STR and isolated variant stratification ---')
print()
print(f'Manual inspection of pangenome-discordant indels showed that they were frequently '
      f'found within multiallelic short tandem repeats (STRs) -- a trend that we confirmed '
      f'with genome-wide analysis (GRCh38: {grch38_multiallelic_indel_disc:.2f}%, T2T-CHM13: '
      f'{chm13_multiallelic_indel_disc:.2f}% indel discordance within STRs, Supplemental Figure 13).')
print()
print(f'In contrast, isolated indels that did not overlap with other variant classes in the '
      f'panel showed substantially lower discordance rates (GRCh38: {grch38_isolated_indel_disc:.2f}%, '
      f'T2T-CHM13: {chm13_isolated_indel_disc:.2f}%, Supplemental Figure 14).')
print()

# ---- Singleton SER ----
print('--- Results: Singleton phasing accuracy ---')
print()
snp_sing_ser = sing_ser('CHM13v2.0', 'SNP')  # manuscript uses CHM13 values
indel_sing_ser = sing_ser('CHM13v2.0', 'Indel')
print(f'Singleton variants were statistically phased with a switch error rate (SER) of ~30% '
      f'({snp_sing_ser:.2f}% for SNPs; {indel_sing_ser:.2f}% for indels) (Figure 2b,d).')
print()

# ---- Summary/derived stats ----
pct_fewer_discordant = (1 - chm13_all_disc / grch38_all_disc) * 100
print('--- Summary / Introduction ---')
print()
print(f'Among HPRC samples with published long-read-based assemblies, alignment to T2T-CHM13 resulted in '
      f'{pct_fewer_discordant:.0f}% fewer assembly-discordant genotypes')
# Out:
# --- Results: 1kGP short-read variant calls (Table 1 / concordance) ---
# Overall, T2T-CHM13 1kGP variants were 99.08% concordant with assembly-derived variation, while GRCh38 1kGP variants were 98.89% concordant (Table 1).
#
# SNPs from the T2T-CHM13 panel were less discordant with assembled genomes (0.25%) than those from the GRCh38 panel (0.42%).
#
# Indels in shared regions followed the same pattern (T2T-CHM13: 4.00%, GRCh38: 4.44%, Table 1).
#
# Genotyping accuracy did not vary substantially by minor allele frequency (0.02%-50%), consistent with the VQSR method's design to maintain a uniform false positive rate regardless of allele frequency. SNPs with only two minor alleles present in the panel (doubletons) were called almost as accurately as SNPs in the overall panel (GRCh38: 0.51% discordant, T2T-CHM13: 0.45% discordant), and singleton SNPs in the T2T-CHM13 panel were only 1.42% discordant with assembly genotypes.
#
# --- Results: STR and isolated variant stratification ---
#
# Manual inspection of pangenome-discordant indels showed that they were frequently found within multiallelic short tandem repeats (STRs) -- a trend that we confirmed with genome-wide analysis (GRCh38: 5.56%, T2T-CHM13: 5.11% indel discordance within STRs, Supplemental Figure 13).
#
# In contrast, isolated indels that did not overlap with other variant classes in the panel showed substantially lower discordance rates (GRCh38: 0.45%, T2T-CHM13: 0.43%, Supplemental Figure 14).
#
# --- Results: Singleton phasing accuracy ---
#
# Singleton variants were statistically phased with a switch error rate (SER) of ~30% (29.78% for SNPs; 28.85% for indels) (Figure 2b,d).
#
# --- Summary / Introduction ---
#
# Among HPRC samples with published long-read-based assemblies, alignment to T2T-CHM13 resulted in 17% fewer assembly-discordant genotypes

# %% [markdown]
# ## 9) Export: paper_per_variant_inline_statistics_reference.tsv
#
# Consolidated export with one row per unique statistic (both genome values on the same row)
# and a `Paper_Text` column containing the plug-and-play manuscript sentence.

# %%
type_abbrev_map = {'SNP': 'SNP', 'Indel': 'Ind', 'SNPs + Indels': 'All'}
syn_abbrev_map = {'All_regions': 'All', 'Syntenic': 'Syn', 'Nonsyntenic': 'Nsyn'}

rows = []

# --- Table 1 / concordance: one row per (type, syntenic) combination ---
for (vtype, syn), grp in concordance_summary.groupby(['type', 'Syntenic'], observed=True):
    type_abbrev = type_abbrev_map.get(vtype, vtype)
    syn_abbrev = syn_abbrev_map.get(syn, syn)
    stat_code = f'C_{type_abbrev}_{syn_abbrev}'
    by_genome = grp.set_index('genome')
    val_chm13 = float(by_genome.loc['CHM13v2.0', 'gt_error_rate']) if 'CHM13v2.0' in by_genome.index else np.nan
    val_grch38 = float(by_genome.loc['GRCh38', 'gt_error_rate']) if 'GRCh38' in by_genome.index else np.nan
    rows.append({
        'Stat_Code': stat_code,
        'Section': 'Per-variant concordance',
        'Statistic_Description': f'{syn} | {vtype} | gt_error_rate',
        'Value_CHM13': val_chm13,
        'Value_GRCh38': val_grch38,
        'Percent_Change': (val_chm13 - val_grch38) / val_grch38 * 100 if (val_chm13 and val_grch38) else np.nan,
        'Paper_Text': '',
        'Paper_Location': 'Results: Table 1 / concordance paragraphs',
        'Source_Notebook': 'calc_per_variant_figures_for_paper.ipynb',
        'Notes': 'ground_truth_source=HPRC_samples (phased_with_parents_and_pedigree)',
    })

# Attach Paper_Text to the overall concordance row
for r in rows:
    if r['Stat_Code'] == 'C_All_All':
        r['Paper_Text'] = (
            f'Overall, T2T-CHM13 1kGP variants were {100 - r["Value_CHM13"]:.2f}% concordant '
            f'with assembly-derived variation, while GRCh38 1kGP variants were '
            f'{100 - r["Value_GRCh38"]:.2f}% concordant (Table 1).'
        )
    elif r['Stat_Code'] == 'C_SNP_Syn':
        r['Paper_Text'] = (
            f'SNPs from the T2T-CHM13 panel were less discordant with assembled genomes '
            f'({r["Value_CHM13"]:.2f}%) than those from the GRCh38 panel ({r["Value_GRCh38"]:.2f}%).'
        )
    elif r['Stat_Code'] == 'C_Ind_Syn':
        r['Paper_Text'] = (
            f'Indels in shared regions followed the same pattern '
            f'(T2T-CHM13: {r["Value_CHM13"]:.2f}%, GRCh38: {r["Value_GRCh38"]:.2f}%, Table 1).'
        )

# --- Final-dataset singleton SER: one row per type ---
for vtype in ['SNP', 'Indel']:
    type_abbrev = type_abbrev_map.get(vtype, vtype)
    ser_by_genome = final_dataset_singleton_ser.loc[final_dataset_singleton_ser.type == vtype].set_index('genome')
    val_chm13 = float(ser_by_genome.loc['CHM13v2.0', 'SER']) if 'CHM13v2.0' in ser_by_genome.index else np.nan
    val_grch38 = float(ser_by_genome.loc['GRCh38', 'SER']) if 'GRCh38' in ser_by_genome.index else np.nan
    rows.append({
        'Stat_Code': f'SING_SER_{type_abbrev}',
        'Section': 'Singleton SER',
        'Statistic_Description': f'Final-dataset singleton SER | {vtype}',
        'Value_CHM13': val_chm13,
        'Value_GRCh38': val_grch38,
        'Percent_Change': np.nan,
        'Paper_Text': '',
        'Paper_Location': 'Results: statistically phased singleton text; Figure 2b,d',
        'Source_Notebook': 'calc_per_variant_figures_for_paper.ipynb',
        'Notes': 'method_of_phasing=phased_with_parents_and_pedigree; ground_truth_source=HGSVC_samples_nontrios_only; rounded_MAF=singleton',
    })

# Attach Paper_Text to singleton SNP row
for r in rows:
    if r['Stat_Code'] == 'SING_SER_SNP':
        indel_row = next(x for x in rows if x['Stat_Code'] == 'SING_SER_Ind')
        r['Paper_Text'] = (
            f'Singleton variants were statistically phased with a switch error rate (SER) of ~30% '
            f'({r["Value_CHM13"]:.2f}% for SNPs; {indel_row["Value_CHM13"]:.2f}% for indels) (Figure 2b,d).'
        )

# --- Singleton/doubleton genotype-discordance ---
maf_concordance_defs = {
    ('HPRC_HGSVC_all_samples', first_non_singleton_maf_bin, 'SNP'): {
        'Stat_Code': 'GT_DISC_SNP_DOUBLETON',
        'Statistic_Description': 'Doubleton SNP genotype discordance (first non-singleton MAF bin)',
        'Paper_Location': 'Results: genotype concordance paragraph, manuscript lines 215-218',
        'Notes': (
            f'method_of_phasing=phased_with_parents_and_pedigree; '
            f'ground_truth_source=HPRC_HGSVC_all_samples; rounded_MAF={first_non_singleton_maf_bin}; '
            f'concordance=100-discordance'
        ),
    },
    ('HGSVC_samples_nontrios_only', 'singleton', 'SNP'): {
        'Stat_Code': 'GT_DISC_SNP_SINGLETON_FINAL',
        'Statistic_Description': 'Singleton SNP genotype discordance (HGSVC non-trio final dataset)',
        'Paper_Location': 'Results: genotype concordance paragraph, manuscript lines 215-218',
        'Notes': (
            'method_of_phasing=phased_with_parents_and_pedigree; '
            'ground_truth_source=HGSVC_samples_nontrios_only; rounded_MAF=singleton; '
            'concordance=100-discordance'
        ),
    },
}

for key, group in paper_maf_concordance.groupby(['ground_truth_data_source', 'rounded_MAF', 'type'], observed=True):
    definition = maf_concordance_defs.get(tuple(key))
    if definition is None:
        continue
    by_genome = group.set_index('genome')
    val_chm13 = float(by_genome.loc['CHM13v2.0', 'gt_error_rate']) if 'CHM13v2.0' in by_genome.index else np.nan
    val_grch38 = float(by_genome.loc['GRCh38', 'gt_error_rate']) if 'GRCh38' in by_genome.index else np.nan
    rows.append({
        'Stat_Code': definition['Stat_Code'],
        'Section': 'MAF-bin genotype concordance',
        'Statistic_Description': definition['Statistic_Description'],
        'Value_CHM13': val_chm13,
        'Value_GRCh38': val_grch38,
        'Percent_Change': np.nan,
        'Paper_Text': '',
        'Paper_Location': definition['Paper_Location'],
        'Source_Notebook': 'calc_per_variant_figures_for_paper.ipynb',
        'Notes': definition['Notes'],
    })

# Attach Paper_Text to the doubleton row (which also covers singleton in same sentence)
for r in rows:
    if r['Stat_Code'] == 'GT_DISC_SNP_DOUBLETON':
        sing_row = next(x for x in rows if x['Stat_Code'] == 'GT_DISC_SNP_SINGLETON_FINAL')
        r['Paper_Text'] = (
            f'SNPs with only two minor alleles present in the panel (doubletons) were called '
            f'almost as accurately as SNPs in the overall panel (GRCh38: {r["Value_GRCh38"]:.2f}% discordant, '
            f'T2T-CHM13: {r["Value_CHM13"]:.2f}% discordant), and singleton SNPs in the T2T-CHM13 panel '
            f'were only {sing_row["Value_CHM13"]:.2f}% discordant with assembly genotypes.'
        )

# --- STR / isolated indel discordance ---
rows.append({
    'Stat_Code': 'STR_INDEL_DISC',
    'Section': 'STR indel discordance',
    'Statistic_Description': 'Indel discordance within GIAB/Platinum STR regions',
    'Value_CHM13': chm13_str_indel_disc,
    'Value_GRCh38': grch38_str_indel_disc,
    'Percent_Change': np.nan,
    'Paper_Text': (
        f'Manual inspection of pangenome-discordant indels showed that they were frequently '
        f'found within multiallelic short tandem repeats (STRs) -- a trend that we confirmed '
        f'with genome-wide analysis (GRCh38: {grch38_str_indel_disc:.2f}%, T2T-CHM13: '
        f'{chm13_str_indel_disc:.2f}% indel discordance within STRs, Supplemental Figure 11).'
    ),
    'Paper_Location': 'Results: STR stratification; manuscript lines 222-229',
    'Source_Notebook': 'calc_per_variant_figures_for_paper.ipynb',
    'Notes': 'ground_truth_source=HPRC_samples; type=Indel; in_STRs or in_platinum_STRs',
})

rows.append({
    'Stat_Code': 'ISOLATED_INDEL_DISC',
    'Section': 'Isolated indel discordance',
    'Statistic_Description': 'Isolated (non-STR, biallelic) indel discordance',
    'Value_CHM13': chm13_isolated_indel_disc,
    'Value_GRCh38': grch38_isolated_indel_disc,
    'Percent_Change': np.nan,
    'Paper_Text': (
        f'In contrast, isolated indels that did not overlap with other variant classes in the '
        f'panel showed substantially lower discordance rates (GRCh38: {grch38_isolated_indel_disc:.2f}%, '
        f'T2T-CHM13: {chm13_isolated_indel_disc:.2f}%, Supplemental Figure 12).'
    ),
    'Paper_Location': 'Results: isolated variant stratification; manuscript lines 222-229',
    'Source_Notebook': 'calc_per_variant_figures_for_paper.ipynb',
    'Notes': 'ground_truth_source=HPRC_samples; type=Indel; ~in_STRs & ~in_platinum_STRs & ~multiallelic',
})

# --- Summary derived stat ---
rows.append({
    'Stat_Code': 'PCT_FEWER_DISCORDANT',
    'Section': 'Summary derived',
    'Statistic_Description': 'Percent fewer assembly-discordant genotypes (HPRC samples; CHM13 vs GRCh38)',
    'Value_CHM13': chm13_all_disc,
    'Value_GRCh38': grch38_all_disc,
    'Percent_Change': pct_fewer_discordant,
    'Paper_Text': (
        f'Among HPRC samples with published long-read-based assemblies, alignment to T2T-CHM13 resulted in '
        f'{pct_fewer_discordant:.0f}% fewer assembly-discordant genotypes'
    ),
    'Paper_Location': 'Summary; Introduction; Discussion',
    'Source_Notebook': 'calc_per_variant_figures_for_paper.ipynb',
    'Notes': 'Derived from HPRC samples only: (1 - chm13_disc/grch38_disc) * 100; All_regions SNPs+Indels gt_error_rate',
})

# --- Build and export ---
paper_inline_statistics_per_variant = pd.DataFrame(rows)
out_path = f'{tables_folder}/paper_per_variant_inline_statistics_reference.tsv'
paper_inline_statistics_per_variant.to_csv(out_path, sep='\t', index=False)
print(f'Wrote {len(paper_inline_statistics_per_variant)} rows to {out_path}')
paper_inline_statistics_per_variant
# Out:
# Wrote 16 rows to tables_whole_genome/paper_per_variant_inline_statistics_reference.tsv
#                       Stat_Code                       Section  \
# 0                     C_Ind_All       Per-variant concordance
# 1                     C_Ind_Syn       Per-variant concordance
# 2                    C_Ind_Nsyn       Per-variant concordance
# 3                     C_SNP_All       Per-variant concordance
# 4                     C_SNP_Syn       Per-variant concordance
# 5                    C_SNP_Nsyn       Per-variant concordance
# 6                     C_All_All       Per-variant concordance
# 7                     C_All_Syn       Per-variant concordance
# 8                    C_All_Nsyn       Per-variant concordance
# 9                  SING_SER_SNP                 Singleton SER
# 10                 SING_SER_Ind                 Singleton SER
# 11        GT_DISC_SNP_DOUBLETON  MAF-bin genotype concordance
# 12  GT_DISC_SNP_SINGLETON_FINAL  MAF-bin genotype concordance
# 13               STR_INDEL_DISC         STR indel discordance
# 14          ISOLATED_INDEL_DISC    Isolated indel discordance
# 15         PCT_FEWER_DISCORDANT               Summary derived
#
#                                 Statistic_Description  Value_CHM13  \
# 0                 All_regions | Indel | gt_error_rate        4.010
# 1                    Syntenic | Indel | gt_error_rate        4.003
# 2                 Nonsyntenic | Indel | gt_error_rate        9.586
# 3                   All_regions | SNP | gt_error_rate        0.257
# 4                      Syntenic | SNP | gt_error_rate        0.254
# 5                   Nonsyntenic | SNP | gt_error_rate        4.597
# 6         All_regions | SNPs + Indels | gt_error_rate        0.918
# 7            Syntenic | SNPs + Indels | gt_error_rate        0.915
# 8         Nonsyntenic | SNPs + Indels | gt_error_rate        6.291
# 9                   Final-dataset singleton SER | SNP       29.778
# 10                Final-dataset singleton SER | Indel       28.854
# 11  Doubleton SNP genotype discordance (first non-...        0.452
# 12  Singleton SNP genotype discordance (HGSVC non-...        1.417
# 13  Indel discordance within GIAB/Platinum STR reg...        5.495
# 14    Isolated (non-STR, biallelic) indel discordance        0.431
# 15  Percent fewer assembly-discordant genotypes (C...        0.918
#
#     Value_GRCh38  Percent_Change  \
# 0          4.440          -9.674
# 1          4.437          -9.786
# 2          6.925          38.428
# 3          0.425         -39.646
# 4          0.422         -39.794
# 5          2.371          93.875
# 6          1.109         -17.195
# 7          1.106         -17.333
# 8          2.945         113.648
# 9            NaN             NaN
# 10           NaN             NaN
# 11         0.510             NaN
# 12           NaN             NaN
# 13         5.926             NaN
# 14         0.445             NaN
# 15         1.109          17.195
#
#                                            Paper_Text  \
# 0
# 1   Indels in shared regions followed the same pat...
# 2
# 3
# 4   SNPs from the T2T-CHM13 panel were less discor...
# 5
# 6   Overall, T2T-CHM13 1kGP variants were 99.08% c...
# 7
# 8
# 9   Singleton variants were statistically phased w...
# 10
# 11  SNPs with only two minor alleles present in th...
# 12
# 13  Manual inspection of pangenome-discordant inde...
# 14  In contrast, isolated indels that did not over...
# 15  alignment to T2T-CHM13 resulted in 17% fewer a...
#
#                                        Paper_Location  \
# 0           Results: Table 1 / concordance paragraphs
# 1           Results: Table 1 / concordance paragraphs
# 2           Results: Table 1 / concordance paragraphs
# 3           Results: Table 1 / concordance paragraphs
# 4           Results: Table 1 / concordance paragraphs
# 5           Results: Table 1 / concordance paragraphs
# 6           Results: Table 1 / concordance paragraphs
# 7           Results: Table 1 / concordance paragraphs
# 8           Results: Table 1 / concordance paragraphs
# 9   Results: statistically phased singleton text; ...
# 10  Results: statistically phased singleton text; ...
# 11  Results: genotype concordance paragraph, manus...
# 12  Results: genotype concordance paragraph, manus...
# 13  Results: STR stratification; manuscript lines ...
# 14  Results: isolated variant stratification; manu...
# 15                              Summary; Introduction
#
#                              Source_Notebook  \
# 0   calc_per_variant_figures_for_paper.ipynb
# 1   calc_per_variant_figures_for_paper.ipynb
# 2   calc_per_variant_figures_for_paper.ipynb
# 3   calc_per_variant_figures_for_paper.ipynb
# 4   calc_per_variant_figures_for_paper.ipynb
# 5   calc_per_variant_figures_for_paper.ipynb
# 6   calc_per_variant_figures_for_paper.ipynb
# 7   calc_per_variant_figures_for_paper.ipynb
# 8   calc_per_variant_figures_for_paper.ipynb
# 9   calc_per_variant_figures_for_paper.ipynb
# 10  calc_per_variant_figures_for_paper.ipynb
# 11  calc_per_variant_figures_for_paper.ipynb
# 12  calc_per_variant_figures_for_paper.ipynb
# 13  calc_per_variant_figures_for_paper.ipynb
# 14  calc_per_variant_figures_for_paper.ipynb
# 15  calc_per_variant_figures_for_paper.ipynb
#
#                                                 Notes
# 0   ground_truth_source=HPRC_samples (phased_with_...
# 1   ground_truth_source=HPRC_samples (phased_with_...
# 2   ground_truth_source=HPRC_samples (phased_with_...
# 3   ground_truth_source=HPRC_samples (phased_with_...
# 4   ground_truth_source=HPRC_samples (phased_with_...
# 5   ground_truth_source=HPRC_samples (phased_with_...
# 6   ground_truth_source=HPRC_samples (phased_with_...
# 7   ground_truth_source=HPRC_samples (phased_with_...
# 8   ground_truth_source=HPRC_samples (phased_with_...
# 9   method_of_phasing=phased_with_parents_and_pedi...
# 10  method_of_phasing=phased_with_parents_and_pedi...
# 11  method_of_phasing=phased_with_parents_and_pedi...
# 12  method_of_phasing=phased_with_parents_and_pedi...
# 13  ground_truth_source=HPRC_samples; type=Indel; ...
# 14  ground_truth_source=HPRC_samples; type=Indel; ...
# 15  Derived: (1 - chm13_disc/grch38_disc) * 100; A...
