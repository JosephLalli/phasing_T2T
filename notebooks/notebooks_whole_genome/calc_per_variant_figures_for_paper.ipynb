# %% [markdown]
# # Paper inline statistics (per-variant source notebook)
#
# This notebook computes **per-variant and filter-derived statistics used directly in manuscript text and tables**.
#
# ## Execution order
# 1. Run this notebook first (heavy per-variant calculations).
# 2. Then run `notebooks/notebooks_whole_genome/make_plots.ipynb`.
# 3. Then run `notebooks/notebooks_whole_genome/calc_figures_for_paper.ipynb` (summary fast-path and consolidated exports).
#
# ## Data paths
# Set `RUN_PROFILE` in the first code cell. `test` uses plain folders (`intermediate_data`, `tables`); `whole_genome` uses `_whole_genome` folders for publication-scale inputs and outputs.
#
# ## Scope
# - Keep production manuscript statistics in ordered sections.
# - Keep exploratory checks at the end under a dedicated heading.
# - Export a central statistics reference TSV to `tables/paper_per_variant_inline_statistics_reference.tsv`.

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
import polars as pl
import seaborn as sns
import glob
import os
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import importlib


# Choose "test" for Docker smoke/test data or "whole_genome" for publication-scale data.
# The environment variable is useful for automated runs; manually edit RUN_PROFILE for interactive use.
RUN_PROFILE = "whole_genome"
RUN_PROFILE = os.environ.get("PHASING_T2T_RUN_PROFILE", RUN_PROFILE)

PROFILE_PATHS = {
    "test": {
        "intermediate_data": "intermediate_data",
        "imputation_statistics": "imputation_statistics",
        "figures": "figures",
        "tables": "tables",
    },
    "whole_genome": {
        "intermediate_data": "intermediate_data_whole_genome",
        "imputation_statistics": "imputation_statistics_whole_genome",
        "figures": "figures_whole_genome",
        "tables": "tables_whole_genome",
    },
}

if RUN_PROFILE not in PROFILE_PATHS:
    raise ValueError(f"RUN_PROFILE must be one of {sorted(PROFILE_PATHS)}, got {RUN_PROFILE!r}")

profile_paths = PROFILE_PATHS[RUN_PROFILE]


pedigree_file_loc = 'resources/pedigrees/gatk_1kgp.ped'
summary_statistics_folder = profile_paths["intermediate_data"]
tables_folder = profile_paths["tables"]


def find_repo_root(start=None):
    start = Path.cwd().resolve() if start is None else Path(start).resolve()
    for candidate in (start, *start.parents):
        if (candidate / 'notebooks').exists() and (candidate / 'resources').exists():
            return candidate
    raise RuntimeError(f'Could not locate repository root from {start}')


os.chdir(find_repo_root())
required_summary_files = (
    "MAF_performance_variants.parquet",
    "chroms.parquet",
    "samples.parquet",
    "ancestries.parquet",
    "methods.parquet",
    "variants.parquet",
    "per_variant_category_imputation_performance.parquet",
    "per_sample_imputation_performance.parquet",
)
missing_summary_files = [
    required_file for required_file in required_summary_files
    if not (Path(summary_statistics_folder) / required_file).exists()
]
if missing_summary_files:
    missing_display = "\n  - ".join(missing_summary_files)
    raise FileNotFoundError(
        f"RUN_PROFILE={RUN_PROFILE!r} expected per-variant summary data at {summary_statistics_folder}, "
        f"but missing required files:\n  - {missing_display}"
    )
Path(tables_folder).mkdir(parents=True, exist_ok=True)
print(f'RUN_PROFILE: {RUN_PROFILE}')
print(f'Current working directory: {Path.cwd()}')
print(f'Summary statistics folder: {summary_statistics_folder}')
print(f'Tables folder: {tables_folder}')
# Out:
# RUN_PROFILE: whole_genome
# Current working directory: /mnt/ssd/lalli/test_dir2/phasing_T2T
# Summary statistics folder: intermediate_data_whole_genome
# Tables folder: tables_whole_genome

# %%
MAF_performance_variant_df = pl.read_parquet(f'{summary_statistics_folder}/MAF_performance_variants.parquet')
all_chroms = pd.read_parquet(f'{summary_statistics_folder}/chroms.parquet')
all_samples = pd.read_parquet(f'{summary_statistics_folder}/samples.parquet')
all_ancestries = pd.read_parquet(f'{summary_statistics_folder}/ancestries.parquet')
all_methods = pd.read_parquet(f'{summary_statistics_folder}/methods.parquet')
all_variants = pl.read_parquet(f'{summary_statistics_folder}/variants.parquet')

per_variant_category_imputation_performance = pd.read_parquet(f'{summary_statistics_folder}/per_variant_category_imputation_performance.parquet')
per_sample_imputation_performance = pd.read_parquet(f'{summary_statistics_folder}/per_sample_imputation_performance.parquet')

# %% [markdown]
# ## 1) Variant filtering statistics (Results: recombination map QC paragraph)
#
# Computes/validates numbers for statements such as:
# - additional variants excluded by VQSLOD compared with prior GRCh38 filtering
# - singleton variants retained
# - percent filtered in GRCh38 vs CHM13
# - percent filtered solely due to singleton or VQSLOD criteria

# %%
variant_filter_stats = pd.read_parquet(f"{summary_statistics_folder}/filter_summary_stats.parquet")
# variant_filter_stats['gatk_filter'] = variant_filter_stats.VQSLOD_filter #| variant_filter_stats.neg_train_site_filter
# chm13_variant_stats = variant_filter_stats.loc[(variant_filter_stats.genome=='CHM13v2.0')]
# singletons = chm13_variant_stats.loc[chm13_variant_stats.singleton]
# not_singletons = chm13_variant_stats.loc[~chm13_variant_stats.singleton]

# num_affected_gatk = chm13_variant_stats.loc[~(chm13_variant_stats.GRCh38_criteria_fail) &
#                                             # chm13_variant_stats.CHM13_criteria_fail &
#                                             chm13_variant_stats.VQSLOD_filter].len.sum()


# singletons_gained = chm13_variant_stats.loc[(chm13_variant_stats.singleton) & chm13_variant_stats.GRCh38_criteria_fail & 
#                                    ~(chm13_variant_stats.CHM13_criteria_fail | 
#                                    chm13_variant_stats.CHM13_filtered)].len.sum()
# print(f"Our VQSLOD filter resulted in the loss of an additional \n\
# {num_affected_gatk} \
# variants that would have been included in NYGC’s GRCh38 1KGP variant filtering methods, \
# but the inclusion of singleton alleles added \n\
# {singletons_gained} \
# unique variants to our dataset (Supplemental Figure 1).")
# chm13_variant_stats.loc[chm13_variant_stats.GRCh38_criteria_fail
#                          #~(chm13_variant_stats.CHM13_criteria_fail | 
#                                 #    chm13_variant_stats.CHM13_filtered)]
#                                 ].sort_values('len', ascending=False)
# chm13_variant_stats.loc[chm13_variant_stats.CHM13_criteria_fail != chm13_variant_stats.CHM13_filtered].groupby(['singleton', 'VQSLOD_filter','MERR_filter', 'HWE_pop_filter','MAC_filter','f_missing_filter','var_len_filter','alt_star_filter','pass_filter']).sum(numeric_only=True).reset_index()

# %%
# Build CHM13 variant ID set used for explicit filter reconstruction from bcftools query data
chm13_ids = pl.scan_parquet(f"{summary_statistics_folder}/MAF_performance_variants.parquet") \
    .select(['variant_id','genome']) \
    .filter(pl.col('genome')=='CHM13v2.0') \
    .select('variant_id') \
    .unique() \
    .collect() \
    .to_series()
chm13_ids = set(chm13_ids)

# %%
variant_filter_stats=pl.scan_parquet(f"{summary_statistics_folder}/bcftools_query_variant_data.parquet").with_columns(MAC_original=pl.min_horizontal(pl.col('AN_original_panel')-pl.col('AC_original_panel'), pl.col('AC_original_panel')))
variant_filter_stats
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.3 (20260303.0454)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="1013pt" height="123pt"
#  viewBox="0.00 0.00 1013.00 123.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 118.5)">
# <title>polars_query</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-118.5 1008.5,-118.5 1008.5,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="1004.5,-114.5 0,-114.5 0,-78.5 1004.5,-78.5 1004.5,-114.5"/>
# ...

# %%
variant_filter_stats = variant_filter_stats.filter(pl.col('genome')=='CHM13v2.0').with_columns(VQSLOD_filter=(pl.col('VQSLOD') < 0),
                                                         MERR_filter=(pl.col('MERR') > (602*0.05)),
                                                         in_panel=pl.col('ID').is_in(chm13_ids),
                                        HWE_pop_filter=((pl.col('HWE_EUR')<1e-10) & (pl.col('HWE_AFR')<1e-10) & (pl.col('HWE_EAS')<1e-10) & (pl.col('HWE_AMR')<1e-10) & (pl.col('HWE_SAS')<1e-10)).cast(pl.Boolean),
                                        MAC_filter=(pl.col('MAC_original')==0).cast(pl.Boolean),
                                        AC_filter=(pl.col('AC_original_panel')<=1),
                                        f_missing_filter=(pl.col('F_MISSING')>0.05).cast(pl.Boolean),
                                        var_len_filter=((pl.col('ID').str.split('_').list[2].str.len_chars().cast(pl.Int64)
                                                        - 
                                                        pl.col('ID').str.split('_').list[3].str.len_chars().cast(pl.Int64)
                                                        ).abs() >= 50-1).cast(pl.Boolean),
                                                        # minus 1 because bcftools ILEN does not count the anchor base
                                        alt_star_filter=(pl.col('ALT') == '*').cast(pl.Boolean),
                                        singleton=(pl.col('MAC_original')==1).cast(pl.Boolean),
                                        pass_filter = (pl.col('FILTER') != 'PASS').cast(pl.Boolean)
                                        ).collect()
# variant_filter_stats['MERR_filter'] = variant_filter_stats.MERR < (602*.05)
# variant_filter_states.drop(['VQSLOD','MERR'], axis=1, inplace=True)
# variant_filter_states[]

# variant_filter_stats['gatk_filter'] = variant_filter_stats.VQSLOD_filter #| variant_filter_stats.neg_train_site_filter
# chm13_variant_stats = variant_filter_stats.loc[(variant_filter_stats.genome=='CHM13v2.0')]
# singletons = chm13_variant_stats.loc[chm13_variant_stats.singleton]
# not_singletons = chm13_variant_stats.loc[~chm13_variant_stats.singleton]

# num_affected_gatk = chm13_variant_stats.loc[~(chm13_variant_stats.GRCh38_criteria_fail) &
#                                             # chm13_variant_stats.CHM13_criteria_fail &
#                                             chm13_variant_stats.VQSLOD_filter].len.sum()


# singletons_gained = chm13_variant_stats.loc[(chm13_variant_stats.singleton) & chm13_variant_stats.GRCh38_criteria_fail & 
#                                    ~(chm13_variant_stats.CHM13_criteria_fail | 
#                                    chm13_variant_stats.CHM13_filtered)].len.sum()
# print(f"Our VQSLOD filter resulted in the loss of an additional \n\
# {num_affected_gatk} \
# variants that would have been included in NYGC’s GRCh38 1KGP variant filtering methods, \
# but the inclusion of singleton alleles added \n\
# {singletons_gained} \
# unique variants to our dataset (Supplemental Figure 1).")
# chm13_variant_stats.loc[chm13_variant_stats.GRCh38_criteria_fail
#                          #~(chm13_variant_stats.CHM13_criteria_fail | 
#                                 #    chm13_variant_stats.CHM13_filtered)]
#                                 ].sort_values('len', ascending=False)
# chm13_variant_stats.loc[~chm13_variant_stats.CHM13_criteria_fail & chm13_variant_stats.CHM13_filtered].groupby(['singleton', 'VQSLOD_filter','MERR_filter', 'HWE_pop_filter','MAC_filter','f_missing_filter','var_len_filter','alt_star_filter','pass_filter']).sum(numeric_only=True).reset_index()

# %%
variant_filter_stats=variant_filter_stats.with_columns(MERR_filter=~pl.col('MERR_filter'))

# %%
variant_filter_stats=variant_filter_stats.with_columns(
                   CHM13_criteria_fail =(pl.col('MAC_filter')|pl.col('VQSLOD_filter')|
                                            pl.col('f_missing_filter')|pl.col('pass_filter')|pl.col('HWE_pop_filter')|pl.col('MERR_filter')|pl.col('var_len_filter')|pl.col('alt_star_filter')).cast(pl.Boolean)
)

# %% [markdown]
# ## 2) Table 1 and core concordance statistics
#
# Computes genotype discordance / concordance and switch error summaries by:
# - variant class (SNP, Indel, combined)
# - genome (GRCh38 vs CHM13v2.0)
# - syntenic / non-syntenic regions
# - ground truth source (HPRC/HGSVC/combined)

# %%
best_phased_variants = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree'))
catVarType = pl.Enum(['SNP','Indel','SNPs + Indels'])
best_phased_variants = best_phased_variants.with_columns(type=pl.col('type').cast(catVarType))
best_phased_variants = pl.concat([best_phased_variants, best_phased_variants.with_columns(type=pl.lit('SNPs + Indels').cast(catVarType))])
best_phased_variants_by_syntenic = best_phased_variants.group_by(['type','Syntenic','method_of_phasing','ground_truth_data_source','genome']
                                                                 ).sum(
                                                                 ).with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked')*100,
                                                                                switch_error_rate = pl.col('n_switch_errors')/pl.col('n_checked')*100
                                                                 ).to_pandas()
best_phased_variants_overall = best_phased_variants.group_by(['type','method_of_phasing','ground_truth_data_source','genome']
                                                                 ).sum(
                                                                 ).with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked')*100,
                                                                                switch_error_rate = pl.col('n_switch_errors')/pl.col('n_checked')*100
                                                                 ).to_pandas()

# %%
best_phased_variants_overall.sort_values(['ground_truth_data_source','genome','type'])
# Out:
#              type                 method_of_phasing  \
# 41            SNP  phased_with_parents_and_pedigree
# 38          Indel  phased_with_parents_and_pedigree
# 4   SNPs + Indels  phased_with_parents_and_pedigree
# 25            SNP  phased_with_parents_and_pedigree
# 20          Indel  phased_with_parents_and_pedigree
# 5   SNPs + Indels  phased_with_parents_and_pedigree
# 7             SNP  phased_with_parents_and_pedigree
# 8           Indel  phased_with_parents_and_pedigree
# 10  SNPs + Indels  phased_with_parents_and_pedigree
# 3             SNP  phased_with_parents_and_pedigree
# 13          Indel  phased_with_parents_and_pedigree
# 23  SNPs + Indels  phased_with_parents_and_pedigree
# 40            SNP  phased_with_parents_and_pedigree
# 17          Indel  phased_with_parents_and_pedigree
# 28  SNPs + Indels  phased_with_parents_and_pedigree
# 33            SNP  phased_with_parents_and_pedigree
# 14          Indel  phased_with_parents_and_pedigree
# ...

# %%
best_phased_variants_by_syntenic.loc[best_phased_variants_by_syntenic.ground_truth_data_source=='HPRC_samples'].sort_values(['ground_truth_data_source','Syntenic','genome','type'])
# Out:
#              type  Syntenic                 method_of_phasing  \
# 37            SNP     False  phased_with_parents_and_pedigree
# 35          Indel     False  phased_with_parents_and_pedigree
# 4   SNPs + Indels     False  phased_with_parents_and_pedigree
# 2             SNP     False  phased_with_parents_and_pedigree
# 59          Indel     False  phased_with_parents_and_pedigree
# 20  SNPs + Indels     False  phased_with_parents_and_pedigree
# 75            SNP      True  phased_with_parents_and_pedigree
# 76          Indel      True  phased_with_parents_and_pedigree
# 3   SNPs + Indels      True  phased_with_parents_and_pedigree
# 64            SNP      True  phased_with_parents_and_pedigree
# 71          Indel      True  phased_with_parents_and_pedigree
# 62  SNPs + Indels      True  phased_with_parents_and_pedigree
#
#    ground_truth_data_source     genome variant_id  n_switch_errors  n_checked  \
# 37             HPRC_samples     GRCh38       None              450     122930
# ...

# %% [markdown]
# ## 3) Percent concordance summaries used in text and supplemental tables

# %%
overall_subsetted = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree')).group_by(['type','Syntenic','method_of_phasing','ground_truth_data_source','genome']).sum().with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked'))
overall           = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree')).group_by(['method_of_phasing','ground_truth_data_source','genome']).sum().with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked'))
overall_syntenic  = MAF_performance_variant_df.filter((pl.col('ground_truth_data_source')!='trios')&(pl.col('Syntenic'))&(pl.col('method_of_phasing')=='phased_with_parents_and_pedigree')).group_by(['method_of_phasing','ground_truth_data_source','genome']).sum().with_columns(gt_error_rate = pl.col('n_gt_errors')/pl.col('n_gt_checked'))

# %%
overall_syntenic = overall_syntenic.to_pandas()[['Syntenic','genome','ground_truth_data_source','gt_error_rate']].sort_values(['genome','Syntenic','gt_error_rate'])
overall_syntenic['Non-reference true positive rate'] = (1-overall_syntenic.gt_error_rate) * 100
overall_syntenic['gt_error_rate'] *= 100
overall_syntenic.loc[overall_syntenic.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples','HPRC_HGSVC_all_samples'))]
# Out:
#     Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 0   21962648     GRCh38             HPRC_samples       1.106405
# 8   24194678     GRCh38            HGSVC_samples       1.386977
# 2   28325609     GRCh38   HPRC_HGSVC_all_samples       1.289689
# 6   19168753  CHM13v2.0             HPRC_samples       0.914633
# 5   21523790  CHM13v2.0            HGSVC_samples       1.203934
# 13  25190775  CHM13v2.0   HPRC_HGSVC_all_samples       1.138373
#
#     Non-reference true positive rate
# 0                          98.893595
# 8                          98.613023
# 2                          98.710311
# 6                          99.085367
# 5                          98.796066
# 13                         98.861627

# %%
overall = overall.to_pandas()[['Syntenic','genome','ground_truth_data_source','gt_error_rate']].sort_values(['genome','Syntenic','gt_error_rate'])
overall['Non-reference true positive rate'] = (1-overall.gt_error_rate) * 100
overall['gt_error_rate'] *= 100
overall.loc[overall.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples','HPRC_HGSVC_all_samples'))]
# Out:
#     Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 10  21962648     GRCh38             HPRC_samples       1.108993
# 12  24194678     GRCh38            HGSVC_samples       1.387967
# 9   28325609     GRCh38   HPRC_HGSVC_all_samples       1.291473
# 8   19168753  CHM13v2.0             HPRC_samples       0.918296
# 7   21523790  CHM13v2.0            HGSVC_samples       1.208646
# 6   25190775  CHM13v2.0   HPRC_HGSVC_all_samples       1.141592
#
#     Non-reference true positive rate
# 10                         98.891007
# 12                         98.612033
# 9                          98.708527
# 8                          99.081704
# 7                          98.791354
# 6                          98.858408

# %%
overall_subsetted = overall_subsetted.to_pandas()[['type','Syntenic','genome','ground_truth_data_source','gt_error_rate']].sort_values(['genome','type','Syntenic','gt_error_rate'])
overall_subsetted['Non-reference true positive rate'] = (1-overall_subsetted.gt_error_rate) * 100
overall_subsetted['gt_error_rate'] *= 100
overall_subsetted.loc[overall_subsetted.ground_truth_data_source.isin(('HPRC_samples', 'HGSVC_samples','HPRC_HGSVC_all_samples'))]
# Out:
#      type  Syntenic     genome ground_truth_data_source  gt_error_rate  \
# 13    SNP     False     GRCh38            HGSVC_samples       1.442616
# 44    SNP     False     GRCh38   HPRC_HGSVC_all_samples       2.010190
# 45    SNP     False     GRCh38             HPRC_samples       2.371092
# 54    SNP      True     GRCh38             HPRC_samples       0.422490
# 48    SNP      True     GRCh38   HPRC_HGSVC_all_samples       0.624200
# 42    SNP      True     GRCh38            HGSVC_samples       0.632463
# 25  Indel     False     GRCh38            HGSVC_samples       6.394128
# 46  Indel     False     GRCh38   HPRC_HGSVC_all_samples       6.490134
# 51  Indel     False     GRCh38             HPRC_samples       6.924883
# 15  Indel      True     GRCh38             HPRC_samples       4.437390
# 28  Indel      True     GRCh38   HPRC_HGSVC_all_samples       4.796596
# 36  Indel      True     GRCh38            HGSVC_samples       5.085148
# ...

# %% [markdown]
# ## 4) Final-dataset singleton accuracy and rephasing checks
#
# The manuscript singleton SER statement uses the final dataset, restricted to statistically phased HGSVC non-trio samples (`phased_with_parents_and_pedigree`, `HGSVC_samples_nontrios_only`, `rounded_MAF == "singleton"`) and grouped by genome and variant type.
#
# The rare/common rephasing summaries below are retained as QC checks for the reference-panel rephasing analysis.

# %%
final_dataset_singletons = MAF_performance_variant_df.filter(
    (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
    (pl.col('ground_truth_data_source') == 'HGSVC_samples_nontrios_only') &
    (pl.col('rounded_MAF').cast(pl.String) == 'singleton')
)

final_dataset_singleton_ser = (
    final_dataset_singletons
    .group_by(['genome', 'type'])
    .sum()
    .with_columns(SER=pl.col('n_switch_errors') / pl.col('n_checked') * 100)
    .sort(['genome', 'type'])
    .to_pandas()
    .reset_index(drop=True)
)

print('Final-dataset singleton SER (HGSVC non-trio samples):')
for _, row in final_dataset_singleton_ser.iterrows():
    print(f"  {row['genome']} {row['type']}: {row['SER']:.2f}%")

# Genotype-discordance rows for the manuscript text that discusses singleton and doubleton SNP concordance.
# The doubleton prose values use all HPRC/HGSVC assembly samples; the singleton prose value uses HGSVC non-trio samples.
first_non_singleton_maf_bin = '0.00021-0.00042'
paper_maf_concordance = (
    MAF_performance_variant_df
    .filter(
        (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
        (pl.col('type') == 'SNP') &
        (
            ((pl.col('ground_truth_data_source') == 'HPRC_HGSVC_all_samples') &
             (pl.col('rounded_MAF').cast(pl.String) == first_non_singleton_maf_bin)) |
            ((pl.col('ground_truth_data_source') == 'HGSVC_samples_nontrios_only') &
             (pl.col('rounded_MAF').cast(pl.String) == 'singleton'))
        )
    )
    .group_by(['ground_truth_data_source', 'rounded_MAF', 'genome', 'type'])
    .sum()
    .with_columns(
        gt_error_rate=pl.col('n_gt_errors') / pl.col('n_gt_checked') * 100,
        gt_accuracy_rate=100 - (pl.col('n_gt_errors') / pl.col('n_gt_checked') * 100),
    )
    .sort(['ground_truth_data_source', 'rounded_MAF', 'genome', 'type'])
    .to_pandas()
    .reset_index(drop=True)
)

print('\nManuscript singleton/doubleton SNP genotype discordance checks:')
for _, row in paper_maf_concordance.iterrows():
    print(
        f"  {row['ground_truth_data_source']} {row['rounded_MAF']} {row['genome']}: "
        f"{row['gt_error_rate']:.2f}% discordant; {row['gt_accuracy_rate']:.2f}% concordant"
    )

rephase = all_variants.filter((pl.col('method_of_phasing') == '1kgp_variation_phased_with_reference_panel') & 
                              (pl.col('ground_truth_data_source') == 'HPRC_samples'))

singletons_rephase_sum = rephase.filter(pl.col('contextual_MAC') == 1).group_by('genome').sum().to_pandas().reset_index()
singletons_rephase_sum['SER'] = singletons_rephase_sum.n_switch_errors/singletons_rephase_sum.n_checked*100
print('\nReference-panel rephasing singleton QC (not the manuscript singleton SER):')
for idx, (genome, ser) in singletons_rephase_sum[['genome','SER']].iterrows():
    print(f'  Singletons in {genome}: {ser}')

rare_rephase = rephase.filter(pl.col('contextual_MAC')/pl.col('contextual_AN') < 0.01)
common_rephase = rephase.filter(pl.col('contextual_MAC')/pl.col('contextual_AN') >= 0.01)

rare_rephase_sum = rare_rephase.group_by('genome').sum().to_pandas().reset_index()
common_rephase_sum = common_rephase.group_by('genome').sum().to_pandas().reset_index()
for idx, (genome, n_switch_errors, n_checked) in rare_rephase_sum[['genome','n_switch_errors', 'n_checked']].iterrows():
    print (f"\nRare in {genome}: {n_switch_errors/n_checked*100}")
    print (f"Common in {genome}: {common_rephase_sum.iloc[idx].n_switch_errors/common_rephase_sum.iloc[idx].n_checked*100}")
syntenic = common_rephase.filter(pl.col('Syntenic') == True)
nonsyntenic = common_rephase.filter(pl.col('Syntenic') == False)

syntenic_sum = syntenic.group_by('genome').sum().to_pandas().set_index('genome')
nonsyntenic_sum = nonsyntenic.group_by('genome').sum().to_pandas().set_index('genome')

for genome, row in syntenic_sum.iterrows():
    print (f"\nCommon Syntenic in {genome}: {row.n_switch_errors/row.n_checked*100}")
    print (f"Common Nonsyntenic {genome}: {nonsyntenic_sum.loc[genome].n_switch_errors/nonsyntenic_sum.loc[genome].n_checked*100}")
# Out:
# Final-dataset singleton SER (HGSVC non-trio samples):
#   CHM13v2.0 SNP: 29.78%
#   CHM13v2.0 Indel: 28.85%
# Manuscript singleton/doubleton SNP genotype discordance checks:
#   HPRC_HGSVC_all_samples 0.00021-0.00042 GRCh38: 0.51% discordant; 99.49% concordant
#   HPRC_HGSVC_all_samples 0.00021-0.00042 CHM13v2.0: 0.45% discordant; 99.55% concordant
#   HGSVC_samples_nontrios_only singleton CHM13v2.0: 1.42% discordant; 98.58% concordant
# Reference-panel rephasing singleton QC (not the manuscript singleton SER):
#   Singletons in CHM13v2.0: 8.27393547908082
#   Singletons in GRCh38: 11.645089351135173
# Rare in CHM13v2.0: 6.224834122910295
# Common in CHM13v2.0: 0.9022070150698872
#
# Rare in GRCh38: 2.5241491223193746
# Common in GRCh38: 0.8103833501207229
# Common Syntenic in GRCh38: 0.9021848407934598
# Common Nonsyntenic GRCh38: 0.9210526315789472
#
# Common Syntenic in CHM13v2.0: 0.8099508170456401
# Common Nonsyntenic CHM13v2.0: 1.8914473684210527

# %%
synEnum = pl.Enum(categories=['All_regions', 'Syntenic', 'Nonsyntenic'])
concordance = all_variants.filter((pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
                                  (pl.col('ground_truth_data_source') == 'HPRC_samples')).with_columns(Syntenic=pl.col('Syntenic').cast(str).replace('true','Syntenic').replace('false','Nonsyntenic').cast(synEnum))

# %%
concordance_summary = concordance.clone().with_columns(Syntenic = pl.lit('All_regions').cast(synEnum))
concordance_summary = pl.concat((concordance, concordance_summary)).group_by(['Syntenic','genome','type']).sum().to_pandas().reset_index()
concordance_summary = pd.concat((concordance_summary, concordance_summary.copy().assign(type = 'SNPs + Indels').groupby(['Syntenic','genome','type'], observed=True).sum(numeric_only=True).reset_index()))
concordance_summary['gt_error_rate'] = concordance_summary.n_gt_errors/concordance_summary.n_gt_checked*100
concordance_summary['gt_accuracy_rate'] = 100-concordance_summary['gt_error_rate'] 
concordance_summary['switch_error_rate'] = concordance_summary.n_switch_errors/concordance_summary.n_checked*100
concordance_summary['Syntenic'] = concordance_summary.Syntenic.replace('false', 'Nonsyntenic').replace('true','Syntenic')

# %%
pd.set_option("display.precision", 3)
concordance_summary.sort_values(['Syntenic','genome','type']).set_index(['Syntenic','genome','type'])[['switch_error_rate','gt_error_rate','n_gt_errors','n_gt_checked', 'n_switch_errors', 'n_checked']].astype(float)
# Out:
#                                      switch_error_rate  gt_error_rate  \
# Syntenic    genome    type
# All_regions GRCh38    Indel                      1.385          4.440
#                       SNP                        0.211          0.425
#                       SNPs + Indels              0.408          1.109
#             CHM13v2.0 Indel                      1.312          4.010
#                       SNP                        0.149          0.257
#                       SNPs + Indels              0.355          0.918
# Syntenic    GRCh38    Indel                      1.385          4.437
#                       SNP                        0.210          0.422
#                       SNPs + Indels              0.408          1.106
#             CHM13v2.0 Indel                      1.311          4.003
#                       SNP                        0.149          0.254
#                       SNPs + Indels              0.354          0.915
# ...

# %% [markdown]
# ## Exploratory Analyses (Review for Deletion)
#
# The cells below are retained for ad hoc QC and manuscript review checks; they are not required for core paper-inline exports.

# %%
# Consolidated export of paper-inline statistics sourced from this notebook

type_abbrev_map = {'SNP': 'SNP', 'Indel': 'Ind', 'SNPs + Indels': 'All'}
syn_abbrev_map = {'All_regions': 'All', 'Syntenic': 'Syn', 'Nonsyntenic': 'Nsyn'}

rows = []

# --- Table 1 / concordance style summaries ---
for _, r in concordance_summary.iterrows():
    type_abbrev = type_abbrev_map.get(r['type'], r['type'])
    syn_abbrev = syn_abbrev_map.get(r['Syntenic'], r['Syntenic'])
    stat_code = f'C_{type_abbrev}_{syn_abbrev}'
    rows.append({
        'Stat_Code': stat_code,
        'Section': 'Per-variant concordance',
        'Statistic_Description': f"{r['Syntenic']} | {r['type']} | gt_error_rate",
        'Value_CHM13': float(r['gt_error_rate']) if r['genome'] == 'CHM13v2.0' else np.nan,
        'Value_GRCh38': float(r['gt_error_rate']) if r['genome'] == 'GRCh38' else np.nan,
        'Percent_Change': np.nan,
        'Paper_Location': 'Results: Table 1 / concordance paragraphs',
        'Source_Notebook': 'calc_per_variant_figures_for_paper.ipynb',
        'Notes': 'ground_truth_source=HPRC_samples (phased_with_parents_and_pedigree)'
    })

# --- Final-dataset singleton SER ---
for _, r in final_dataset_singleton_ser.iterrows():
    type_abbrev = type_abbrev_map.get(r['type'], r['type'])
    rows.append({
        'Stat_Code': f'SING_SER_{type_abbrev}',
        'Section': 'Singleton SER',
        'Statistic_Description': f"Final-dataset singleton SER | {r['type']}",
        'Value_CHM13': float(r['SER']) if r['genome'] == 'CHM13v2.0' else np.nan,
        'Value_GRCh38': float(r['SER']) if r['genome'] == 'GRCh38' else np.nan,
        'Percent_Change': np.nan,
        'Paper_Location': 'Results: statistically phased singleton text; Figure 2b,d',
        'Source_Notebook': 'calc_per_variant_figures_for_paper.ipynb',
        'Notes': 'method_of_phasing=phased_with_parents_and_pedigree; ground_truth_source=HGSVC_samples_nontrios_only; rounded_MAF=singleton'
    })

# --- Singleton/doubleton genotype-discordance rows for manuscript concordance prose ---
maf_concordance_defs = {
    ('HPRC_HGSVC_all_samples', first_non_singleton_maf_bin, 'SNP'): {
        'Stat_Code': 'GT_DISC_SNP_DOUBLETON',
        'Statistic_Description': 'Doubleton SNP genotype discordance (first non-singleton MAF bin)',
        'Paper_Location': 'Results: genotype concordance paragraph, manuscript lines 215-218',
        'Notes': ('method_of_phasing=phased_with_parents_and_pedigree; '
                  f'ground_truth_source=HPRC_HGSVC_all_samples; rounded_MAF={first_non_singleton_maf_bin}; '
                  'equivalent to contextual_MAC=2 in variants.parquet; concordance=100-discordance'),
    },
    ('HGSVC_samples_nontrios_only', 'singleton', 'SNP'): {
        'Stat_Code': 'GT_DISC_SNP_SINGLETON_FINAL',
        'Statistic_Description': 'Singleton SNP genotype discordance (HGSVC non-trio final dataset)',
        'Paper_Location': 'Results: genotype concordance paragraph, manuscript lines 215-218',
        'Notes': ('method_of_phasing=phased_with_parents_and_pedigree; '
                  'ground_truth_source=HGSVC_samples_nontrios_only; rounded_MAF=singleton; '
                  'concordance=100-discordance'),
    },
}

for key, group in paper_maf_concordance.groupby(['ground_truth_data_source', 'rounded_MAF', 'type'], observed=True):
    definition = maf_concordance_defs.get(tuple(key))
    if definition is None:
        continue
    by_genome = group.set_index('genome')
    rows.append({
        'Stat_Code': definition['Stat_Code'],
        'Section': 'MAF-bin genotype concordance',
        'Statistic_Description': definition['Statistic_Description'],
        'Value_CHM13': float(by_genome.loc['CHM13v2.0', 'gt_error_rate']) if 'CHM13v2.0' in by_genome.index else np.nan,
        'Value_GRCh38': float(by_genome.loc['GRCh38', 'gt_error_rate']) if 'GRCh38' in by_genome.index else np.nan,
        'Percent_Change': np.nan,
        'Paper_Location': definition['Paper_Location'],
        'Source_Notebook': 'calc_per_variant_figures_for_paper.ipynb',
        'Notes': definition['Notes'],
    })

paper_inline_statistics_per_variant = pd.DataFrame(rows)

os.makedirs('tables', exist_ok=True)
out_path = f'{tables_folder}/paper_per_variant_inline_statistics_reference.tsv'
paper_inline_statistics_per_variant.to_csv(out_path, sep='	', index=False)
print(f'Wrote {len(paper_inline_statistics_per_variant)} per-variant rows to {out_path}')
paper_inline_statistics_per_variant.head()
# Out:
# Wrote 22 per-variant rows to tables_whole_genome/paper_per_variant_inline_statistics_reference.tsv
#     Stat_Code                  Section                Statistic_Description  \
# 0   C_Ind_All  Per-variant concordance  All_regions | Indel | gt_error_rate
# 1  C_Ind_Nsyn  Per-variant concordance  Nonsyntenic | Indel | gt_error_rate
# 2   C_Ind_Syn  Per-variant concordance     Syntenic | Indel | gt_error_rate
# 3   C_Ind_All  Per-variant concordance  All_regions | Indel | gt_error_rate
# 4   C_SNP_Syn  Per-variant concordance       Syntenic | SNP | gt_error_rate
#
#    Value_CHM13  Value_GRCh38  Percent_Change  \
# 0          NaN         4.440             NaN
# 1          NaN         6.925             NaN
# 2          NaN         4.437             NaN
# 3         4.01           NaN             NaN
# 4          NaN         0.422             NaN
#
#                               Paper_Location  \
# 0  Results: Table 1 / concordance paragraphs
# ...

# %%
# Exploratory: HGSVC proband singleton counts
HGSVC_probands = all_variants.filter(
    (pl.col('method_of_phasing') == 'phased_with_parents_and_pedigree') &
    (pl.col('ground_truth_data_source') == 'HGSVC_probands')
)

singletons_HGSVC_probands_sum = (
    HGSVC_probands
    .filter(pl.col('contextual_MAC') == 1)
    .group_by('genome')
    .sum()
    .to_pandas()
    .reset_index()
)
singletons_HGSVC_probands_sum
# Out:
#    index     genome variant_id    position  n_switch_errors  n_checked  \
# 0      0  CHM13v2.0       None  3423461243             1338      13230
#
#   method_of_phasing ground_truth_data_source chrom type  n_gt_errors  \
# 0               NaN                      NaN   NaN  NaN       120884
#
#    n_gt_checked  contextual_MAC  contextual_AN  is_private_variant  Syntenic  \
# 0       1350411           44926      287706104                   0     43943
#
#    multiallelic
# 0         19058
